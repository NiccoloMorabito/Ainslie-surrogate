# %% [markdown]
# The idea is to implement here an architecture similar to the one developed in "Datadriven wind turbine wake modeling via probabilistic Machine Learning":
# - autoencoder trained on the output wake field
# - MLP from input to latent space which is then plugged to the trained decoder to obtain the actual desired output

# %%
import torch
import torch.nn as nn
import numpy as np
import random
from math import floor, ceil

from utils.metrics import MetricsLogger
from utils.data_loaders import get_wake_dataloaders
import utils.utils as uutils
import utils.data_utils as data_utils
import utils.plotting as plotting
from utils.evaluation import test_pytorch_model

# define random seeds for Neural Networks
torch.manual_seed(0)
np.random.seed(0)

# %%
LATENT_SPACE = 8
CONVOLUTIONAL = False

BATCH_SIZE = 64
EPOCHS = 500
LR = 1e-6
CONSIDER_WS = False
COORDS_AS_INPUT = False # multivariate data
FACTORS_FOLDER = "discr_factors_x2_30_y-2_2_step0.125_TIstep0.01_CTstep0.01"
DATA_FOLDER = f"data/{FACTORS_FOLDER}/"
INPUT_VAR_TO_TRAIN_REDUCTION_FACTOR = {'ti': 4, 'ct': 4}
train_reduc_factor_string = "training_factors=" + "-".join([f"{k}{v}" for k, v in INPUT_VAR_TO_TRAIN_REDUCTION_FACTOR.items()])
DEVICE = torch.device("cuda" if torch.cuda.is_available() else "cpu")
print(f"Device: {DEVICE}")
# Out:
# Device: cpu

# %%
# autoencoders hyperparameters
if not CONVOLUTIONAL:
    HIDDEN_LAYERS_UNITS = [LATENT_SPACE, 16, 32, 64, 128, 256, 512, 1024, 2048, 4096]
    ACTIVATION_FUNCTION = nn.Sigmoid()
    MODEL_NAME = f"autoencoders_layers{'-'.join(str(lu) for lu in HIDDEN_LAYERS_UNITS)}_{train_reduc_factor_string}"

class AutoEncoder(nn.Module):
    def __init__(self, layer_dimensions: list[int], num_cells: int, activation_function, flatten: bool = False):
        super(AutoEncoder, self).__init__()
        self.act_function = activation_function
        incr = sorted(layer_dimensions)
        decr = sorted(layer_dimensions, reverse=True)
        
        encoder_layers = self.__generate_encoder_layers(num_cells, decr)
        decoder_layers = self.__generate_decoder_layers(num_cells, incr)
        self.encoder = nn.Sequential(*encoder_layers)
        self.decoder = nn.Sequential(*decoder_layers)
    
    def __generate_encoder_layers(self, num_cells: int, decr_layers_units: list[int]):
        encoder_layers = []
        encoder_layers += [nn.Linear(num_cells, decr_layers_units[0]), self.act_function]
        for first, second in zip(decr_layers_units, decr_layers_units[1:]):
            encoder_layers += [nn.Linear(first, second), self.act_function] #TODO activate last layer?
        return encoder_layers

    def __generate_decoder_layers(self, num_cells: int, incr_layers_units: list[int]):
        decoder_layers = []
        for first, second in zip(incr_layers_units, incr_layers_units[1:]):
            decoder_layers += [nn.Linear(first, second), self.act_function]
        decoder_layers += [nn.Linear(incr_layers_units[-1], num_cells), self.act_function] #TODO activate last layer?
        return decoder_layers
    
    def forward(self, x):
        encode = self.encoder(x)
        decode = self.decoder(encode)
        return decode

# %%
#Link for Convolutional Autoencoder https://medium.com/dataseries/convolutional-autoencoder-in-pytorch-on-mnist-dataset-d65145c132ac

# convolutional autoencoders hyperparameters
# TODO change parameters of convolutional layers according also to the final grid shape
if CONVOLUTIONAL:
    HIDDEN_LINEAR_LAYERS_UNITS = sorted([])[::-1]
    CHANNELS = [32, 16, 8]
    KERNEL_SIZES = [3, 3, 3]
    STRIDES = [2] * len(CHANNELS)
    PADDINGS = [1] * len(CHANNELS)
    assert len(CHANNELS) == len(KERNEL_SIZES) == len(STRIDES) == len(PADDINGS)
    CONV_INPUTS = [(c_in, c_out, ks, s, p) for c_in, c_out, ks, s, p in \
                zip([1] + CHANNELS[:-1], CHANNELS, KERNEL_SIZES, STRIDES, PADDINGS)] # first has one channel (wind deficit)
    ACTIVATION_FUNCTION = nn.ReLU()
    CONVOLUTIONAL = True

    MODEL_NAME = f"conv_autoencoders_channels{'-'.join(str(c) for c in CHANNELS)}_"\
        f"kernels{'-'.join(str(k) for k in KERNEL_SIZES)}_"\
        f"strides{'-'.join(str(s) for s in STRIDES)}_"\
        f"paddings{'-'.join(str(p) for p in PADDINGS)}_"\
        f"lin-layers{'-'.join(str(lu) for lu in HIDDEN_LINEAR_LAYERS_UNITS)}_"\
        f"{train_reduc_factor_string}"


class ReshapeInputModule(nn.Module):
    """Dividing the two dimensions of the wake field and adding a dimension for the channel"""
    def __init__(self, field_shape):
        super(ReshapeInputModule, self).__init__()
        self.field_shape = field_shape
    
    def forward(self, x):
        x = x.view(-1, *self.field_shape)
        x = torch.unsqueeze(x, 1)
        return x

class RestoreShapeModule(nn.Module):
    """Restoring the original 1-dimensional shape of the wake field"""
    def __init__(self):
        super(RestoreShapeModule, self).__init__()
    
    def forward(self, x):
        x = x.flatten(start_dim=1)
        return x

#TODO delete
class PrintLayer(nn.Module):
    def __init__(self):
        super(PrintLayer, self).__init__()
    
    def forward(self, x):
        #print(x.shape)
        return x

#TODO move somewhere else
#TODO change name (it's not about output and input, it's about Conv or ConvTranspose)
#TODO this function is not really working in case of big kernel sizes or decreasing channels (?)
def conv_output_shape(input_shape, output_channels, kernel_size=1, stride=1, padding=0, dilation=1):
    assert len(input_shape) == 3 # no batch_size
    in_channels, h_in, w_in  = input_shape
    
    if type(kernel_size) is not tuple:
        kernel_size = (kernel_size, kernel_size)
    h_out = floor( ((h_in + (2 * padding) - ( dilation * (kernel_size[0] - 1) ) - 1 )/ stride) + 1)
    w_out = floor( ((w_in + (2 * padding) - ( dilation * (kernel_size[1] - 1) ) - 1 )/ stride) + 1)

    return [output_channels, h_out, w_out]

#TODO move somewhere else (only if you will use it)
#TODO change name (it's not about output and input, it's about Conv or ConvTranspose)
def conv_transpose_output_shape(input_shape, output_channels, kernel_size=1, stride=1, padding=0, output_padding=0, dilation=1):
    assert len(input_shape) == 3  # no batch_size
    in_channels, h_in, w_in = input_shape
    
    if type(kernel_size) is not tuple:
        kernel_size = (kernel_size, kernel_size)
    
    # Compute the input shape
    h_out = ceil((h_in - 1) * stride - 2 * padding + dilation * (kernel_size[0] - 1) + output_padding + 1)
    w_out = ceil((w_in - 1) * stride - 2 * padding + dilation * (kernel_size[1] - 1) + output_padding + 1)

    return [output_channels, h_out, w_out]

#TODO fix the following two functions as well
def get_dim_out_conv_transpose(dim_in, kernel_size, padding, stride, dilation, output_padding):
    return ceil((dim_in - 1) * stride - 2 * padding + dilation * (kernel_size - 1) + output_padding + 1)

def compute_output_padding(input_shape, output_shape, kernel_size=1, stride=1, padding=0, dilation=1):
    #TODO find smarter solution to find this value
    assert len(input_shape) == 2  # no batch_size nor channel
    assert len(output_shape) == 2 # no batch_size nor channel
    h_in, w_in = input_shape
    h_out, w_out = output_shape
    
    if type(kernel_size) is not tuple:
        kernel_size = (kernel_size, kernel_size)
    
    output_padding1 = 0
    while True:
        h_gen = get_dim_out_conv_transpose(h_in, kernel_size[0], padding, stride, dilation, output_padding1)
        if h_gen == h_out:
            break
        output_padding1 += 1
    
    output_padding2 = 0
    while True:
        w_gen = get_dim_out_conv_transpose(w_in, kernel_size[1], padding, stride, dilation, output_padding2)
        if w_gen == w_out:
            break
        output_padding2 += 1
    
    return output_padding1, output_padding2

def product(list: list[int]) -> int:
    product = 1
    for el in list:
        product *= el
    return product

class ConvEncoder(nn.Module):

    def __init__(self, field_shape):
        super().__init__()
        
        ### Convolutional section
        conv_shapes = [ [1] + list(field_shape) ]
        cnn_layers = [PrintLayer(), ReshapeInputModule(field_shape), PrintLayer()]
        for in_channels, out_channels, kernel_size, stride, padding in CONV_INPUTS:
            # shape after Conv2d: [batch_size, C_in, H_old, W_old] = [batch_size, C_out, H_new, W_new]
            cnn_layers += [nn.Conv2d(in_channels, out_channels, kernel_size, stride, padding),
                           PrintLayer(),
                           #nn.BatchNorm2d(out_channels), #TODO mettere o no????
                           #nn.MaxPool2d(kernel_size, stride), #TODO mettere o no?
                           ACTIVATION_FUNCTION]
            conv_shapes += [conv_output_shape(conv_shapes[-1], out_channels, kernel_size, stride, padding)]
        self.encoder_cnn = nn.Sequential(*cnn_layers)
        self.conv_shapes = conv_shapes
        print(conv_shapes)
        print(product(conv_shapes[-1]))

        ### Flatten layer
        self.flatten = nn.Flatten(start_dim=1)
        
        ### Linear section
        linear_units = [product(conv_shapes[-1])] + HIDDEN_LINEAR_LAYERS_UNITS
        linear_layers = [PrintLayer()]
        for first, second in zip(linear_units, linear_units[1:]):
            linear_layers += [nn.Linear(first, second), ACTIVATION_FUNCTION, PrintLayer()]
        # last layer is activated as well
        self.encoder_lin = nn.Sequential(*linear_layers)
        
    def forward(self, x):
        x = self.encoder_cnn(x)
        x = self.flatten(x)
        x = self.encoder_lin(x)
        return x

class ConvDecoder(nn.Module):
    
    def __init__(self, transp_conv_shapes: list[list[int]]):
        super().__init__()
        ### Linear section
        linear_units = HIDDEN_LINEAR_LAYERS_UNITS[::-1] + [product(transp_conv_shapes[0])]
        linear_layers = list()
        for first, second in zip(linear_units, linear_units[1:]):
            linear_layers += [nn.Linear(first, second), ACTIVATION_FUNCTION, PrintLayer()]
        self.decoder_lin = nn.Sequential(*linear_layers)

        ### Flatten layer
        self.unflatten = nn.Unflatten(dim=1, unflattened_size=transp_conv_shapes[0])

        ### Convolutional section
        cnn_layers = [PrintLayer()]
        for i, (in_channels, out_channels, kernel_size, stride, padding) in enumerate(CONV_INPUTS[::-1]):
            output_padding = compute_output_padding(transp_conv_shapes[i][-2:], transp_conv_shapes[i+1][-2:],
                                                    kernel_size, stride, padding)
            cnn_layers += [nn.ConvTranspose2d(out_channels, in_channels, kernel_size, stride, padding,
                                             output_padding=output_padding),
                           PrintLayer(),
                           #nn.BatchNorm2d(in_channels), #TODO mettere o no????
                           ACTIVATION_FUNCTION]
        cnn_layers += [RestoreShapeModule(), PrintLayer()]
        self.decoder_cnn = nn.Sequential(*cnn_layers)
        
    def forward(self, x):
        x = self.decoder_lin(x)
        x = self.unflatten(x)
        x = self.decoder_cnn(x)
        x = torch.sigmoid(x) #TODO??????
        return x

class ConvAutoEncoder(nn.Module):
    def __init__(self, field_shape) -> None:
        super().__init__() 
        self.encoder = ConvEncoder(field_shape)
        self.decoder = ConvDecoder(self.encoder.conv_shapes[::-1])
    
    def forward(self, x):
        encode = self.encoder(x)
        decode = self.decoder(encode)
        return decode

# %%
"CODE TO TEST THE CONVOLUTION AUTOENCODER STRUCTURE" #TODO move or delete

shape1 = [1, 32, 224]
shape2 = [2, 15, 111]
shape3 = [4, 7, 55]
shape4 = [8, 3, 27]
shape5 = [16, 1, 13]

kernel_size = 3
stride = 2
padding = 1

print(shape1)
print(conv_output_shape(shape2, 2, 5, 2, 1))
print(conv_output_shape(shape2, 4, 5, 2, 1))
print(conv_output_shape(shape3, 8, 5, 2, 1))
print(conv_output_shape(shape4, 16, 5, 2, 1))
print("---")
print(shape5)
output_padding = compute_output_padding(shape5[-2:], shape4[-2:], kernel_size=kernel_size, stride=stride, padding=padding)[0]
print(conv_transpose_output_shape(shape5, output_channels=8, kernel_size=kernel_size, stride=stride, padding=padding,
                                  output_padding=output_padding))

output_padding = compute_output_padding(shape4[-2:], shape3[-2:], kernel_size=kernel_size, stride=stride, padding=padding)[0]
print(conv_transpose_output_shape(shape4, output_channels=4, kernel_size=kernel_size, stride=stride, padding=padding,
                                  output_padding=output_padding))
output_padding = compute_output_padding(shape3[-2:], shape2[-2:], kernel_size=kernel_size, stride=stride, padding=padding)[0]
print(conv_transpose_output_shape(shape3, output_channels=2, kernel_size=kernel_size, stride=stride, padding=padding,
                                  output_padding=output_padding))
output_padding = compute_output_padding(shape2[-2:], shape1[-2:], kernel_size=kernel_size, stride=stride, padding=padding)[0]
print(conv_transpose_output_shape(shape2, output_channels=1, kernel_size=kernel_size, stride=stride, padding=padding,
                                  output_padding=output_padding))
# Out:
# [1, 32, 224]
# [2, 7, 55]
# [4, 7, 55]
# [8, 3, 27]
# [16, 1, 13]
# ---
# [16, 1, 13]
# [8, 3, 27]
# [4, 7, 55]
# [2, 15, 111]
# [1, 32, 224]

# %% [markdown]
# ### Data loading

# %%
valid_dataloader = None
train_dataloader, valid_dataloader, test_dataloader = get_wake_dataloaders(DATA_FOLDER,
                                                          consider_ws=CONSIDER_WS,
                                                          coords_as_input=COORDS_AS_INPUT,
                                                          #train_perc=0.6,
                                                          #test_perc=0.2,
                                                          #validation_perc=0.2,
                                                          input_var_to_train_reduction_factor=INPUT_VAR_TO_TRAIN_REDUCTION_FACTOR,
                                                          batch_size=BATCH_SIZE)
len(train_dataloader), len(test_dataloader)
# Out:
# /Users/niccolomorabito/Library/CloudStorage/GoogleDrive-morabito.1808746@studenti.uniroma1.it/My Drive/BDMA/Semester4 Thesis/Ainslie-surrogate/utils/data_loaders.py:248: UserWarning:
# Ignoring percentages of train-valid-test split (train_perc=0.8, valid_perc=0, test_perc=0.2)
# and using the reduction factors for the training set instead:
# {'ti': 4, 'ct': 4}
#   warnings.warn(
# (9, 63)

# %%
for b in train_dataloader:
    print(b[0].shape, b[1].shape)
    break

input_space = train_dataloader.dataset.inputs.shape[1]
output_space = train_dataloader.dataset.outputs.shape[1]
print(f"{input_space=}\t{output_space=}")
# Out:
# torch.Size([64, 2]) torch.Size([64, 7168])
# input_space=2	output_space=7168

# %% [markdown]
# ### Autoencoder definition

# %%
if CONVOLUTIONAL:
    autoencoder = ConvAutoEncoder(train_dataloader.dataset.X_grid.shape).to(DEVICE)
else:
    autoencoder = AutoEncoder(HIDDEN_LAYERS_UNITS, train_dataloader.dataset.num_cells, ACTIVATION_FUNCTION).to(DEVICE)
print(autoencoder)

BEST_MODEL_PATH = f"saved_models/{FACTORS_FOLDER}/{MODEL_NAME}.pt"
if CONSIDER_WS:
    MODEL_NAME += "_consider_ws"
    BEST_MODEL_PATH = f"saved_models/{FACTORS_FOLDER}/{MODEL_NAME}.pt"\
        .replace("TIstep0.01_CTstep0.01", "reducedTI-CT")
print(f"Model name: {MODEL_NAME}")
print(f"Best model path: {BEST_MODEL_PATH}")

MODEL_DESCRIPTION = f"{MODEL_NAME}_{FACTORS_FOLDER}: act. func. {ACTIVATION_FUNCTION.__class__.__name__} " +\
    f", batch size {BATCH_SIZE}, {EPOCHS} epochs, lr={LR})"
print(f"Model description: {MODEL_DESCRIPTION}")
# Out:
# AutoEncoder(
#   (act_function): Sigmoid()
#   (encoder): Sequential(
#     (0): Linear(in_features=7168, out_features=4096, bias=True)
#     (1): Sigmoid()
#     (2): Linear(in_features=4096, out_features=2048, bias=True)
#     (3): Sigmoid()
#     (4): Linear(in_features=2048, out_features=1024, bias=True)
#     (5): Sigmoid()
#     (6): Linear(in_features=1024, out_features=512, bias=True)
#     (7): Sigmoid()
#     (8): Linear(in_features=512, out_features=256, bias=True)
#     (9): Sigmoid()
#     (10): Linear(in_features=256, out_features=128, bias=True)
#     (11): Sigmoid()
#     (12): Linear(in_features=128, out_features=64, bias=True)
#     (13): Sigmoid()
#     (14): Linear(in_features=64, out_features=32, bias=True)
#     (15): Sigmoid()
#     (16): Linear(in_features=32, out_features=16, bias=True)
#     (17): Sigmoid()
#     (18): Linear(in_features=16, out_features=8, bias=True)
#     (19): Sigmoid()
#   )
#   (decoder): Sequential(
#     (0): Linear(in_features=8, out_features=16, bias=True)
#     (1): Sigmoid()
#     (2): Linear(in_features=16, out_features=32, bias=True)
#     (3): Sigmoid()
#     (4): Linear(in_features=32, out_features=64, bias=True)
#     (5): Sigmoid()
#     (6): Linear(in_features=64, out_features=128, bias=True)
#     (7): Sigmoid()
#     (8): Linear(in_features=128, out_features=256, bias=True)
#     (9): Sigmoid()
#     (10): Linear(in_features=256, out_features=512, bias=True)
#     (11): Sigmoid()
#     (12): Linear(in_features=512, out_features=1024, bias=True)
#     (13): Sigmoid()
#     (14): Linear(in_features=1024, out_features=2048, bias=True)
#     (15): Sigmoid()
#     (16): Linear(in_features=2048, out_features=4096, bias=True)
#     (17): Sigmoid()
#     (18): Linear(in_features=4096, out_features=7168, bias=True)
#     (19): Sigmoid()
#   )
# )
# Model name: autoencoders_layers8-16-32-64-128-256-512-1024-2048-4096_training_factors=ti4-ct4
# Best model path: saved_models/discr_factors_x2_30_y-2_2_step0.125_TIstep0.01_CTstep0.01/autoencoders_layers8-16-32-64-128-256-512-1024-2048-4096_training_factors=ti4-ct4.pt
# Model description: autoencoders_layers8-16-32-64-128-256-512-1024-2048-4096_training_factors=ti4-ct4_discr_factors_x2_30_y-2_2_step0.125_TIstep0.01_CTstep0.01: act. func. Sigmoid , batch size 64, 500 epochs, lr=1e-06)

# %% [markdown]
# ### Autoencoder training

# %%
optimizer = torch.optim.Adam(
    [p for p in autoencoder.parameters() if p.requires_grad], lr=LR
)
loss_function = nn.MSELoss(reduction='mean')

metrics_logger = MetricsLogger(name=MODEL_NAME)
best_vloss = 1_000_000.
for epoch in range(EPOCHS):
    '''TRAINING'''
    autoencoder.train(True)
    epoch_tloss = 0
    for batch in iter(train_dataloader):
        wake_field = batch[1].to(DEVICE) # only considering the wake field (not the input variables)
        optimizer.zero_grad()
        reconstructed_wake_field = autoencoder(wake_field)
        tloss = loss_function(reconstructed_wake_field, wake_field)
        tloss.backward()
        #torch.nn.utils.clip_grad_norm_(model.parameters(), 0.5) TODO
        optimizer.step()

        epoch_tloss += tloss.item() * BATCH_SIZE

    avg_tloss = epoch_tloss / len(train_dataloader.sampler)
    metrics_logger.log_metric(epoch, 'Training loss', avg_tloss)

    '''VALIDATION'''
    if valid_dataloader:
        autoencoder.train(False)
        epoch_vloss = 0
        for batch in iter(valid_dataloader):
            wake_field = batch[1].to(DEVICE) # only considering the wake field (not the input variables)
            reconstructed_wake_field = autoencoder(wake_field)
            vloss = loss_function(reconstructed_wake_field, wake_field)

            epoch_vloss += vloss.item() * BATCH_SIZE

        avg_vloss = epoch_vloss / len(valid_dataloader.sampler)
        metrics_logger.log_metric(epoch, 'Validation loss', avg_vloss)
        # Track best performance, and save the model's state
        if avg_vloss < best_vloss:
            best_vloss = avg_vloss
            torch.save(autoencoder.state_dict(), BEST_MODEL_PATH)
    
    #TODO remove from here
    rwf = reconstructed_wake_field.detach()[random.randint(0, 50)].reshape(32, 224)
    wf = wake_field.detach()[0].reshape(32, 224)
    plotting.plot_maps(train_dataloader.dataset.X_grid, train_dataloader.dataset.Y_grid,
                        wf, rwf, 0, 0, 0, error_to_plot='absolute')
    #TODO remove until here
2
# NOTE: the loss should go below 0.0006 to make the new attempts worth it

# %%
metrics_logger.plot_metrics_by_epoch()
metrics_logger.save_metrics()
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[1], line 1
# ----> 1 metrics_logger.plot_metrics_by_epoch()
#       2 metrics_logger.save_metrics()
#
# NameError: name 'metrics_logger' is not defined

# %% [markdown]
# # Second part: MLP from input to latent space which is then plugged to the decoder
#
# For the training of this second part, there are two main options:
# - to calculate the loss as the final difference between the reconstructed output and the ground truth output -> it may be unfair because it would evaluate also the capacity of the decoder to reconstruct the field from the latent space
# - to calculate the loss on the latent space (output of this model and the output of the previously-trained encoder) -> it may be uncorrect because it would learn from the ground truth but from a latent space that is obtained from the trained encoder

# %%
# loading best autoencoder
if CONVOLUTIONAL:
    autoencoder = ConvAutoEncoder(train_dataloader.dataset.X_grid.shape).to(DEVICE)
else:
    autoencoder = AutoEncoder(HIDDEN_LAYERS_UNITS, train_dataloader.dataset.num_cells, ACTIVATION_FUNCTION).to(DEVICE)
autoencoder.load_state_dict(torch.load(BEST_MODEL_PATH))
autoencoder.eval()

bottleneck_space = min(HIDDEN_LAYERS_UNITS) # minimum of autoencoder hidden units
print(f"{bottleneck_space=}")
final_model_description = "Autoencoder description: " + MODEL_DESCRIPTION
autoencoder
# Out:
# bottleneck_space=8
# AutoEncoder(
#   (act_function): Sigmoid()
#   (encoder): Sequential(
#     (0): Linear(in_features=7168, out_features=4096, bias=True)
#     (1): Sigmoid()
#     (2): Linear(in_features=4096, out_features=2048, bias=True)
#     (3): Sigmoid()
#     (4): Linear(in_features=2048, out_features=1024, bias=True)
#     (5): Sigmoid()
#     (6): Linear(in_features=1024, out_features=512, bias=True)
#     (7): Sigmoid()
#     (8): Linear(in_features=512, out_features=256, bias=True)
#     (9): Sigmoid()
#     (10): Linear(in_features=256, out_features=128, bias=True)
#     (11): Sigmoid()
#     (12): Linear(in_features=128, out_features=64, bias=True)
#     (13): Sigmoid()
#     (14): Linear(in_features=64, out_features=32, bias=True)
#     (15): Sigmoid()
#     (16): Linear(in_features=32, out_features=16, bias=True)
#     (17): Sigmoid()
#     (18): Linear(in_features=16, out_features=8, bias=True)
#     (19): Sigmoid()
#   )
#   (decoder): Sequential(
#     (0): Linear(in_features=8, out_features=16, bias=True)
#     (1): Sigmoid()
#     (2): Linear(in_features=16, out_features=32, bias=True)
#     (3): Sigmoid()
#     (4): Linear(in_features=32, out_features=64, bias=True)
#     (5): Sigmoid()
#     (6): Linear(in_features=64, out_features=128, bias=True)
#     (7): Sigmoid()
#     (8): Linear(in_features=128, out_features=256, bias=True)
#     (9): Sigmoid()
#     (10): Linear(in_features=256, out_features=512, bias=True)
#     (11): Sigmoid()
#     (12): Linear(in_features=512, out_features=1024, bias=True)
#     (13): Sigmoid()
#     (14): Linear(in_features=1024, out_features=2048, bias=True)
#     (15): Sigmoid()
#     (16): Linear(in_features=2048, out_features=4096, bias=True)
#     (17): Sigmoid()
#     (18): Linear(in_features=4096, out_features=7168, bias=True)
#     (19): Sigmoid()
#   )
# )

# %%
# new hyperparameters
HIDDEN_LAYERS_UNITS = [6, 24, 48, 16]
ACTIVATION_FUNCTION = nn.ReLU()
EPOCHS = 500
LR = 0.001

MODEL_NAME = f"aemlp_layers{'-'.join(str(lu) for lu in HIDDEN_LAYERS_UNITS)}"
BEST_MODEL_PATH = f"saved_models/{FACTORS_FOLDER}/{MODEL_NAME}.pt"
if CONSIDER_WS:
    MODEL_NAME += "_consider_ws"
    BEST_MODEL_PATH = f"saved_models/{FACTORS_FOLDER}/{MODEL_NAME}.pt"\
        .replace("TIstep0.01_CTstep0.01", "reducedTI-CT")
print(f"Model name: {MODEL_NAME}")
print(f"Best model path: {BEST_MODEL_PATH}")

MODEL_DESCRIPTION = f"{MODEL_NAME}_{FACTORS_FOLDER}: act. func. {ACTIVATION_FUNCTION.__class__.__name__} " +\
    f"(not last layer), batch size {BATCH_SIZE}, {EPOCHS} epochs, lr={LR})"
print(f"Model description: {MODEL_DESCRIPTION}")
final_model_description += " --- MLP description: " + MODEL_DESCRIPTION

DEVICE = torch.device("cuda" if torch.cuda.is_available() else "cpu")
print(f"{DEVICE=}")
# Out:
# Model name: aemlp_layers6-24-48-16
# Best model path: saved_models/discr_factors_x2_30_y-2_2_step0.125_TIstep0.01_CTstep0.01/aemlp_layers6-24-48-16.pt
# Model description: aemlp_layers6-24-48-16_discr_factors_x2_30_y-2_2_step0.125_TIstep0.01_CTstep0.01: act. func. ReLU (not last layer), batch size 64, 500 epochs, lr=0.001)
# DEVICE=device(type='cpu')

# %%
class AE_MLP(nn.Module):
    def __init__(self, input_space, output_space) -> None:
        super(AE_MLP, self).__init__()
        layer_units = [input_space] + HIDDEN_LAYERS_UNITS
        layers = list()
        for first, second in zip(layer_units, layer_units[1:]):
            layers += [nn.Linear(first, second), ACTIVATION_FUNCTION]
        layers.append(nn.Linear(layer_units[-1], output_space)) # last layer not activated
        self.layers = nn.Sequential(*layers)
    
    def forward(self, x):
        return self.layers(x)

# %%
mlp = AE_MLP(input_space, bottleneck_space)

optimizer = torch.optim.Adam(
    (p for p in mlp.parameters() if p.requires_grad), lr=LR
)
loss_function = torch.nn.MSELoss() #TODO change ?

metrics_logger = MetricsLogger(name=MODEL_NAME)
best_vloss = 1_000_000.
for epoch in range(EPOCHS):
    '''TRAINING'''
    mlp.train(True)
    epoch_tloss = 0
    for batch in iter(train_dataloader):
        input_features, wake_field = batch[0].to(DEVICE), batch[1].to(DEVICE)
        optimizer.zero_grad()

        bottleneck_pred = mlp.forward(input_features)
        bottleneck_truth = autoencoder.encoder(wake_field)
        
        tloss = loss_function(bottleneck_pred, bottleneck_truth)
        tloss.backward()
        optimizer.step()

        epoch_tloss += tloss.item() * BATCH_SIZE

    avg_tloss = epoch_tloss / len(train_dataloader.sampler)
    metrics_logger.log_metric(epoch, 'Training loss', avg_tloss)

    '''VALIDATION'''
    if valid_dataloader:
        mlp.train(False)
        epoch_vloss = 0
        for batch in iter(valid_dataloader):
            input_features, wake_field = batch[0].to(DEVICE), batch[1].to(DEVICE)

            bottleneck_pred = mlp.forward(input_features)
            bottleneck_truth = autoencoder.encoder(wake_field)

            vloss = loss_function(bottleneck_pred, bottleneck_truth)
            epoch_vloss += vloss.item() * BATCH_SIZE

        avg_vloss = epoch_vloss / len(valid_dataloader.sampler)
        metrics_logger.log_metric(epoch, 'Validation loss', avg_vloss)
        # Track best performance, and save the model's state
        if avg_vloss < best_vloss:
            best_vloss = avg_vloss
            torch.save(mlp.state_dict(), BEST_MODEL_PATH)
# Out:
# Logging aemlp_layers6-24-48-16
# Epoch 0 ->	Training loss=0.25917653343894265	Validation loss=0.23273599754949534	epoch_time (seconds)=1
# Epoch 1 ->	Training loss=0.23219221808693627	Validation loss=0.20879075328755822	epoch_time (seconds)=1
# Epoch 2 ->	Training loss=0.20591672030362215	Validation loss=0.18124081273997053	epoch_time (seconds)=1
# Epoch 3 ->	Training loss=0.174072397405451	Validation loss=0.1468982836326457	epoch_time (seconds)=1
# Epoch 4 ->	Training loss=0.13558583693070844	Validation loss=0.10798987418228055	epoch_time (seconds)=1
# Epoch 5 ->	Training loss=0.09514374906366521	Validation loss=0.07113517701996039	epoch_time (seconds)=1
# Epoch 6 ->	Training loss=0.06031431501561945	Validation loss=0.04267980030604771	epoch_time (seconds)=1
# Epoch 7 ->	Training loss=0.034510927633805706	Validation loss=0.02236310935168533	epoch_time (seconds)=1
# Epoch 8 ->	Training loss=0.016932184262709184	Validation loss=0.009998472388486685	epoch_time (seconds)=1
# Epoch 9 ->	Training loss=0.007350236556746743	Validation loss=0.004215953431514479	epoch_time (seconds)=1
# Epoch 10 ->	Training loss=0.0030532221360640094	Validation loss=0.0017117470706471745	epoch_time (seconds)=1
# Epoch 11 ->	Training loss=0.0012488713995976882	Validation loss=0.0006900870948104384	epoch_time (seconds)=1
# Epoch 12 ->	Training loss=0.000506986877457662	Validation loss=0.00029710040445098227	epoch_time (seconds)=1
# Epoch 13 ->	Training loss=0.0002604423802007328	Validation loss=0.00020786700029828533	epoch_time (seconds)=1
# Epoch 14 ->	Training loss=0.0002090901458127932	Validation loss=0.00018676998521785558	epoch_time (seconds)=1
# Epoch 15 ->	Training loss=0.00018810151483524928	Validation loss=0.00016317474522760937	epoch_time (seconds)=1
# Epoch 16 ->	Training loss=0.00016359597783197055	Validation loss=0.00014222983467560376	epoch_time (seconds)=1
# Epoch 17 ->	Training loss=0.00014299673282287337	Validation loss=0.00012745114390431725	epoch_time (seconds)=1
# Epoch 18 ->	Training loss=0.00013137789781798016	Validation loss=0.00011556781209449961	epoch_time (seconds)=1
# Epoch 19 ->	Training loss=0.00011869180524213747	Validation loss=0.00010621521425265704	epoch_time (seconds)=1
# Epoch 20 ->	Training loss=0.0001100990404798226	Validation loss=9.795824673188769e-05	epoch_time (seconds)=1
# Epoch 21 ->	Training loss=0.00010188868099992926	Validation loss=9.045136427240712e-05	epoch_time (seconds)=1
# Epoch 22 ->	Training loss=9.36028640717268e-05	Validation loss=8.375304768451993e-05	epoch_time (seconds)=1
# Epoch 23 ->	Training loss=8.676687001504681e-05	Validation loss=7.757295362697625e-05	epoch_time (seconds)=1
# Epoch 24 ->	Training loss=8.063151924447579e-05	Validation loss=7.237920774760084e-05	epoch_time (seconds)=1
# Epoch 25 ->	Training loss=7.418782111595977e-05	Validation loss=6.699713340364628e-05	epoch_time (seconds)=1
# Epoch 26 ->	Training loss=7.007147693498569e-05	Validation loss=6.22350113720905e-05	epoch_time (seconds)=1
# Epoch 27 ->	Training loss=6.590293762697414e-05	Validation loss=5.7919777565352294e-05	epoch_time (seconds)=1
# Epoch 28 ->	Training loss=5.988266065039418e-05	Validation loss=5.3966516218153955e-05	epoch_time (seconds)=1
# Epoch 29 ->	Training loss=5.5488383990119806e-05	Validation loss=4.988928391997303e-05	epoch_time (seconds)=1
# Epoch 30 ->	Training loss=5.269574213095687e-05	Validation loss=4.660013308227988e-05	epoch_time (seconds)=1
# Epoch 31 ->	Training loss=4.832970867441459e-05	Validation loss=4.3008397015170284e-05	epoch_time (seconds)=1
# Epoch 32 ->	Training loss=4.4580107893456115e-05	Validation loss=3.9983825954776375e-05	epoch_time (seconds)=1
# Epoch 33 ->	Training loss=4.166516602378e-05	Validation loss=3.7054484565482006e-05	epoch_time (seconds)=1
# Epoch 34 ->	Training loss=3.898336467417804e-05	Validation loss=3.437528788742627e-05	epoch_time (seconds)=1
# Epoch 35 ->	Training loss=3.5611177286641166e-05	Validation loss=3.194008739838689e-05	epoch_time (seconds)=1
# Epoch 36 ->	Training loss=3.320693228901787e-05	Validation loss=2.9563999862080404e-05	epoch_time (seconds)=1
# Epoch 37 ->	Training loss=3.093781669370153e-05	Validation loss=2.732321844141213e-05	epoch_time (seconds)=1
# Epoch 38 ->	Training loss=2.8967341746796263e-05	Validation loss=2.5418220154408897e-05	epoch_time (seconds)=1
# Epoch 39 ->	Training loss=2.640250011939894e-05	Validation loss=2.3432219898478585e-05	epoch_time (seconds)=1
# Epoch 40 ->	Training loss=2.4330992336300286e-05	Validation loss=2.1700584546587667e-05	epoch_time (seconds)=1
# Epoch 41 ->	Training loss=2.2883510894396088e-05	Validation loss=2.00120498345274e-05	epoch_time (seconds)=1
# Epoch 42 ->	Training loss=2.08334561268037e-05	Validation loss=1.8462613904675156e-05	epoch_time (seconds)=1
# Epoch 43 ->	Training loss=1.9114359112625772e-05	Validation loss=1.7049264347886448e-05	epoch_time (seconds)=1
# Epoch 44 ->	Training loss=1.772607486187057e-05	Validation loss=1.5749384356975e-05	epoch_time (seconds)=1
# Epoch 45 ->	Training loss=1.6582287974994292e-05	Validation loss=1.458452551000931e-05	epoch_time (seconds)=1
# Epoch 46 ->	Training loss=1.543987489474768e-05	Validation loss=1.3404693172504165e-05	epoch_time (seconds)=1
# Epoch 47 ->	Training loss=1.398583143864843e-05	Validation loss=1.2544678214659787e-05	epoch_time (seconds)=1
# Epoch 48 ->	Training loss=1.3075368478894233e-05	Validation loss=1.1376749951195736e-05	epoch_time (seconds)=1
# Epoch 49 ->	Training loss=1.1897440893914212e-05	Validation loss=1.049767883916773e-05	epoch_time (seconds)=1
# Epoch 50 ->	Training loss=1.0878258300098505e-05	Validation loss=9.676406596735212e-06	epoch_time (seconds)=1
# Epoch 51 ->	Training loss=1.019924773241986e-05	Validation loss=8.931904539512182e-06	epoch_time (seconds)=1
# Epoch 52 ->	Training loss=9.308664488013495e-06	Validation loss=8.203449864403246e-06	epoch_time (seconds)=1
# Epoch 53 ->	Training loss=8.521906301294537e-06	Validation loss=7.570032753420543e-06	epoch_time (seconds)=1
# Epoch 54 ->	Training loss=7.969322032295168e-06	Validation loss=6.9874042452758425e-06	epoch_time (seconds)=1
# Epoch 55 ->	Training loss=7.291349095546386e-06	Validation loss=6.458450781950808e-06	epoch_time (seconds)=1
# Epoch 56 ->	Training loss=6.711148413490843e-06	Validation loss=5.955760882768248e-06	epoch_time (seconds)=1
# Epoch 57 ->	Training loss=6.222656599923291e-06	Validation loss=5.5042529979038126e-06	epoch_time (seconds)=1
# Epoch 58 ->	Training loss=5.77270185617222e-06	Validation loss=5.098949128657764e-06	epoch_time (seconds)=1
# Epoch 59 ->	Training loss=5.362385365350002e-06	Validation loss=4.7119969273599224e-06	epoch_time (seconds)=1
# Epoch 60 ->	Training loss=4.942783376794647e-06	Validation loss=4.383654638066286e-06	epoch_time (seconds)=1
# Epoch 61 ->	Training loss=4.646793716925789e-06	Validation loss=4.051040029384612e-06	epoch_time (seconds)=1
# Epoch 62 ->	Training loss=4.290828259069134e-06	Validation loss=3.774042271282987e-06	epoch_time (seconds)=1
# Epoch 63 ->	Training loss=3.9860186304643075e-06	Validation loss=3.4992522357598594e-06	epoch_time (seconds)=1
# Epoch 64 ->	Training loss=3.664404503069818e-06	Validation loss=3.2592447953998627e-06	epoch_time (seconds)=1
# Epoch 65 ->	Training loss=3.416551255875013e-06	Validation loss=3.0418961675496344e-06	epoch_time (seconds)=1
# Epoch 66 ->	Training loss=3.221506459257481e-06	Validation loss=2.8413701086646375e-06	epoch_time (seconds)=1
# Epoch 67 ->	Training loss=3.050683299079537e-06	Validation loss=2.6712220061645606e-06	epoch_time (seconds)=1
# Epoch 68 ->	Training loss=2.813866436058147e-06	Validation loss=2.497261672451375e-06	epoch_time (seconds)=1
# Epoch 69 ->	Training loss=2.624905213120986e-06	Validation loss=2.34404585854966e-06	epoch_time (seconds)=1
# Epoch 70 ->	Training loss=2.4570148459381677e-06	Validation loss=2.2107379215260423e-06	epoch_time (seconds)=1
# Epoch 71 ->	Training loss=2.299205132823607e-06	Validation loss=2.083996741422192e-06	epoch_time (seconds)=1
# Epoch 72 ->	Training loss=2.2130356625315142e-06	Validation loss=1.9685514213413187e-06	epoch_time (seconds)=1
# Epoch 73 ->	Training loss=2.073189508254555e-06	Validation loss=1.869358786494581e-06	epoch_time (seconds)=1
# Epoch 74 ->	Training loss=1.9744318110910666e-06	Validation loss=1.769805207207903e-06	epoch_time (seconds)=1
# Epoch 75 ->	Training loss=1.8837455321441998e-06	Validation loss=1.6931162478969148e-06	epoch_time (seconds)=1
# Epoch 76 ->	Training loss=1.7776849166363139e-06	Validation loss=1.6024965783494369e-06	epoch_time (seconds)=1
# Epoch 77 ->	Training loss=1.7112154323099688e-06	Validation loss=1.535714077560798e-06	epoch_time (seconds)=1
# Epoch 78 ->	Training loss=1.6200568246528168e-06	Validation loss=1.461730021925539e-06	epoch_time (seconds)=1
# Epoch 79 ->	Training loss=1.570176431083713e-06	Validation loss=1.408133434525095e-06	epoch_time (seconds)=1
# Epoch 80 ->	Training loss=1.4936782297974621e-06	Validation loss=1.3419829523378855e-06	epoch_time (seconds)=1
# Epoch 81 ->	Training loss=1.4390463051809506e-06	Validation loss=1.2879335057201524e-06	epoch_time (seconds)=1
# Epoch 82 ->	Training loss=1.3697799559767273e-06	Validation loss=1.2378095051198504e-06	epoch_time (seconds)=1
# Epoch 83 ->	Training loss=1.3236793430141089e-06	Validation loss=1.1923088884105478e-06	epoch_time (seconds)=1
# Epoch 84 ->	Training loss=1.281246407994662e-06	Validation loss=1.1497718957758953e-06	epoch_time (seconds)=1
# Epoch 85 ->	Training loss=1.239682579497722e-06	Validation loss=1.108515201431485e-06	epoch_time (seconds)=1
# Epoch 86 ->	Training loss=1.1859052359465172e-06	Validation loss=1.0718860432450654e-06	epoch_time (seconds)=1
# Epoch 87 ->	Training loss=1.142398250522092e-06	Validation loss=1.035095033415171e-06	epoch_time (seconds)=1
# Epoch 88 ->	Training loss=1.1071448600639335e-06	Validation loss=1.0012789068653926e-06	epoch_time (seconds)=1
# Epoch 89 ->	Training loss=1.079777582410977e-06	Validation loss=9.71965933752229e-07	epoch_time (seconds)=1
# Epoch 90 ->	Training loss=1.0466336971148848e-06	Validation loss=9.421121834499634e-07	epoch_time (seconds)=1
# Epoch 91 ->	Training loss=1.007970197613097e-06	Validation loss=9.127814723655975e-07	epoch_time (seconds)=1
# Epoch 92 ->	Training loss=9.813602280866525e-07	Validation loss=8.86380464931869e-07	epoch_time (seconds)=1
# Epoch 93 ->	Training loss=9.5456836623436e-07	Validation loss=8.60649878694242e-07	epoch_time (seconds)=1
# Epoch 94 ->	Training loss=9.332041835560548e-07	Validation loss=8.379952283937669e-07	epoch_time (seconds)=1
# Epoch 95 ->	Training loss=9.17782037339004e-07	Validation loss=8.149517518222356e-07	epoch_time (seconds)=1
# Epoch 96 ->	Training loss=8.813422623048113e-07	Validation loss=7.963698852289561e-07	epoch_time (seconds)=1
# Epoch 97 ->	Training loss=8.589178006249396e-07	Validation loss=7.736218260942455e-07	epoch_time (seconds)=1
# Epoch 98 ->	Training loss=8.38177399021912e-07	Validation loss=7.536425381777403e-07	epoch_time (seconds)=1
# Epoch 99 ->	Training loss=8.217297991822389e-07	Validation loss=7.349286694441176e-07	epoch_time (seconds)=1
# Epoch 100 ->	Training loss=7.936027792642232e-07	Validation loss=7.166635587280732e-07	epoch_time (seconds)=1
# Epoch 101 ->	Training loss=7.722713582387024e-07	Validation loss=7.001176749982275e-07	epoch_time (seconds)=1
# Epoch 102 ->	Training loss=7.636498445539143e-07	Validation loss=6.847196133512286e-07	epoch_time (seconds)=1
# Epoch 103 ->	Training loss=7.416962630073116e-07	Validation loss=6.694837246648389e-07	epoch_time (seconds)=1
# Epoch 104 ->	Training loss=7.349259910618209e-07	Validation loss=6.579332644234104e-07	epoch_time (seconds)=1
# Epoch 105 ->	Training loss=7.235200411576609e-07	Validation loss=6.446976255139579e-07	epoch_time (seconds)=1
# Epoch 106 ->	Training loss=6.950889457419345e-07	Validation loss=6.321114792542023e-07	epoch_time (seconds)=1
# Epoch 107 ->	Training loss=6.805702154947953e-07	Validation loss=6.174974567227945e-07	epoch_time (seconds)=1
# Epoch 108 ->	Training loss=6.750892630820586e-07	Validation loss=6.064769790416745e-07	epoch_time (seconds)=1
# Epoch 109 ->	Training loss=6.620606026527557e-07	Validation loss=5.962488567601218e-07	epoch_time (seconds)=1
# Epoch 110 ->	Training loss=6.483230985891581e-07	Validation loss=5.858826824472581e-07	epoch_time (seconds)=1
# Epoch 111 ->	Training loss=6.439996518152343e-07	Validation loss=5.755480491846904e-07	epoch_time (seconds)=1
# Epoch 112 ->	Training loss=6.331711219073358e-07	Validation loss=5.660318481730101e-07	epoch_time (seconds)=1
# Epoch 113 ->	Training loss=6.130863766884431e-07	Validation loss=5.579680817289226e-07	epoch_time (seconds)=1
# Epoch 114 ->	Training loss=6.017797336839563e-07	Validation loss=5.492385699083271e-07	epoch_time (seconds)=1
# Epoch 115 ->	Training loss=5.932508429395966e-07	Validation loss=5.430208644012614e-07	epoch_time (seconds)=1
# Epoch 116 ->	Training loss=5.942016022428024e-07	Validation loss=5.367595230331153e-07	epoch_time (seconds)=1
# Epoch 117 ->	Training loss=5.834505282109603e-07	Validation loss=5.270705128309855e-07	epoch_time (seconds)=1
# Epoch 118 ->	Training loss=5.722109133123674e-07	Validation loss=5.205524320676576e-07	epoch_time (seconds)=1
# Epoch 119 ->	Training loss=5.674404019373469e-07	Validation loss=5.149970416168347e-07	epoch_time (seconds)=1
# Epoch 120 ->	Training loss=5.53724474395329e-07	Validation loss=5.102295234910739e-07	epoch_time (seconds)=1
# Epoch 121 ->	Training loss=5.545863843343052e-07	Validation loss=5.023369494835002e-07	epoch_time (seconds)=1
# Epoch 122 ->	Training loss=5.420249991319989e-07	Validation loss=4.96689544832305e-07	epoch_time (seconds)=1
# Epoch 123 ->	Training loss=5.460900402712551e-07	Validation loss=4.931115605890091e-07	epoch_time (seconds)=1
# Epoch 124 ->	Training loss=5.328420262561519e-07	Validation loss=4.91371310152611e-07	epoch_time (seconds)=1
# Epoch 125 ->	Training loss=5.210965272536586e-07	Validation loss=4.850512167824988e-07	epoch_time (seconds)=1
# Epoch 126 ->	Training loss=5.273789098613303e-07	Validation loss=4.774508764153861e-07	epoch_time (seconds)=1
# Epoch 127 ->	Training loss=5.19185093501371e-07	Validation loss=4.767265152916463e-07	epoch_time (seconds)=1
# Epoch 128 ->	Training loss=5.240229107915763e-07	Validation loss=4.7271721002136747e-07	epoch_time (seconds)=1
# Epoch 129 ->	Training loss=5.069442902987992e-07	Validation loss=4.6642137835451594e-07	epoch_time (seconds)=1
# Epoch 130 ->	Training loss=5.044348356684416e-07	Validation loss=4.609788481745528e-07	epoch_time (seconds)=1
# Epoch 131 ->	Training loss=4.969212353568186e-07	Validation loss=4.579919254441994e-07	epoch_time (seconds)=1
# Epoch 132 ->	Training loss=4.943344703695567e-07	Validation loss=4.5303081080747005e-07	epoch_time (seconds)=1
# Epoch 133 ->	Training loss=4.907862669576637e-07	Validation loss=4.478918166320644e-07	epoch_time (seconds)=1
# Epoch 134 ->	Training loss=4.8097263391934e-07	Validation loss=4.4415189872129955e-07	epoch_time (seconds)=1
# Epoch 135 ->	Training loss=4.777281488217837e-07	Validation loss=4.412060178149642e-07	epoch_time (seconds)=1
# Epoch 136 ->	Training loss=4.7330924148396164e-07	Validation loss=4.3724229641913825e-07	epoch_time (seconds)=1
# Epoch 137 ->	Training loss=4.7296954355922276e-07	Validation loss=4.363126902474432e-07	epoch_time (seconds)=1
# Epoch 138 ->	Training loss=4.6672108675755393e-07	Validation loss=4.3090234646358183e-07	epoch_time (seconds)=1
# Epoch 139 ->	Training loss=4.7071265064666724e-07	Validation loss=4.307259982654258e-07	epoch_time (seconds)=1
# Epoch 140 ->	Training loss=4.6247738117182796e-07	Validation loss=4.2897024619796526e-07	epoch_time (seconds)=1
# Epoch 141 ->	Training loss=4.6276837978935377e-07	Validation loss=4.22425080117515e-07	epoch_time (seconds)=1
# Epoch 142 ->	Training loss=4.650223027883013e-07	Validation loss=4.2119839230316593e-07	epoch_time (seconds)=1
# Epoch 143 ->	Training loss=4.6137054927054453e-07	Validation loss=4.195483095104436e-07	epoch_time (seconds)=1
# Epoch 144 ->	Training loss=4.535057186413641e-07	Validation loss=4.139459796426297e-07	epoch_time (seconds)=1
# Epoch 145 ->	Training loss=4.4709557021798737e-07	Validation loss=4.1258610926549706e-07	epoch_time (seconds)=1
# Epoch 146 ->	Training loss=4.4388566245536573e-07	Validation loss=4.0543720998182336e-07	epoch_time (seconds)=1
# Epoch 147 ->	Training loss=4.370450055417181e-07	Validation loss=4.0250284994427426e-07	epoch_time (seconds)=1
# Epoch 148 ->	Training loss=4.377081826202233e-07	Validation loss=4.00057027301887e-07	epoch_time (seconds)=1
# Epoch 149 ->	Training loss=4.331502416541546e-07	Validation loss=3.970066306538452e-07	epoch_time (seconds)=1
# Epoch 150 ->	Training loss=4.282560026199049e-07	Validation loss=3.9707318532948746e-07	epoch_time (seconds)=1
# Epoch 151 ->	Training loss=4.261135869786482e-07	Validation loss=3.916233310621284e-07	epoch_time (seconds)=1
# Epoch 152 ->	Training loss=4.2314144428184424e-07	Validation loss=3.8922598347051927e-07	epoch_time (seconds)=1
# Epoch 153 ->	Training loss=4.1799037386557426e-07	Validation loss=3.862386921970955e-07	epoch_time (seconds)=1
# Epoch 154 ->	Training loss=4.1841230664762074e-07	Validation loss=3.8562073268904493e-07	epoch_time (seconds)=1
# Epoch 155 ->	Training loss=4.1382611842974174e-07	Validation loss=3.834215159761511e-07	epoch_time (seconds)=1
# Epoch 156 ->	Training loss=4.1146425329233434e-07	Validation loss=3.7978131043227963e-07	epoch_time (seconds)=1
# Epoch 157 ->	Training loss=4.0871744700284166e-07	Validation loss=3.752658921489145e-07	epoch_time (seconds)=1
# Epoch 158 ->	Training loss=4.034054423259063e-07	Validation loss=3.760084637291787e-07	epoch_time (seconds)=1
# Epoch 159 ->	Training loss=4.0592131633523175e-07	Validation loss=3.7084947174244344e-07	epoch_time (seconds)=1
# Epoch 160 ->	Training loss=4.0129959829342126e-07	Validation loss=3.6920061264377267e-07	epoch_time (seconds)=1
# Epoch 161 ->	Training loss=3.9657026883849706e-07	Validation loss=3.660905764173204e-07	epoch_time (seconds)=1
# Epoch 162 ->	Training loss=3.887558242157948e-07	Validation loss=3.659350396045744e-07	epoch_time (seconds)=1
# Epoch 163 ->	Training loss=3.8549517657057466e-07	Validation loss=3.6206206792903345e-07	epoch_time (seconds)=1
# Epoch 164 ->	Training loss=3.8951335062103516e-07	Validation loss=3.578962649450846e-07	epoch_time (seconds)=1
# Epoch 165 ->	Training loss=3.814766717947681e-07	Validation loss=3.5575506710234064e-07	epoch_time (seconds)=1
# Epoch 166 ->	Training loss=3.7471274646866895e-07	Validation loss=3.532043364492277e-07	epoch_time (seconds)=1
# Epoch 167 ->	Training loss=3.7829477977621454e-07	Validation loss=3.507934761389451e-07	epoch_time (seconds)=1
# Epoch 168 ->	Training loss=3.7771350682967086e-07	Validation loss=3.484450754055519e-07	epoch_time (seconds)=1
# Epoch 169 ->	Training loss=3.695879654101604e-07	Validation loss=3.4594006804508584e-07	epoch_time (seconds)=1
# Epoch 170 ->	Training loss=3.6854344216408207e-07	Validation loss=3.433066840952057e-07	epoch_time (seconds)=1
# Epoch 171 ->	Training loss=3.6936215275835076e-07	Validation loss=3.4048016651631884e-07	epoch_time (seconds)=1
# Epoch 172 ->	Training loss=3.6947299205084245e-07	Validation loss=3.384110958966924e-07	epoch_time (seconds)=1
# Epoch 173 ->	Training loss=3.58968126502904e-07	Validation loss=3.36491756689097e-07	epoch_time (seconds)=1
# Epoch 174 ->	Training loss=3.581293838744221e-07	Validation loss=3.342454053285483e-07	epoch_time (seconds)=1
# Epoch 175 ->	Training loss=3.6127363934858955e-07	Validation loss=3.31435660413692e-07	epoch_time (seconds)=1
# Epoch 176 ->	Training loss=3.514522243428721e-07	Validation loss=3.3377020722667265e-07	epoch_time (seconds)=1
# Epoch 177 ->	Training loss=3.51417643700684e-07	Validation loss=3.2728155262776224e-07	epoch_time (seconds)=1
# Epoch 178 ->	Training loss=3.495241220331412e-07	Validation loss=3.290542739456858e-07	epoch_time (seconds)=1
# Epoch 179 ->	Training loss=3.490333983791061e-07	Validation loss=3.288480987275592e-07	epoch_time (seconds)=1
# Epoch 180 ->	Training loss=3.485925712580369e-07	Validation loss=3.211276391920596e-07	epoch_time (seconds)=1
# Epoch 181 ->	Training loss=3.449756232757037e-07	Validation loss=3.1882269581022775e-07	epoch_time (seconds)=1
# Epoch 182 ->	Training loss=3.389294248666953e-07	Validation loss=3.155145045271887e-07	epoch_time (seconds)=1
# Epoch 183 ->	Training loss=3.3427655580453577e-07	Validation loss=3.130747469151841e-07	epoch_time (seconds)=1
# Epoch 184 ->	Training loss=3.3690393055704504e-07	Validation loss=3.107842807683324e-07	epoch_time (seconds)=1
# Epoch 185 ->	Training loss=3.324371904124167e-07	Validation loss=3.0855004986518885e-07	epoch_time (seconds)=1
# Epoch 186 ->	Training loss=3.309021187967367e-07	Validation loss=3.0707512840828193e-07	epoch_time (seconds)=1
# Epoch 187 ->	Training loss=3.248794514961033e-07	Validation loss=3.0413782680501167e-07	epoch_time (seconds)=1
# Epoch 188 ->	Training loss=3.2163499285657467e-07	Validation loss=3.026514820946505e-07	epoch_time (seconds)=1
# Epoch 189 ->	Training loss=3.2494451509344136e-07	Validation loss=3.0305040104535944e-07	epoch_time (seconds)=1
# Epoch 190 ->	Training loss=3.2436863958454604e-07	Validation loss=2.9693859382492765e-07	epoch_time (seconds)=1
# Epoch 191 ->	Training loss=3.213494379782457e-07	Validation loss=2.9461537332795355e-07	epoch_time (seconds)=1
# Epoch 192 ->	Training loss=3.170987144006755e-07	Validation loss=2.922517308191272e-07	epoch_time (seconds)=1
# Epoch 193 ->	Training loss=3.1216648825317284e-07	Validation loss=2.9009522849665696e-07	epoch_time (seconds)=1
# Epoch 194 ->	Training loss=3.104413587028499e-07	Validation loss=2.8819792470746525e-07	epoch_time (seconds)=1
# Epoch 195 ->	Training loss=3.1815974745603107e-07	Validation loss=2.892058371301952e-07	epoch_time (seconds)=1
# Epoch 196 ->	Training loss=3.064408371177375e-07	Validation loss=2.83357540351774e-07	epoch_time (seconds)=1
# Epoch 197 ->	Training loss=3.0082457008327104e-07	Validation loss=2.811362492421321e-07	epoch_time (seconds)=1
# Epoch 198 ->	Training loss=3.005061725244476e-07	Validation loss=2.7873260693036033e-07	epoch_time (seconds)=1
# Epoch 199 ->	Training loss=2.917239246678285e-07	Validation loss=2.8069768908924583e-07	epoch_time (seconds)=1
# Epoch 200 ->	Training loss=2.969785501508423e-07	Validation loss=2.8007090194653346e-07	epoch_time (seconds)=1
# Epoch 201 ->	Training loss=2.964239303599408e-07	Validation loss=2.752202847021305e-07	epoch_time (seconds)=1
# Epoch 202 ->	Training loss=2.878059736262499e-07	Validation loss=2.7114094811385375e-07	epoch_time (seconds)=1
# Epoch 203 ->	Training loss=2.889793772324496e-07	Validation loss=2.692763413935654e-07	epoch_time (seconds)=1
# Epoch 204 ->	Training loss=2.904212504455989e-07	Validation loss=2.688303310668128e-07	epoch_time (seconds)=1
# Epoch 205 ->	Training loss=2.8492127140370113e-07	Validation loss=2.6548236842782044e-07	epoch_time (seconds)=1
# Epoch 206 ->	Training loss=2.819721918389074e-07	Validation loss=2.635408755110198e-07	epoch_time (seconds)=1
# Epoch 207 ->	Training loss=2.8159191887508233e-07	Validation loss=2.6214194363572416e-07	epoch_time (seconds)=1
# Epoch 208 ->	Training loss=2.763680574637626e-07	Validation loss=2.564193886236189e-07	epoch_time (seconds)=1
# Epoch 209 ->	Training loss=2.7310536593590355e-07	Validation loss=2.5691306020110783e-07	epoch_time (seconds)=1
# Epoch 210 ->	Training loss=2.785839288580147e-07	Validation loss=2.5460534314288733e-07	epoch_time (seconds)=1
# Epoch 211 ->	Training loss=2.775243791058363e-07	Validation loss=2.590015061083611e-07	epoch_time (seconds)=1
# Epoch 212 ->	Training loss=2.6973310675450853e-07	Validation loss=2.4824770786513876e-07	epoch_time (seconds)=1
# Epoch 213 ->	Training loss=2.6504437548944474e-07	Validation loss=2.5231275442746894e-07	epoch_time (seconds)=1
# Epoch 214 ->	Training loss=2.623790665397378e-07	Validation loss=2.4410977304164e-07	epoch_time (seconds)=1
# Epoch 215 ->	Training loss=2.58323465955486e-07	Validation loss=2.419843118298316e-07	epoch_time (seconds)=1
# Epoch 216 ->	Training loss=2.6003302495651454e-07	Validation loss=2.4118358840112377e-07	epoch_time (seconds)=1
# Epoch 217 ->	Training loss=2.5499270122963935e-07	Validation loss=2.3762913114754251e-07	epoch_time (seconds)=1
# Epoch 218 ->	Training loss=2.543973410369786e-07	Validation loss=2.354765424768076e-07	epoch_time (seconds)=1
# Epoch 219 ->	Training loss=2.567747535729061e-07	Validation loss=2.4043130635494303e-07	epoch_time (seconds)=1
# Epoch 220 ->	Training loss=2.544572585479314e-07	Validation loss=2.3651322283834848e-07	epoch_time (seconds)=1
# Epoch 221 ->	Training loss=2.5365758781183766e-07	Validation loss=2.3471510085864398e-07	epoch_time (seconds)=1
# Epoch 222 ->	Training loss=2.50318048942559e-07	Validation loss=2.3509760314753418e-07	epoch_time (seconds)=1
# Epoch 223 ->	Training loss=2.462582696435592e-07	Validation loss=2.3337082351396665e-07	epoch_time (seconds)=1
# Epoch 224 ->	Training loss=2.499703606934583e-07	Validation loss=2.2742704414040925e-07	epoch_time (seconds)=1
# Epoch 225 ->	Training loss=2.3845226017080924e-07	Validation loss=2.2516692528968983e-07	epoch_time (seconds)=1
# Epoch 226 ->	Training loss=2.4255809793513353e-07	Validation loss=2.1826660672530982e-07	epoch_time (seconds)=1
# Epoch 227 ->	Training loss=2.3407724835454826e-07	Validation loss=2.166660871005672e-07	epoch_time (seconds)=1
# Epoch 228 ->	Training loss=2.3424785302433355e-07	Validation loss=2.1424815860419296e-07	epoch_time (seconds)=1
# Epoch 229 ->	Training loss=2.298216184664687e-07	Validation loss=2.1535199334297577e-07	epoch_time (seconds)=1
# Epoch 230 ->	Training loss=2.259243361053946e-07	Validation loss=2.0989429448609767e-07	epoch_time (seconds)=1
# Epoch 231 ->	Training loss=2.2526064805622974e-07	Validation loss=2.0926370079736138e-07	epoch_time (seconds)=1
# Epoch 232 ->	Training loss=2.2235817596083506e-07	Validation loss=2.0928751238548019e-07	epoch_time (seconds)=1
# Epoch 233 ->	Training loss=2.2308234540766782e-07	Validation loss=2.0890999796889976e-07	epoch_time (seconds)=1
# Epoch 234 ->	Training loss=2.201771216773936e-07	Validation loss=2.037664585795994e-07	epoch_time (seconds)=1
# Epoch 235 ->	Training loss=2.1385842211946675e-07	Validation loss=2.0040620996646427e-07	epoch_time (seconds)=1
# Epoch 236 ->	Training loss=2.168384592302821e-07	Validation loss=2.004290058580155e-07	epoch_time (seconds)=1
# Epoch 237 ->	Training loss=2.217816141968466e-07	Validation loss=1.964976180721543e-07	epoch_time (seconds)=1
# Epoch 238 ->	Training loss=2.0796186370055445e-07	Validation loss=1.95782672647663e-07	epoch_time (seconds)=1
# Epoch 239 ->	Training loss=2.0820124435968781e-07	Validation loss=1.9665966370350518e-07	epoch_time (seconds)=1
# Epoch 240 ->	Training loss=2.059827833859758e-07	Validation loss=1.9029170684718892e-07	epoch_time (seconds)=1
# Epoch 241 ->	Training loss=1.9979236722892066e-07	Validation loss=1.921382179558429e-07	epoch_time (seconds)=1
# Epoch 242 ->	Training loss=2.0155015259991738e-07	Validation loss=1.8562725006247673e-07	epoch_time (seconds)=1
# Epoch 243 ->	Training loss=1.9742837056665766e-07	Validation loss=1.8578952052543715e-07	epoch_time (seconds)=1
# Epoch 244 ->	Training loss=1.9591702518730678e-07	Validation loss=1.8220043423284072e-07	epoch_time (seconds)=1
# Epoch 245 ->	Training loss=1.951309307266704e-07	Validation loss=1.8005586041355222e-07	epoch_time (seconds)=1
# Epoch 246 ->	Training loss=1.9013435865583067e-07	Validation loss=1.7829286165048096e-07	epoch_time (seconds)=1
# Epoch 247 ->	Training loss=1.8901850787435912e-07	Validation loss=1.7676732743481428e-07	epoch_time (seconds)=1
# Epoch 248 ->	Training loss=1.8863306071249428e-07	Validation loss=1.7485283396979765e-07	epoch_time (seconds)=1
# Epoch 249 ->	Training loss=1.868735258044167e-07	Validation loss=1.739879493617528e-07	epoch_time (seconds)=1
# Epoch 250 ->	Training loss=1.8311211533728055e-07	Validation loss=1.7125666909688442e-07	epoch_time (seconds)=1
# Epoch 251 ->	Training loss=1.8576202902212653e-07	Validation loss=1.7030530459197275e-07	epoch_time (seconds)=1
# Epoch 252 ->	Training loss=1.786238863132894e-07	Validation loss=1.6712166386315172e-07	epoch_time (seconds)=1
# Epoch 253 ->	Training loss=1.7696695729021236e-07	Validation loss=1.6556085932996957e-07	epoch_time (seconds)=1
# Epoch 254 ->	Training loss=1.7319059638380582e-07	Validation loss=1.630619009566256e-07	epoch_time (seconds)=1
# Epoch 255 ->	Training loss=1.7465725580801848e-07	Validation loss=1.6806918284369513e-07	epoch_time (seconds)=1
# Epoch 256 ->	Training loss=1.7601500572213394e-07	Validation loss=1.6153934457348747e-07	epoch_time (seconds)=1
# Epoch 257 ->	Training loss=1.7393074978661553e-07	Validation loss=1.5882901279611863e-07	epoch_time (seconds)=1
# Epoch 258 ->	Training loss=1.7138426880013537e-07	Validation loss=1.5896888048390234e-07	epoch_time (seconds)=1
# Epoch 259 ->	Training loss=1.6644290636494672e-07	Validation loss=1.5818251707268986e-07	epoch_time (seconds)=1
# Epoch 260 ->	Training loss=1.645522429912076e-07	Validation loss=1.5452139196438015e-07	epoch_time (seconds)=1
# Epoch 261 ->	Training loss=1.6121886636194012e-07	Validation loss=1.5365388021592532e-07	epoch_time (seconds)=1
# Epoch 262 ->	Training loss=1.6017406530657107e-07	Validation loss=1.503741865653526e-07	epoch_time (seconds)=1
# Epoch 263 ->	Training loss=1.594908487525324e-07	Validation loss=1.470750840718826e-07	epoch_time (seconds)=1
# Epoch 264 ->	Training loss=1.5840847647103312e-07	Validation loss=1.459007701595742e-07	epoch_time (seconds)=1
# Epoch 265 ->	Training loss=1.5634970623068512e-07	Validation loss=1.4502888583174692e-07	epoch_time (seconds)=1
# Epoch 266 ->	Training loss=1.525391218654642e-07	Validation loss=1.4199225187219568e-07	epoch_time (seconds)=1
# Epoch 267 ->	Training loss=1.5109773316494697e-07	Validation loss=1.4033012703067974e-07	epoch_time (seconds)=1
# Epoch 268 ->	Training loss=1.492844826729693e-07	Validation loss=1.4009983206955249e-07	epoch_time (seconds)=1
# Epoch 269 ->	Training loss=1.4748247518913227e-07	Validation loss=1.3695114779783926e-07	epoch_time (seconds)=1
# Epoch 270 ->	Training loss=1.445660869979871e-07	Validation loss=1.3520309694737893e-07	epoch_time (seconds)=1
# Epoch 271 ->	Training loss=1.4212744314466942e-07	Validation loss=1.338607731521287e-07	epoch_time (seconds)=1
# Epoch 272 ->	Training loss=1.4083068890613505e-07	Validation loss=1.3165334522731744e-07	epoch_time (seconds)=1
# Epoch 273 ->	Training loss=1.3843269202466631e-07	Validation loss=1.301626395745968e-07	epoch_time (seconds)=1
# Epoch 274 ->	Training loss=1.3770953211695252e-07	Validation loss=1.293515143510184e-07	epoch_time (seconds)=1
# Epoch 275 ->	Training loss=1.3714908246501263e-07	Validation loss=1.308063510579407e-07	epoch_time (seconds)=1
# Epoch 276 ->	Training loss=1.3812787818262058e-07	Validation loss=1.2730539395459074e-07	epoch_time (seconds)=1
# Epoch 277 ->	Training loss=1.3316082004166673e-07	Validation loss=1.2474998855520104e-07	epoch_time (seconds)=1
# Epoch 278 ->	Training loss=1.3033122575672513e-07	Validation loss=1.2230880405334104e-07	epoch_time (seconds)=1
# Epoch 279 ->	Training loss=1.3051258892201904e-07	Validation loss=1.2104933511244165e-07	epoch_time (seconds)=1
# Epoch 280 ->	Training loss=1.300553379802626e-07	Validation loss=1.243280743019907e-07	epoch_time (seconds)=1
# Epoch 281 ->	Training loss=1.3075085420992267e-07	Validation loss=1.2521899779983767e-07	epoch_time (seconds)=1
# Epoch 282 ->	Training loss=1.3045522791799159e-07	Validation loss=1.1663294763984708e-07	epoch_time (seconds)=1
# Epoch 283 ->	Training loss=1.2263084747907917e-07	Validation loss=1.1510691444488222e-07	epoch_time (seconds)=1
# Epoch 284 ->	Training loss=1.206863039855803e-07	Validation loss=1.1332866899171694e-07	epoch_time (seconds)=1
# Epoch 285 ->	Training loss=1.1924196604178923e-07	Validation loss=1.1249073813475961e-07	epoch_time (seconds)=1
# Epoch 286 ->	Training loss=1.1800218751225408e-07	Validation loss=1.1208832299603244e-07	epoch_time (seconds)=1
# Epoch 287 ->	Training loss=1.1675649892078417e-07	Validation loss=1.0971472332791298e-07	epoch_time (seconds)=1
# Epoch 288 ->	Training loss=1.1514142236344263e-07	Validation loss=1.0840735197895545e-07	epoch_time (seconds)=1
# Epoch 289 ->	Training loss=1.1308001293483275e-07	Validation loss=1.0688447377026971e-07	epoch_time (seconds)=1
# Epoch 290 ->	Training loss=1.1124143632266417e-07	Validation loss=1.0532668028594434e-07	epoch_time (seconds)=1
# Epoch 291 ->	Training loss=1.1124299073179083e-07	Validation loss=1.0362275506793493e-07	epoch_time (seconds)=1
# Epoch 292 ->	Training loss=1.0985181688738522e-07	Validation loss=1.0219428235280287e-07	epoch_time (seconds)=1
# Epoch 293 ->	Training loss=1.0792359220927624e-07	Validation loss=1.0143066512162997e-07	epoch_time (seconds)=1
# Epoch 294 ->	Training loss=1.0685322608465371e-07	Validation loss=9.975400079276358e-08	epoch_time (seconds)=1
# Epoch 295 ->	Training loss=1.0514454929348589e-07	Validation loss=9.832599779492627e-08	epoch_time (seconds)=1
# Epoch 296 ->	Training loss=1.0520363999107345e-07	Validation loss=9.700953867322598e-08	epoch_time (seconds)=1
# Epoch 297 ->	Training loss=1.0372847844502592e-07	Validation loss=9.740386484516206e-08	epoch_time (seconds)=1
# Epoch 298 ->	Training loss=1.02555312134262e-07	Validation loss=9.481406535014006e-08	epoch_time (seconds)=1
# Epoch 299 ->	Training loss=1.0205176212449177e-07	Validation loss=9.363240955597418e-08	epoch_time (seconds)=1
# Epoch 300 ->	Training loss=9.671314232532909e-08	Validation loss=9.237073319799611e-08	epoch_time (seconds)=1
# Epoch 301 ->	Training loss=9.73541194649773e-08	Validation loss=9.15639197701691e-08	epoch_time (seconds)=1
# Epoch 302 ->	Training loss=9.637652841444254e-08	Validation loss=9.073645968280476e-08	epoch_time (seconds)=1
# Epoch 303 ->	Training loss=9.460912720400797e-08	Validation loss=9.056244662641808e-08	epoch_time (seconds)=1
# Epoch 304 ->	Training loss=9.286407227839597e-08	Validation loss=8.700900699007643e-08	epoch_time (seconds)=1
# Epoch 305 ->	Training loss=9.323091365910262e-08	Validation loss=8.60904919650436e-08	epoch_time (seconds)=1
# Epoch 306 ->	Training loss=8.957574374852067e-08	Validation loss=8.457777959101917e-08	epoch_time (seconds)=1
# Epoch 307 ->	Training loss=8.92299158294918e-08	Validation loss=8.420625501616007e-08	epoch_time (seconds)=1
# Epoch 308 ->	Training loss=8.989224459748418e-08	Validation loss=8.344680581278723e-08	epoch_time (seconds)=1
# Epoch 309 ->	Training loss=8.655000866300807e-08	Validation loss=8.196481391017452e-08	epoch_time (seconds)=1
# Epoch 310 ->	Training loss=8.641333806735929e-08	Validation loss=7.94291290109659e-08	epoch_time (seconds)=1
# Epoch 311 ->	Training loss=8.357323167729192e-08	Validation loss=7.837983373194999e-08	epoch_time (seconds)=1
# Epoch 312 ->	Training loss=8.245399385486962e-08	Validation loss=7.711764636222831e-08	epoch_time (seconds)=1
# Epoch 313 ->	Training loss=8.216630621146496e-08	Validation loss=7.658145692425791e-08	epoch_time (seconds)=1
# Epoch 314 ->	Training loss=7.977215649258472e-08	Validation loss=7.513228676476015e-08	epoch_time (seconds)=1
# Epoch 315 ->	Training loss=7.860261245117395e-08	Validation loss=7.377085875084744e-08	epoch_time (seconds)=1
# Epoch 316 ->	Training loss=7.763402829203352e-08	Validation loss=7.272943314306781e-08	epoch_time (seconds)=1
# Epoch 317 ->	Training loss=7.606165623160037e-08	Validation loss=7.159831435409677e-08	epoch_time (seconds)=1
# Epoch 318 ->	Training loss=7.45348052078043e-08	Validation loss=7.06659880588688e-08	epoch_time (seconds)=1
# Epoch 319 ->	Training loss=7.305004931946644e-08	Validation loss=6.978857154592435e-08	epoch_time (seconds)=1
# Epoch 320 ->	Training loss=7.228733838101933e-08	Validation loss=6.856596620473397e-08	epoch_time (seconds)=1
# Epoch 321 ->	Training loss=7.102335861087671e-08	Validation loss=6.740122814182813e-08	epoch_time (seconds)=1
# Epoch 322 ->	Training loss=7.032283478607001e-08	Validation loss=6.63475599162525e-08	epoch_time (seconds)=1
# Epoch 323 ->	Training loss=7.028360910639591e-08	Validation loss=6.656913197583444e-08	epoch_time (seconds)=1
# Epoch 324 ->	Training loss=6.807827214123047e-08	Validation loss=6.485847036782847e-08	epoch_time (seconds)=1
# Epoch 325 ->	Training loss=6.715979328543074e-08	Validation loss=6.408737946280187e-08	epoch_time (seconds)=1
# Epoch 326 ->	Training loss=6.711984993175561e-08	Validation loss=6.280213863375923e-08	epoch_time (seconds)=1
# Epoch 327 ->	Training loss=6.554211805368223e-08	Validation loss=6.149903157216523e-08	epoch_time (seconds)=1
# Epoch 328 ->	Training loss=6.459927135438192e-08	Validation loss=6.09791079950132e-08	epoch_time (seconds)=1
# Epoch 329 ->	Training loss=6.317294677997283e-08	Validation loss=5.943864377417785e-08	epoch_time (seconds)=1
# Epoch 330 ->	Training loss=6.172001576487673e-08	Validation loss=5.833528589871958e-08	epoch_time (seconds)=1
# Epoch 331 ->	Training loss=6.05425673876942e-08	Validation loss=5.749147013087376e-08	epoch_time (seconds)=1
# Epoch 332 ->	Training loss=6.119786906889533e-08	Validation loss=5.924232934280017e-08	epoch_time (seconds)=1
# Epoch 333 ->	Training loss=6.046206842504695e-08	Validation loss=6.23734732748151e-08	epoch_time (seconds)=1
# Epoch 334 ->	Training loss=5.999278197453929e-08	Validation loss=5.511000790930265e-08	epoch_time (seconds)=1
# Epoch 335 ->	Training loss=5.834329220471607e-08	Validation loss=5.395820562908338e-08	epoch_time (seconds)=1
# Epoch 336 ->	Training loss=5.5141034119349736e-08	Validation loss=5.2928067274230405e-08	epoch_time (seconds)=1
# Epoch 337 ->	Training loss=5.6128873934953434e-08	Validation loss=5.2013262931090454e-08	epoch_time (seconds)=1
# Epoch 338 ->	Training loss=5.4662463381563695e-08	Validation loss=5.232850514928614e-08	epoch_time (seconds)=1
# Epoch 339 ->	Training loss=5.47130519573164e-08	Validation loss=5.088409074323298e-08	epoch_time (seconds)=1
# Epoch 340 ->	Training loss=5.415372387770648e-08	Validation loss=5.1095853761230415e-08	epoch_time (seconds)=1
# Epoch 341 ->	Training loss=5.179830292366784e-08	Validation loss=4.861855737680406e-08	epoch_time (seconds)=1
# Epoch 342 ->	Training loss=5.002437195468123e-08	Validation loss=4.780936717381665e-08	epoch_time (seconds)=2
# Epoch 343 ->	Training loss=4.9816657007216815e-08	Validation loss=4.735747024146493e-08	epoch_time (seconds)=2
# Epoch 344 ->	Training loss=4.843323495151708e-08	Validation loss=4.776885056886634e-08	epoch_time (seconds)=2
# Epoch 345 ->	Training loss=4.9118500349074815e-08	Validation loss=4.814768265120241e-08	epoch_time (seconds)=2
# Epoch 346 ->	Training loss=4.720902738468298e-08	Validation loss=4.488038981966248e-08	epoch_time (seconds)=1
# Epoch 347 ->	Training loss=4.623886566564166e-08	Validation loss=4.3803349218471556e-08	epoch_time (seconds)=1
# Epoch 348 ->	Training loss=4.593493362004996e-08	Validation loss=4.324687299276492e-08	epoch_time (seconds)=1
# Epoch 349 ->	Training loss=4.5842185417396565e-08	Validation loss=4.385501820562799e-08	epoch_time (seconds)=1
# Epoch 350 ->	Training loss=4.449222284496169e-08	Validation loss=4.162545399888569e-08	epoch_time (seconds)=1
# Epoch 351 ->	Training loss=4.217540518683646e-08	Validation loss=4.082205857642672e-08	epoch_time (seconds)=1
# Epoch 352 ->	Training loss=4.215781183864403e-08	Validation loss=4.005705993013349e-08	epoch_time (seconds)=1
# Epoch 353 ->	Training loss=4.177406315813476e-08	Validation loss=4.1067172539176746e-08	epoch_time (seconds)=1
# Epoch 354 ->	Training loss=4.137840402439575e-08	Validation loss=3.878204628427676e-08	epoch_time (seconds)=1
# Epoch 355 ->	Training loss=3.977340611527325e-08	Validation loss=3.8192539470615905e-08	epoch_time (seconds)=1
# Epoch 356 ->	Training loss=3.929472809845306e-08	Validation loss=3.7280883363157767e-08	epoch_time (seconds)=1
# Epoch 357 ->	Training loss=3.847483702140215e-08	Validation loss=3.6725481612232196e-08	epoch_time (seconds)=1
# Epoch 358 ->	Training loss=3.8070611894495825e-08	Validation loss=3.6444491783615425e-08	epoch_time (seconds)=1
# Epoch 359 ->	Training loss=3.682893913554091e-08	Validation loss=3.573890333664958e-08	epoch_time (seconds)=1
# Epoch 360 ->	Training loss=3.6449589102134766e-08	Validation loss=3.507363493644679e-08	epoch_time (seconds)=1
# Epoch 361 ->	Training loss=3.722182865120968e-08	Validation loss=3.4340627116649354e-08	epoch_time (seconds)=1
# Epoch 362 ->	Training loss=3.489560557764807e-08	Validation loss=3.3422114774908346e-08	epoch_time (seconds)=1
# Epoch 363 ->	Training loss=3.454936983292679e-08	Validation loss=3.290940094867545e-08	epoch_time (seconds)=1
# Epoch 364 ->	Training loss=3.311058352747667e-08	Validation loss=3.289605198141606e-08	epoch_time (seconds)=1
# Epoch 365 ->	Training loss=3.38720021566339e-08	Validation loss=3.241332706238609e-08	epoch_time (seconds)=1
# Epoch 366 ->	Training loss=3.240667224831255e-08	Validation loss=3.112146508366937e-08	epoch_time (seconds)=1
# Epoch 367 ->	Training loss=3.208506851396206e-08	Validation loss=3.0538500191960905e-08	epoch_time (seconds)=1
# Epoch 368 ->	Training loss=3.162200114688445e-08	Validation loss=3.0037773760103965e-08	epoch_time (seconds)=1
# Epoch 369 ->	Training loss=3.066925418434866e-08	Validation loss=3.0471033055873254e-08	epoch_time (seconds)=1
# Epoch 370 ->	Training loss=3.0209790069916796e-08	Validation loss=2.90567587534559e-08	epoch_time (seconds)=1
# Epoch 371 ->	Training loss=2.9542229433652458e-08	Validation loss=2.864876043294435e-08	epoch_time (seconds)=1
# Epoch 372 ->	Training loss=3.01649280035318e-08	Validation loss=2.9229458310250527e-08	epoch_time (seconds)=1
# Epoch 373 ->	Training loss=2.8472768669664882e-08	Validation loss=2.7715940567369607e-08	epoch_time (seconds)=1
# Epoch 374 ->	Training loss=2.817687262987337e-08	Validation loss=2.6887403745610037e-08	epoch_time (seconds)=1
# Epoch 375 ->	Training loss=2.7638077840079363e-08	Validation loss=2.6918596264543604e-08	epoch_time (seconds)=1
# Epoch 376 ->	Training loss=2.7718334753113925e-08	Validation loss=2.6241515717166007e-08	epoch_time (seconds)=1
# Epoch 377 ->	Training loss=2.732708067428162e-08	Validation loss=2.6124168629315175e-08	epoch_time (seconds)=1
# Epoch 378 ->	Training loss=2.649889169829707e-08	Validation loss=2.5013526703999486e-08	epoch_time (seconds)=1
# Epoch 379 ->	Training loss=2.585515424222897e-08	Validation loss=2.450144196847296e-08	epoch_time (seconds)=1
# Epoch 380 ->	Training loss=2.534233648144767e-08	Validation loss=2.4493415903691232e-08	epoch_time (seconds)=1
# Epoch 381 ->	Training loss=2.4748387245794716e-08	Validation loss=2.3665610561404927e-08	epoch_time (seconds)=1
# Epoch 382 ->	Training loss=2.4011957190272038e-08	Validation loss=2.3572828544139094e-08	epoch_time (seconds)=1
# Epoch 383 ->	Training loss=2.4023213220723185e-08	Validation loss=2.2793905449226195e-08	epoch_time (seconds)=1
# Epoch 384 ->	Training loss=2.329907023191812e-08	Validation loss=2.3062518396597755e-08	epoch_time (seconds)=1
# Epoch 385 ->	Training loss=2.2804593051908092e-08	Validation loss=2.2106628364679816e-08	epoch_time (seconds)=1
# Epoch 386 ->	Training loss=2.2309685515541456e-08	Validation loss=2.1517586537246537e-08	epoch_time (seconds)=1
# Epoch 387 ->	Training loss=2.212597626732366e-08	Validation loss=2.1443570403789637e-08	epoch_time (seconds)=1
# Epoch 388 ->	Training loss=2.133670539644134e-08	Validation loss=2.0842095317737698e-08	epoch_time (seconds)=1
# Epoch 389 ->	Training loss=2.093200888256516e-08	Validation loss=2.0340605941280232e-08	epoch_time (seconds)=1
# Epoch 390 ->	Training loss=2.0423392263844357e-08	Validation loss=2.0229833172599897e-08	epoch_time (seconds)=1
# Epoch 391 ->	Training loss=2.0511587205295325e-08	Validation loss=1.9685868755349366e-08	epoch_time (seconds)=1
# Epoch 392 ->	Training loss=2.034272204747884e-08	Validation loss=1.9268814127222326e-08	epoch_time (seconds)=1
# Epoch 393 ->	Training loss=2.0213709087163973e-08	Validation loss=2.1511126512185067e-08	epoch_time (seconds)=1
# Epoch 394 ->	Training loss=2.133445274342772e-08	Validation loss=2.09624219045825e-08	epoch_time (seconds)=1
# Epoch 395 ->	Training loss=2.0255630798518805e-08	Validation loss=1.826166803851418e-08	epoch_time (seconds)=1
# Epoch 396 ->	Training loss=1.852448680107376e-08	Validation loss=1.787221006407263e-08	epoch_time (seconds)=1
# Epoch 397 ->	Training loss=1.791882503064037e-08	Validation loss=1.7669841956873445e-08	epoch_time (seconds)=1
# Epoch 398 ->	Training loss=1.7890790579919917e-08	Validation loss=2.0188892381580298e-08	epoch_time (seconds)=1
# Epoch 399 ->	Training loss=1.889785835373914e-08	Validation loss=1.718072076214666e-08	epoch_time (seconds)=1
# Epoch 400 ->	Training loss=1.7985117375990904e-08	Validation loss=2.047884961611773e-08	epoch_time (seconds)=1
# Epoch 401 ->	Training loss=1.8075536445394392e-08	Validation loss=1.653662078051469e-08	epoch_time (seconds)=1
# Epoch 402 ->	Training loss=1.6501233052291686e-08	Validation loss=1.623172501076511e-08	epoch_time (seconds)=1
# Epoch 403 ->	Training loss=1.6057745659219854e-08	Validation loss=1.5944771777912764e-08	epoch_time (seconds)=1
# Epoch 404 ->	Training loss=1.5943263013634187e-08	Validation loss=1.543281677248454e-08	epoch_time (seconds)=1
# Epoch 405 ->	Training loss=1.5806455373670112e-08	Validation loss=1.5292630860413336e-08	epoch_time (seconds)=1
# Epoch 406 ->	Training loss=1.5151302932281395e-08	Validation loss=1.5007243582545723e-08	epoch_time (seconds)=1
# Epoch 407 ->	Training loss=1.4997883681644453e-08	Validation loss=1.4675329464988642e-08	epoch_time (seconds)=1
# Epoch 408 ->	Training loss=1.4908939337229557e-08	Validation loss=1.4317402556173067e-08	epoch_time (seconds)=1
# Epoch 409 ->	Training loss=1.4655471328627423e-08	Validation loss=1.4105764862026307e-08	epoch_time (seconds)=1
# Epoch 410 ->	Training loss=1.4685606608757305e-08	Validation loss=1.4857693109119034e-08	epoch_time (seconds)=1
# Epoch 411 ->	Training loss=1.376559783817687e-08	Validation loss=1.3551065102609139e-08	epoch_time (seconds)=1
# Epoch 412 ->	Training loss=1.3596679557601668e-08	Validation loss=1.3714297024335844e-08	epoch_time (seconds)=1
# Epoch 413 ->	Training loss=1.318750646946269e-08	Validation loss=1.3038007002974182e-08	epoch_time (seconds)=1
# Epoch 414 ->	Training loss=1.296625493358244e-08	Validation loss=1.2921217107731485e-08	epoch_time (seconds)=1
# Epoch 415 ->	Training loss=1.2813117212896362e-08	Validation loss=1.279764342002382e-08	epoch_time (seconds)=1
# Epoch 416 ->	Training loss=1.2444782607252075e-08	Validation loss=1.2464033476157823e-08	epoch_time (seconds)=1
# Epoch 417 ->	Training loss=1.2538400927620717e-08	Validation loss=1.2220694256741453e-08	epoch_time (seconds)=1
# Epoch 418 ->	Training loss=1.2138827866113967e-08	Validation loss=1.1871981305997206e-08	epoch_time (seconds)=1
# Epoch 419 ->	Training loss=1.2243602379219902e-08	Validation loss=1.2403021895332368e-08	epoch_time (seconds)=1
# Epoch 420 ->	Training loss=1.2366227276123193e-08	Validation loss=1.1925333917546064e-08	epoch_time (seconds)=1
# Epoch 421 ->	Training loss=1.1365604409134407e-08	Validation loss=1.128008146913784e-08	epoch_time (seconds)=1
# Epoch 422 ->	Training loss=1.0961493382472493e-08	Validation loss=1.1014458697437189e-08	epoch_time (seconds)=1
# Epoch 423 ->	Training loss=1.0976128289092396e-08	Validation loss=1.0895491755742476e-08	epoch_time (seconds)=1
# Epoch 424 ->	Training loss=1.0854127119521515e-08	Validation loss=1.1007003262906584e-08	epoch_time (seconds)=1
# Epoch 425 ->	Training loss=1.0903956783956594e-08	Validation loss=1.0584789985067862e-08	epoch_time (seconds)=1
# Epoch 426 ->	Training loss=1.0782287528276025e-08	Validation loss=1.027375245691208e-08	epoch_time (seconds)=1
# Epoch 427 ->	Training loss=1.0380231804612611e-08	Validation loss=1.008385669259533e-08	epoch_time (seconds)=1
# Epoch 428 ->	Training loss=9.95711368225536e-09	Validation loss=9.838883765075722e-09	epoch_time (seconds)=1
# Epoch 429 ->	Training loss=1.0350864840802387e-08	Validation loss=1.0236363073231841e-08	epoch_time (seconds)=1
# Epoch 430 ->	Training loss=1.01998995722335e-08	Validation loss=9.693493375493039e-09	epoch_time (seconds)=1
# Epoch 431 ->	Training loss=9.270573390164249e-09	Validation loss=9.31718883401129e-09	epoch_time (seconds)=1
# Epoch 432 ->	Training loss=9.847331367299458e-09	Validation loss=9.557961280022383e-09	epoch_time (seconds)=1
# Epoch 433 ->	Training loss=9.013300231427737e-09	Validation loss=9.743001634848517e-09	epoch_time (seconds)=1
# Epoch 434 ->	Training loss=8.809522465856968e-09	Validation loss=8.778047019478204e-09	epoch_time (seconds)=1
# Epoch 435 ->	Training loss=8.72648084540825e-09	Validation loss=8.81841876903789e-09	epoch_time (seconds)=1
# Epoch 436 ->	Training loss=8.498856748867018e-09	Validation loss=8.577895847982357e-09	epoch_time (seconds)=1
# Epoch 437 ->	Training loss=8.292805918327675e-09	Validation loss=8.475364386455644e-09	epoch_time (seconds)=1
# Epoch 438 ->	Training loss=8.140164647391596e-09	Validation loss=8.454723870244328e-09	epoch_time (seconds)=1
# Epoch 439 ->	Training loss=8.474999772674479e-09	Validation loss=8.07128761926771e-09	epoch_time (seconds)=1
# Epoch 440 ->	Training loss=8.092269106121173e-09	Validation loss=7.82446932134917e-09	epoch_time (seconds)=1
# Epoch 441 ->	Training loss=7.993300011383491e-09	Validation loss=7.693943563472825e-09	epoch_time (seconds)=1
# Epoch 442 ->	Training loss=7.627457731277073e-09	Validation loss=8.504246817091885e-09	epoch_time (seconds)=1
# Epoch 443 ->	Training loss=8.036547156238654e-09	Validation loss=8.946069054907424e-09	epoch_time (seconds)=1
# Epoch 444 ->	Training loss=7.603197528541469e-09	Validation loss=7.6811722030233e-09	epoch_time (seconds)=1
# Epoch 445 ->	Training loss=7.270326963490251e-09	Validation loss=7.177307633135355e-09	epoch_time (seconds)=1
# Epoch 446 ->	Training loss=7.062627570452274e-09	Validation loss=9.57841248646501e-09	epoch_time (seconds)=1
# Epoch 447 ->	Training loss=7.094749838126352e-09	Validation loss=6.859791992412837e-09	epoch_time (seconds)=1
# Epoch 448 ->	Training loss=6.61192989975296e-09	Validation loss=6.724130459887595e-09	epoch_time (seconds)=1
# Epoch 449 ->	Training loss=6.565978248380071e-09	Validation loss=7.103413359964292e-09	epoch_time (seconds)=1
# Epoch 450 ->	Training loss=6.491677130394568e-09	Validation loss=6.670782356975126e-09	epoch_time (seconds)=1
# Epoch 451 ->	Training loss=6.168129971229064e-09	Validation loss=6.361513841912705e-09	epoch_time (seconds)=1
# Epoch 452 ->	Training loss=5.950635113549651e-09	Validation loss=6.212537102175973e-09	epoch_time (seconds)=1
# Epoch 453 ->	Training loss=5.830512980702968e-09	Validation loss=6.241687067598809e-09	epoch_time (seconds)=1
# Epoch 454 ->	Training loss=5.991567025954613e-09	Validation loss=6.178806302159501e-09	epoch_time (seconds)=1
# Epoch 455 ->	Training loss=6.18626436541738e-09	Validation loss=6.482395492385419e-09	epoch_time (seconds)=1
# Epoch 456 ->	Training loss=5.904941789677568e-09	Validation loss=5.797982143974776e-09	epoch_time (seconds)=1
# Epoch 457 ->	Training loss=5.638677552352337e-09	Validation loss=5.638050431105128e-09	epoch_time (seconds)=1
# Epoch 458 ->	Training loss=5.433024005634996e-09	Validation loss=6.4085734633160166e-09	epoch_time (seconds)=1
# Epoch 459 ->	Training loss=5.6396724672099064e-09	Validation loss=5.688241665903542e-09	epoch_time (seconds)=1
# Epoch 460 ->	Training loss=5.161111341129237e-09	Validation loss=5.644270252119466e-09	epoch_time (seconds)=1
# Epoch 461 ->	Training loss=4.985092154832025e-09	Validation loss=5.239488870152312e-09	epoch_time (seconds)=1
# Epoch 462 ->	Training loss=4.809835006240477e-09	Validation loss=5.201995636017267e-09	epoch_time (seconds)=1
# Epoch 463 ->	Training loss=4.810637376935616e-09	Validation loss=5.019158510922296e-09	epoch_time (seconds)=1
# Epoch 464 ->	Training loss=4.566585558181528e-09	Validation loss=4.894981403843569e-09	epoch_time (seconds)=1
# Epoch 465 ->	Training loss=4.4420535387375404e-09	Validation loss=4.807893490703142e-09	epoch_time (seconds)=1
# Epoch 466 ->	Training loss=4.65370535804058e-09	Validation loss=4.715364857390189e-09	epoch_time (seconds)=1
# Epoch 467 ->	Training loss=4.301865834060498e-09	Validation loss=4.6814630434184765e-09	epoch_time (seconds)=1
# Epoch 468 ->	Training loss=4.225490783937857e-09	Validation loss=4.5911840184174405e-09	epoch_time (seconds)=1
# Epoch 469 ->	Training loss=4.172509410306123e-09	Validation loss=4.452789846215202e-09	epoch_time (seconds)=1
# Epoch 470 ->	Training loss=4.127834203741672e-09	Validation loss=4.392336496008137e-09	epoch_time (seconds)=1
# Epoch 471 ->	Training loss=3.872894751566491e-09	Validation loss=4.263181783741478e-09	epoch_time (seconds)=1
# Epoch 472 ->	Training loss=3.9633601741942664e-09	Validation loss=4.232372018733083e-09	epoch_time (seconds)=1
# Epoch 473 ->	Training loss=4.0101040677985686e-09	Validation loss=4.333237987505736e-09	epoch_time (seconds)=1
# Epoch 474 ->	Training loss=3.941143182311697e-09	Validation loss=4.194378444235384e-09	epoch_time (seconds)=1
# Epoch 475 ->	Training loss=3.6787560795594553e-09	Validation loss=4.098570752407032e-09	epoch_time (seconds)=1
# Epoch 476 ->	Training loss=3.5194107216408487e-09	Validation loss=3.878759214712094e-09	epoch_time (seconds)=1
# Epoch 477 ->	Training loss=3.500936610511086e-09	Validation loss=3.788063515093544e-09	epoch_time (seconds)=1
# Epoch 478 ->	Training loss=3.3862285032558827e-09	Validation loss=3.7246939315585036e-09	epoch_time (seconds)=1
# Epoch 479 ->	Training loss=3.2336271519025932e-09	Validation loss=3.635415142421237e-09	epoch_time (seconds)=1
# Epoch 480 ->	Training loss=3.233735671156782e-09	Validation loss=3.633870574331521e-09	epoch_time (seconds)=1
# Epoch 481 ->	Training loss=3.155870470808705e-09	Validation loss=3.724533002896803e-09	epoch_time (seconds)=1
# Epoch 482 ->	Training loss=3.221087416188146e-09	Validation loss=3.792463716483823e-09	epoch_time (seconds)=1
# Epoch 483 ->	Training loss=3.14196990364673e-09	Validation loss=4.058134114848992e-09	epoch_time (seconds)=1
# Epoch 484 ->	Training loss=3.4270479690431703e-09	Validation loss=4.037501855056e-09	epoch_time (seconds)=1
# Epoch 485 ->	Training loss=3.140121407341212e-09	Validation loss=3.658616851850034e-09	epoch_time (seconds)=1
# Epoch 486 ->	Training loss=2.952096400060162e-09	Validation loss=3.4479331650387923e-09	epoch_time (seconds)=1
# Epoch 487 ->	Training loss=3.125097665898383e-09	Validation loss=3.4135084428079446e-09	epoch_time (seconds)=1
# Epoch 488 ->	Training loss=2.9111168037781516e-09	Validation loss=3.1532934379847916e-09	epoch_time (seconds)=1
# Epoch 489 ->	Training loss=2.534656289299164e-09	Validation loss=3.024679412550913e-09	epoch_time (seconds)=1
# Epoch 490 ->	Training loss=2.5214867543416567e-09	Validation loss=2.9144268282354504e-09	epoch_time (seconds)=1
# Epoch 491 ->	Training loss=2.487572252427774e-09	Validation loss=2.9677858938072707e-09	epoch_time (seconds)=1
# Epoch 492 ->	Training loss=2.357860337683219e-09	Validation loss=2.808970451519458e-09	epoch_time (seconds)=1
# Epoch 493 ->	Training loss=2.336367065874418e-09	Validation loss=2.888968535701323e-09	epoch_time (seconds)=1
# Epoch 494 ->	Training loss=2.3657522583355535e-09	Validation loss=2.770526128128752e-09	epoch_time (seconds)=1
# Epoch 495 ->	Training loss=2.222984585903925e-09	Validation loss=2.656166769210364e-09	epoch_time (seconds)=1
# Epoch 496 ->	Training loss=2.1872247140725616e-09	Validation loss=2.655908211094108e-09	epoch_time (seconds)=1
# Epoch 497 ->	Training loss=2.1078042390275764e-09	Validation loss=2.5398443863732664e-09	epoch_time (seconds)=1
# Epoch 498 ->	Training loss=2.037954477497227e-09	Validation loss=2.531771612895275e-09	epoch_time (seconds)=1
# Epoch 499 ->	Training loss=2.0684641232161414e-09	Validation loss=2.4433230430743533e-09

# %%
metrics_logger.plot_metrics_by_epoch()
metrics_logger.save_metrics()
# Out:
# epoch_time (seconds)=1
# Metrics exported in the following csv file: logged_metrics/aemlp_layers6-24-48-16_04-07-2023_01-41-45.csv

# %% [markdown]
# # Testing

# %%
# loading best mlp
mlp = AE_MLP(input_space, bottleneck_space).to(DEVICE)
mlp.load_state_dict(torch.load(BEST_MODEL_PATH))
mlp.eval()

mlp
# Out:
# AE_MLP(
#   (layers): Sequential(
#     (0): Linear(in_features=2, out_features=6, bias=True)
#     (1): ReLU()
#     (2): Linear(in_features=6, out_features=24, bias=True)
#     (3): ReLU()
#     (4): Linear(in_features=24, out_features=48, bias=True)
#     (5): ReLU()
#     (6): Linear(in_features=48, out_features=16, bias=True)
#     (7): ReLU()
#     (8): Linear(in_features=16, out_features=8, bias=True)
#   )
# )

# %%
class FinalModel(nn.Module): #TODO change name
    def __init__(self, mlp: AE_MLP, autoencoder: AutoEncoder):
        super(FinalModel, self).__init__()
        self.mlp = mlp
        self.autoencoder = autoencoder

    def forward(self, x):
        x = self.mlp(x)
        x = self.autoencoder.decoder(x)
        return x

# %%
# loading best model
model = FinalModel(mlp, autoencoder).to(DEVICE)
model.eval()

test_pytorch_model(model, test_dataloader,
                   model_description=final_model_description,
                   save_results=True)
# Out:
# Test results for Autoencoder description: autoencoders_layers8-16-32-64-128-256-512-1024-2048-4096_training_factors=ti4-ct4_discr_factors_x2_30_y-2_2_step0.125_TIstep0.01_CTstep0.01: act. func. Sigmoid , batch size 64, 500 epochs, lr=1e-06) --- MLP description: aemlp_layers6-24-48-16_discr_factors_x2_30_y-2_2_step0.125_TIstep0.01_CTstep0.01: act. func. ReLU (not last layer), batch size 64, 500 epochs, lr=0.001)
# r2_score=-12.063679544604165
# explained_variance_score=2.1852818982941765e-08
# mean_squared_error=0.0007561064558103681
# mean_absolute_error=0.017863264307379723
# median_absolute_error=0.016519695520401
# mean_absolute_percentage_error=1673117958144.0
# Prediction time=0.0004915818516512095s

# %%
test_dataset = test_dataloader.dataset
indices = list(range(len(test_dataset)))
random.shuffle(indices)
with torch.no_grad():
    for idx in indices[:10]:
        ti, ct, ws, wake_field, predicted_wake_field = test_dataset.get_parameters_for_plotting_multivariate(model, idx)
        
        plotting.plot_maps(test_dataset.X_grid, test_dataset.Y_grid, wake_field, predicted_wake_field, ti, ct, ws, error_to_plot='absolute')
