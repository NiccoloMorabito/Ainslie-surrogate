# %%
from sklearn.linear_model import LinearRegression
from sklearn.metrics import mean_squared_error, r2_score
import numpy as np
import torch

import utils.plotting as plotting
import utils.utils as utils
import utils.data_utils as data_utils
from utils.data_loaders import get_wake_datasets
from utils.evaluation import test_sklearn_model

# %%
FACTORS_FOLDER = "discr_factors_x2_30_y-2_2_step0.125_TIstep0.01_CTstep0.01"
DATA_FOLDER = f"data/{FACTORS_FOLDER}/"
INPUT_VAR_TO_TRAIN_REDUCTION_FACTOR = {'ti': 4, 'ct': 4}
train_reduc_factor_string = "training_factors=" + "-".join([f"{k}{v}" for k, v in INPUT_VAR_TO_TRAIN_REDUCTION_FACTOR.items()])
MODEL_NAME = f"multivariate_LR_{train_reduc_factor_string}" #TODO make the name represent the structure or the parameters of the model
#BEST_MODEL_PATH = f"saved_models/{FACTORS_FOLDER}/{MODEL_NAME}.pt"

CONSIDER_WS = False
COORDS_AS_INPUT = False #multivariate

# %%
valid_dataset = None
train_dataset, test_dataset = get_wake_datasets(DATA_FOLDER,
                                                consider_ws=CONSIDER_WS,
                                                coords_as_input=COORDS_AS_INPUT,
                                                #train_perc=0.7,
                                                #test_perc=0.3,
                                                #validation_perc=0,
                                                input_var_to_train_reduction_factor=INPUT_VAR_TO_TRAIN_REDUCTION_FACTOR)
train_x, train_y = train_dataset.inputs, train_dataset.outputs
test_x, test_y = test_dataset.inputs, test_dataset.outputs
print("Train shapes: ", train_x.shape, train_y.shape)
print("Test shapes: ", test_x.shape, test_y.shape)

if valid_dataset is not None:
    valid_x, valid_y = valid_dataset.inputs, valid_dataset.outputs
    print("Valid shapes: ", valid_x.shape, valid_y.shape)
# Out:
# Train shapes:  torch.Size([6020, 2]) torch.Size([6020, 7168])
# Test shapes:  torch.Size([2580, 2]) torch.Size([2580, 7168])

# %% [markdown]
# # Training

# %%
model = LinearRegression()
model.fit(train_x, train_y)
# Out:
# LinearRegression()

# %% [markdown]
# # Testing

# %%
test_sklearn_model(model, test_x, test_y,
                   model_description=MODEL_NAME+"_"+FACTORS_FOLDER,
                   save_results=True)
# Out:
# Test results
# r2_score=0.7538112223531289
# explained_variance_score=0.7539763062211152
# mean_squared_error=0.00018022356380242854
# mean_absolute_error=0.005994722247123718
# median_absolute_error=0.004916189704090357
# mean_absolute_percentage_error=398478442496.0

# %%
with torch.no_grad():
    for idx in range(len(test_dataset)):
        ti, ct, ws, wake_field, predicted_wake_field = test_dataset.get_parameters_for_plotting_multivariate(model, idx)
        
        plotting.plot_maps(test_dataset.X_grid, test_dataset.Y_grid, wake_field, predicted_wake_field, ti, ct, ws, error_to_plot='absolute')
# Out:
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# Cell In[6], line 5
#       2 for idx in range(len(test_dataset)):
#       3     ti, ct, ws, wake_field, predicted_wake_field = test_dataset.get_parameters_for_plotting_multivariate(model, idx)
# ----> 5     plotting.plot_maps(test_dataset.X_grid, test_dataset.Y_grid, wake_field, predicted_wake_field, ti, ct, ws, error_to_plot='absolute')
#
# File ~/Library/CloudStorage/GoogleDrive-morabito.1808746@studenti.uniroma1.it/My Drive/BDMA/Semester4 Thesis/Ainslie-surrogate/utils/plotting.py:78, in plot_maps(X, Y, original, predicted, ti, ct, ws, zlabel, error_to_plot)
#      75 else:
#      76     fig, axs = plt.subplots(1, 3, figsize=(15, 5))  # Create a figure with three subplots
# ---> 78 plot_submap(X, Y, original, zlabel=f"Actual {zlabel}", levels=levels, ax=axs[0])
#      79 plot_submap(X, Y, predicted, zlabel=f"Predicted {zlabel}", levels=levels, ax=axs[1])
#      80 if error_to_plot is not None:
#
# File ~/Library/CloudStorage/GoogleDrive-morabito.1808746@studenti.uniroma1.it/My Drive/BDMA/Semester4 Thesis/Ainslie-surrogate/utils/plotting.py:95, in plot_submap(X, Y, wake_field, zlabel, levels, cmap, ax)
#      93 if wake_field.dim() == 1:
#      94     wake_field = wake_field.reshape(X.shape)
# ---> 95 __plot_contour(X, Y, wake_field,
#      96                DEFAULT_XLABEL, DEFAULT_YLABEL, zlabel,
#      97                title=zlabel,
#      98                levels=levels, cmap=cmap, ax=ax)
#
# File ~/Library/CloudStorage/GoogleDrive-morabito.1808746@studenti.uniroma1.it/My Drive/BDMA/Semester4 Thesis/Ainslie-surrogate/utils/plotting.py:134, in __plot_contour(X, Y, Z, xlabel, ylabel, zlabel, title, levels, cmap, ax)
#     132 ax.set_ylabel(ylabel)
#     133 ax.set_title(title)
# --> 134 c = ax.contourf(X, Y, Z, levels=levels, cmap=cmap)
#     135 plt.colorbar(c, label=zlabel, ax=ax)
#     136 if show:
#
# File /opt/homebrew/lib/python3.10/site-packages/matplotlib/__init__.py:1433, in _preprocess_data.<locals>.inner(ax, data, *args, **kwargs)
#    1430 @functools.wraps(func)
#    1431 def inner(ax, *args, data=None, **kwargs):
#    1432     if data is None:
# -> 1433         return func(ax, *map(sanitize_sequence, args), **kwargs)
#    1435     bound = new_sig.bind(ax, *args, **kwargs)
#    1436     auto_label = (bound.arguments.get(label_namer)
#    1437                   or bound.kwargs.get(label_namer))
#
# File /opt/homebrew/lib/python3.10/site-packages/matplotlib/axes/_axes.py:6420, in Axes.contourf(self, *args, **kwargs)
#    6411 """
#    6412 Plot filled contours.
#    6413
#    (...)
#    6417 %(contour_doc)s
#    6418 """
#    6419 kwargs['filled'] = True
# -> 6420 contours = mcontour.QuadContourSet(self, *args, **kwargs)
#    6421 self._request_autoscale_view()
#    6422 return contours
#
# File /opt/homebrew/lib/python3.10/site-packages/matplotlib/contour.py:848, in ContourSet.__init__(self, ax, levels, filled, linewidths, linestyles, hatches, alpha, origin, extent, cmap, colors, norm, vmin, vmax, extend, antialiased, nchunk, locator, transform, negative_linestyles, *args, **kwargs)
#     845 self._process_colors()
#     847 if getattr(self, 'allsegs', None) is None:
# --> 848     self.allsegs, self.allkinds = self._get_allsegs_and_allkinds()
#     849 elif self.allkinds is None:
#     850     # allsegs specified in constructor may or may not have allkinds as
#     851     # well.  Must ensure allkinds can be zipped below.
#     852     self.allkinds = [None] * len(self.allsegs)
#
# File /opt/homebrew/lib/python3.10/site-packages/matplotlib/contour.py:1031, in ContourSet._get_allsegs_and_allkinds(self)
#    1028 lowers, uppers = self._get_lowers_and_uppers()
#    1029 for level, level_upper in zip(lowers, uppers):
#    1030     vertices, kinds = \
# -> 1031         self._contour_generator.create_filled_contour(
#    1032             level, level_upper)
#    1033     allsegs.append(vertices)
#    1034     allkinds.append(kinds)
#
# KeyboardInterrupt:
