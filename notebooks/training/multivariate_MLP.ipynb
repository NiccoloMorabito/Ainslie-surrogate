# %% [markdown]
# # Multivariate regression to predict the wind speed field

# %%
import torch
import torch.nn as nn
import numpy as np


import sys

sys.path.append("../..")

from src.data_loaders import get_wake_dataloaders
from src.logging_metrics import MetricsLogger
import src.plotting as plotting
from src.evaluation import evaluate_model

# define random seeds for Neural Networks
torch.manual_seed(0)
np.random.seed(0)

# %%
HIDDEN_LAYERS_UNITS = [50, 500]
ACTIVATION_FUNCTION = nn.ReLU()


class MultivariateNN(nn.Module):
    def __init__(self, input_space, output_space) -> None:
        super(MultivariateNN, self).__init__()
        layer_units = [input_space] + HIDDEN_LAYERS_UNITS
        layers = list()
        for first, second in zip(layer_units, layer_units[1:]):
            layers += [nn.Linear(first, second), ACTIVATION_FUNCTION]
        layers.append(
            nn.Linear(layer_units[-1], output_space)
        )  # last layer not activated
        self.layers = nn.Sequential(*layers)

    def forward(self, x):
        return self.layers(x)


# TODO add regularization term in the loss function?

# %%
FACTORS_FOLDER = "discr_factors_x2_30_y-2_2_step0.125_TIstep0.01_CTstep0.01"
DATA_FOLDER = f"../../data/{FACTORS_FOLDER}/"

INPUT_VAR_TO_TRAIN_REDUCTION_FACTOR = {"ti": 4, "ct": 4}
train_reduc_factor_string = "training_factors=" + "-".join(
    [f"{k}{v}" for k, v in INPUT_VAR_TO_TRAIN_REDUCTION_FACTOR.items()]
)
# INPUT_VAR_TO_TRAIN_RANGES = {'ti': [(0.15, 0.4)], 'ct': [(0.3, 0.7)]}
# train_range_string = "training_ranges=" + '-'.join([f"{var}{r[0]}-{r[1]}" for var, ranges in INPUT_VAR_TO_TRAIN_RANGES.items() for r in ranges])
EXPERIMENT = "interpolation"
MODEL_NAME = f"multivariate_NN_layers{'-'.join(str(lu) for lu in HIDDEN_LAYERS_UNITS)}_{train_reduc_factor_string}"
BEST_MODEL_PATH = f"../saved_models/{FACTORS_FOLDER}/{MODEL_NAME}.pt"
CONSIDER_WS = False
COORDS_AS_INPUT = False  # multivariate setting
if CONSIDER_WS:
    MODEL_NAME += "_consider_ws"
    BEST_MODEL_PATH = BEST_MODEL_PATH.replace("TIstep0.01_CTstep0.01", "reducedTI-CT")
print(f"Model name: {MODEL_NAME}")
print(f"Best model path: {BEST_MODEL_PATH}")

# hyperparameters
BATCH_SIZE = 64
EPOCHS = 500
LR = 0.001

MODEL_DESCRIPTION = (
    f"{MODEL_NAME}_{FACTORS_FOLDER}: act. func. {ACTIVATION_FUNCTION.__class__.__name__} "
    + f"(not last layer), batch size {BATCH_SIZE}, {EPOCHS} epochs, lr={LR})"
)
print(f"Model description: {MODEL_DESCRIPTION}")

DEVICE = torch.device("cuda" if torch.cuda.is_available() else "cpu")
print(f"\nDevice: {DEVICE}")
# Out:
# Model name: multivariate_NN_layers50-500_training_factors=ti4-ct4
# Best model path: saved_models/discr_factors_x2_30_y-2_2_step0.125_TIstep0.01_CTstep0.01/multivariate_NN_layers50-500_training_factors=ti4-ct4.pt
# Model description: multivariate_NN_layers50-500_training_factors=ti4-ct4_discr_factors_x2_30_y-2_2_step0.125_TIstep0.01_CTstep0.01: act. func. ReLU (not last layer), batch size 64, 500 epochs, lr=0.001)
#
# Device: cpu

# %%
valid_dataloader = None
train_dataloader, valid_dataloader, test_dataloader = get_wake_dataloaders(
    DATA_FOLDER,
    consider_ws=CONSIDER_WS,
    coords_as_input=COORDS_AS_INPUT,
    # train_perc=0.6,
    # test_perc=0.2,
    # validation_perc=0.2,
    input_var_to_train_reduction_factor=INPUT_VAR_TO_TRAIN_REDUCTION_FACTOR,
    # input_var_to_train_ranges=INPUT_VAR_TO_TRAIN_RANGES,
    batch_size=BATCH_SIZE,
)
len(train_dataloader)
# Out:
# /Users/niccolomorabito/Library/CloudStorage/GoogleDrive-morabito.1808746@studenti.uniroma1.it/My Drive/BDMA/Semester4 Thesis/Ainslie-surrogate/utils/data_loaders.py:328: UserWarning:
# Ignoring percentages of train-valid-test split (train_perc=0.8, valid_perc=0, test_perc=0.2)
# and using the reduction factors for the training set instead:
# {'ti': 4, 'ct': 4}
#   warnings.warn(
# 9

# %%
for b in train_dataloader:
    print(b[0].shape, b[1].shape)
    break

input_space = train_dataloader.dataset.inputs.shape[1]
output_space = train_dataloader.dataset.outputs.shape[1]
print(f"{input_space=}\t{output_space=}")
# Out:
# torch.Size([64, 2]) torch.Size([64, 7168])
# input_space=2	output_space=7168

# %%
model = MultivariateNN(input_space, output_space).to(DEVICE)

optimizer = torch.optim.Adam((p for p in model.parameters() if p.requires_grad), lr=LR)

loss_function = torch.nn.MSELoss()
# rmse_function = RMSELoss()

metrics_logger = MetricsLogger(name=MODEL_NAME)
best_v_loss = 1_000_000.0
for epoch in range(EPOCHS):
    """TRAINING"""
    model.train(True)
    epoch_t_loss = 0
    epoch_t_rmse = 0
    for batch in iter(train_dataloader):
        input_features, wake_field = batch[0].to(DEVICE), batch[1].to(DEVICE)
        optimizer.zero_grad()
        prediction = model.forward(input_features)
        tloss = loss_function(prediction, wake_field)
        tloss.backward()
        # torch.nn.utils.clip_grad_norm_(model.parameters(), 0.5) TODO
        optimizer.step()

        epoch_t_loss += tloss.item() * input_features.size(0)

        # other metrics
        # rmse = rmse_function(prediction, wake_field)
        # epoch_t_rmse += rmse.item() * input_features.size(0)

    avg_t_loss = epoch_t_loss / len(train_dataloader.sampler)
    # avg_t_rmse = epoch_t_rmse / len(train_dataloader.sampler)
    metrics_logger.log_metric(epoch, "Training loss (MSE)", avg_t_loss)
    # metrics_logger.log_metric(epoch, 'Training RMSE', avg_t_rmse)

    """VALIDATION"""
    if valid_dataloader:
        model.train(False)
        epoch_v_loss = 0
        epoch_v_rmse = 0
        for batch in iter(valid_dataloader):
            input_features, wake_field = batch[0].to(DEVICE), batch[1].to(DEVICE)
            prediction = model(input_features)

            vloss = loss_function(prediction, wake_field)
            epoch_v_loss += vloss.item() * input_features.size(0)
            # rmse = rmse_function(prediction, wake_field)
            # epoch_v_rmse += rmse.item() * input_features.size(0)

        avg_v_loss = epoch_v_loss / len(valid_dataloader.sampler)
        # avg_v_rmse = epoch_v_rmse / len(valid_dataloader.sampler)
        metrics_logger.log_metric(epoch, "Validation loss (MSE)", avg_v_loss)
        # metrics_logger.log_metric(epoch, 'Validation RMSE', avg_v_rmse)
        # Track best performance, and save the model's state
        if avg_v_loss < best_v_loss:
            best_vloss = avg_v_loss
            torch.save(model.state_dict(), BEST_MODEL_PATH)

metrics_logger.plot_metrics_by_epoch()
metrics_logger.save_metrics()
# Out:
# Logging multivariate_NN_layers50-500_training_ranges=ti0.15-0.4-ct0.3-0.7
# Epoch 0 ->	Training loss (MSE)=0.001509838564230538	Validation loss (MSE)=0.0011583557861356542	epoch_time (seconds)=0
# Epoch 1 ->	Training loss (MSE)=0.00018745480981235187	Validation loss (MSE)=0.0008443763722747234	epoch_time (seconds)=0
# Epoch 2 ->	Training loss (MSE)=9.673617078167408e-05	Validation loss (MSE)=0.0006493693556309084	epoch_time (seconds)=0
# Epoch 3 ->	Training loss (MSE)=6.0193033614934124e-05	Validation loss (MSE)=0.0005246868520928891	epoch_time (seconds)=0
# Epoch 4 ->	Training loss (MSE)=3.885498868041351e-05	Validation loss (MSE)=0.00043162378565375837	epoch_time (seconds)=0
# Epoch 5 ->	Training loss (MSE)=2.4730637069740445e-05	Validation loss (MSE)=0.0003661917131138452	epoch_time (seconds)=0
# Epoch 6 ->	Training loss (MSE)=1.6096116443982393e-05	Validation loss (MSE)=0.0003295135174763862	epoch_time (seconds)=0
# Epoch 7 ->	Training loss (MSE)=1.0811359580191315e-05	Validation loss (MSE)=0.00030900386400341815	epoch_time (seconds)=0
# Epoch 8 ->	Training loss (MSE)=7.948140639378037e-06	Validation loss (MSE)=0.00029111621235600556	epoch_time (seconds)=0
# Epoch 9 ->	Training loss (MSE)=6.168925428272171e-06	Validation loss (MSE)=0.0002838499964423352	epoch_time (seconds)=0
# Epoch 10 ->	Training loss (MSE)=4.696549117286894e-06	Validation loss (MSE)=0.0002776518190690683	epoch_time (seconds)=0
# Epoch 11 ->	Training loss (MSE)=3.949520533063971e-06	Validation loss (MSE)=0.00027334687527816906	epoch_time (seconds)=0
# Epoch 12 ->	Training loss (MSE)=3.389951676448307e-06	Validation loss (MSE)=0.0002631183669480978	epoch_time (seconds)=0
# Epoch 13 ->	Training loss (MSE)=2.9074301577255514e-06	Validation loss (MSE)=0.0002659242807340699	epoch_time (seconds)=0
# Epoch 14 ->	Training loss (MSE)=2.5132206881208708e-06	Validation loss (MSE)=0.0002523786136022461	epoch_time (seconds)=0
# Epoch 15 ->	Training loss (MSE)=3.0235202713101457e-06	Validation loss (MSE)=0.0002627548480892225	epoch_time (seconds)=0
# Epoch 16 ->	Training loss (MSE)=2.1491143297680536e-06	Validation loss (MSE)=0.00025631079648536805	epoch_time (seconds)=0
# Epoch 17 ->	Training loss (MSE)=1.7950136584769962e-06	Validation loss (MSE)=0.0002512137180980031	epoch_time (seconds)=0
# Epoch 18 ->	Training loss (MSE)=1.7232050711244505e-06	Validation loss (MSE)=0.0002561875649665432	epoch_time (seconds)=0
# Epoch 19 ->	Training loss (MSE)=1.4930672116905753e-06	Validation loss (MSE)=0.0002490420298529897	epoch_time (seconds)=0
# Epoch 20 ->	Training loss (MSE)=1.4890904349602174e-06	Validation loss (MSE)=0.0002491082043110156	epoch_time (seconds)=0
# Epoch 21 ->	Training loss (MSE)=1.3558274823237031e-06	Validation loss (MSE)=0.00024552245415627186	epoch_time (seconds)=0
# Epoch 22 ->	Training loss (MSE)=1.2947506784590454e-06	Validation loss (MSE)=0.0002464111344254484	epoch_time (seconds)=0
# Epoch 23 ->	Training loss (MSE)=1.2063785205588452e-06	Validation loss (MSE)=0.00024295360880211553	epoch_time (seconds)=0
# Epoch 24 ->	Training loss (MSE)=1.25190286292686e-06	Validation loss (MSE)=0.00024484909413585986	epoch_time (seconds)=0
# Epoch 25 ->	Training loss (MSE)=1.1152260946423999e-06	Validation loss (MSE)=0.00023829532102971813	epoch_time (seconds)=0
# Epoch 26 ->	Training loss (MSE)=1.12256464662118e-06	Validation loss (MSE)=0.00023642778677502972	epoch_time (seconds)=0
# Epoch 27 ->	Training loss (MSE)=1.1283509535110725e-06	Validation loss (MSE)=0.00023297491730358	epoch_time (seconds)=0
# Epoch 28 ->	Training loss (MSE)=1.1064576355926053e-06	Validation loss (MSE)=0.00023340313486880775	epoch_time (seconds)=0
# Epoch 29 ->	Training loss (MSE)=1.0766832458945673e-06	Validation loss (MSE)=0.00023214559566422336	epoch_time (seconds)=0
# Epoch 30 ->	Training loss (MSE)=1.0157661044902897e-06	Validation loss (MSE)=0.0002318376334207801	epoch_time (seconds)=0
# Epoch 31 ->	Training loss (MSE)=9.116151469664523e-07	Validation loss (MSE)=0.00023097501792136084	epoch_time (seconds)=0
# Epoch 32 ->	Training loss (MSE)=8.987393903780463e-07	Validation loss (MSE)=0.000232835435843879	epoch_time (seconds)=0
# Epoch 33 ->	Training loss (MSE)=9.225778024678797e-07	Validation loss (MSE)=0.00023193329122689983	epoch_time (seconds)=0
# Epoch 34 ->	Training loss (MSE)=9.159370536164671e-07	Validation loss (MSE)=0.0002315803215384863	epoch_time (seconds)=0
# Epoch 35 ->	Training loss (MSE)=8.845570341802114e-07	Validation loss (MSE)=0.00022954340544915263	epoch_time (seconds)=0
# Epoch 36 ->	Training loss (MSE)=8.749414443139735e-07	Validation loss (MSE)=0.0002224556325880492	epoch_time (seconds)=0
# Epoch 37 ->	Training loss (MSE)=8.604984713002057e-07	Validation loss (MSE)=0.00022081411920314302	epoch_time (seconds)=0
# Epoch 38 ->	Training loss (MSE)=9.203680238209838e-07	Validation loss (MSE)=0.00021545154660821666	epoch_time (seconds)=0
# Epoch 39 ->	Training loss (MSE)=1.0655391708784985e-06	Validation loss (MSE)=0.00022283093765311125	epoch_time (seconds)=0
# Epoch 40 ->	Training loss (MSE)=8.439592376384453e-07	Validation loss (MSE)=0.0002207259146974608	epoch_time (seconds)=0
# Epoch 41 ->	Training loss (MSE)=7.697220828448757e-07	Validation loss (MSE)=0.00021648741495149424	epoch_time (seconds)=0
# Epoch 42 ->	Training loss (MSE)=9.425952347688818e-07	Validation loss (MSE)=0.0002195753028430438	epoch_time (seconds)=0
# Epoch 43 ->	Training loss (MSE)=7.865942666007979e-07	Validation loss (MSE)=0.00021882457231771823	epoch_time (seconds)=0
# Epoch 44 ->	Training loss (MSE)=7.778337390934722e-07	Validation loss (MSE)=0.00021841849371669923	epoch_time (seconds)=0
# Epoch 45 ->	Training loss (MSE)=7.568964249679905e-07	Validation loss (MSE)=0.00021697528582666692	epoch_time (seconds)=0
# Epoch 46 ->	Training loss (MSE)=7.371793363501372e-07	Validation loss (MSE)=0.0002209497736781686	epoch_time (seconds)=0
# Epoch 47 ->	Training loss (MSE)=7.964861804089751e-07	Validation loss (MSE)=0.0002162920006163863	epoch_time (seconds)=0
# Epoch 48 ->	Training loss (MSE)=7.084880450370625e-07	Validation loss (MSE)=0.00021084274687234374	epoch_time (seconds)=0
# Epoch 49 ->	Training loss (MSE)=7.891686134537783e-07	Validation loss (MSE)=0.00021543924893371055	epoch_time (seconds)=0
# Epoch 50 ->	Training loss (MSE)=7.052083205741017e-07	Validation loss (MSE)=0.000213455481740175	epoch_time (seconds)=0
# Epoch 51 ->	Training loss (MSE)=6.832682002246523e-07	Validation loss (MSE)=0.00021373836069213918	epoch_time (seconds)=0
# Epoch 52 ->	Training loss (MSE)=6.40391778006233e-07	Validation loss (MSE)=0.00021332246002469726	epoch_time (seconds)=0
# Epoch 53 ->	Training loss (MSE)=6.464162481456808e-07	Validation loss (MSE)=0.00021101446036328567	epoch_time (seconds)=0
# Epoch 54 ->	Training loss (MSE)=6.40416786337682e-07	Validation loss (MSE)=0.00021510446543604678	epoch_time (seconds)=0
# Epoch 55 ->	Training loss (MSE)=7.018561317880351e-07	Validation loss (MSE)=0.00021289573122642506	epoch_time (seconds)=0
# Epoch 56 ->	Training loss (MSE)=6.381059619559714e-07	Validation loss (MSE)=0.00021378200933857945	epoch_time (seconds)=0
# Epoch 57 ->	Training loss (MSE)=6.137001983366955e-07	Validation loss (MSE)=0.00021104052891316032	epoch_time (seconds)=0
# Epoch 58 ->	Training loss (MSE)=5.989461973923626e-07	Validation loss (MSE)=0.0002115198150803281	epoch_time (seconds)=0
# Epoch 59 ->	Training loss (MSE)=5.901214668239579e-07	Validation loss (MSE)=0.00020745193139269335	epoch_time (seconds)=0
# Epoch 60 ->	Training loss (MSE)=6.285822326212727e-07	Validation loss (MSE)=0.00020588081963584043	epoch_time (seconds)=0
# Epoch 61 ->	Training loss (MSE)=7.0007665349627e-07	Validation loss (MSE)=0.00020506142184948165	epoch_time (seconds)=0
# Epoch 62 ->	Training loss (MSE)=7.836498997032944e-07	Validation loss (MSE)=0.0002097567982126889	epoch_time (seconds)=0
# Epoch 63 ->	Training loss (MSE)=6.035559251758081e-07	Validation loss (MSE)=0.0002072943126993724	epoch_time (seconds)=0
# Epoch 64 ->	Training loss (MSE)=5.623702978072088e-07	Validation loss (MSE)=0.0002081020920491436	epoch_time (seconds)=0
# Epoch 65 ->	Training loss (MSE)=5.65478035186083e-07	Validation loss (MSE)=0.00020738434081972373	epoch_time (seconds)=0
# Epoch 66 ->	Training loss (MSE)=5.585803835568119e-07	Validation loss (MSE)=0.00020619382354167292	epoch_time (seconds)=0
# Epoch 67 ->	Training loss (MSE)=5.505294831348182e-07	Validation loss (MSE)=0.00020677765672217558	epoch_time (seconds)=0
# Epoch 68 ->	Training loss (MSE)=5.397824226592337e-07	Validation loss (MSE)=0.00020717553855357604	epoch_time (seconds)=0
# Epoch 69 ->	Training loss (MSE)=5.423935326744845e-07	Validation loss (MSE)=0.00020698599363436259	epoch_time (seconds)=0
# Epoch 70 ->	Training loss (MSE)=4.858254993262274e-07	Validation loss (MSE)=0.0002082852280405896	epoch_time (seconds)=0
# Epoch 71 ->	Training loss (MSE)=5.249984496358814e-07	Validation loss (MSE)=0.0002070100547421533	epoch_time (seconds)=0
# Epoch 72 ->	Training loss (MSE)=5.735725013470606e-07	Validation loss (MSE)=0.00020522919519808843	epoch_time (seconds)=0
# Epoch 73 ->	Training loss (MSE)=4.7517681158607467e-07	Validation loss (MSE)=0.00020679041163721972	epoch_time (seconds)=0
# Epoch 74 ->	Training loss (MSE)=4.676972907152337e-07	Validation loss (MSE)=0.00020645161794211888	epoch_time (seconds)=0
# Epoch 75 ->	Training loss (MSE)=4.702917604088437e-07	Validation loss (MSE)=0.00020668606112852255	epoch_time (seconds)=0
# Epoch 76 ->	Training loss (MSE)=4.41329959833516e-07	Validation loss (MSE)=0.0002067407610863811	epoch_time (seconds)=0
# Epoch 77 ->	Training loss (MSE)=4.318245115572187e-07	Validation loss (MSE)=0.00020449627169930113	epoch_time (seconds)=0
# Epoch 78 ->	Training loss (MSE)=5.182511764116232e-07	Validation loss (MSE)=0.00020413444170774055	epoch_time (seconds)=0
# Epoch 79 ->	Training loss (MSE)=5.172785330110057e-07	Validation loss (MSE)=0.00020574313863374808	epoch_time (seconds)=0
# Epoch 80 ->	Training loss (MSE)=4.2920558102440093e-07	Validation loss (MSE)=0.00020718244009517494	epoch_time (seconds)=0
# Epoch 81 ->	Training loss (MSE)=4.5738537129714465e-07	Validation loss (MSE)=0.00020648076819426085	epoch_time (seconds)=0
# Epoch 82 ->	Training loss (MSE)=4.3612953568410334e-07	Validation loss (MSE)=0.00020706182099087606	epoch_time (seconds)=0
# Epoch 83 ->	Training loss (MSE)=4.176962684086015e-07	Validation loss (MSE)=0.0002081111203370185	epoch_time (seconds)=0
# Epoch 84 ->	Training loss (MSE)=4.906967970372335e-07	Validation loss (MSE)=0.00020826377160269413	epoch_time (seconds)=0
# Epoch 85 ->	Training loss (MSE)=5.242558036781436e-07	Validation loss (MSE)=0.0002046000357519849	epoch_time (seconds)=0
# Epoch 86 ->	Training loss (MSE)=4.504886999950209e-07	Validation loss (MSE)=0.00020431860032849852	epoch_time (seconds)=0
# Epoch 87 ->	Training loss (MSE)=4.303804203825565e-07	Validation loss (MSE)=0.0002032906666820684	epoch_time (seconds)=0
# Epoch 88 ->	Training loss (MSE)=4.383925450317137e-07	Validation loss (MSE)=0.00020528326332315886	epoch_time (seconds)=0
# Epoch 89 ->	Training loss (MSE)=4.0024525102991194e-07	Validation loss (MSE)=0.00020555272779106373	epoch_time (seconds)=0
# Epoch 90 ->	Training loss (MSE)=4.0814833549275804e-07	Validation loss (MSE)=0.00020543252768050565	epoch_time (seconds)=0
# Epoch 91 ->	Training loss (MSE)=4.169046923429849e-07	Validation loss (MSE)=0.00020345525500519985	epoch_time (seconds)=0
# Epoch 92 ->	Training loss (MSE)=4.0401447585636784e-07	Validation loss (MSE)=0.00020478310399327856	epoch_time (seconds)=0
# Epoch 93 ->	Training loss (MSE)=3.799272077222535e-07	Validation loss (MSE)=0.00020376136018147194	epoch_time (seconds)=0
# Epoch 94 ->	Training loss (MSE)=3.3596589664822627e-07	Validation loss (MSE)=0.00020438015311668748	epoch_time (seconds)=0
# Epoch 95 ->	Training loss (MSE)=3.2341519869305556e-07	Validation loss (MSE)=0.00020335044475125274	epoch_time (seconds)=0
# Epoch 96 ->	Training loss (MSE)=3.2577552923523797e-07	Validation loss (MSE)=0.00020334078197221448	epoch_time (seconds)=0
# Epoch 97 ->	Training loss (MSE)=4.049342143245179e-07	Validation loss (MSE)=0.000202896691724897	epoch_time (seconds)=0
# Epoch 98 ->	Training loss (MSE)=3.587078322613995e-07	Validation loss (MSE)=0.00020377118535189366	epoch_time (seconds)=0
# Epoch 99 ->	Training loss (MSE)=3.198297760147353e-07	Validation loss (MSE)=0.0002019063857662587	epoch_time (seconds)=0
# Epoch 100 ->	Training loss (MSE)=3.2680873533001056e-07	Validation loss (MSE)=0.00020325149478559967	epoch_time (seconds)=0
# Epoch 101 ->	Training loss (MSE)=3.021765798632437e-07	Validation loss (MSE)=0.00020248674835339524	epoch_time (seconds)=0
# Epoch 102 ->	Training loss (MSE)=3.3054585423442627e-07	Validation loss (MSE)=0.0002026468728035403	epoch_time (seconds)=0
# Epoch 103 ->	Training loss (MSE)=2.9327418654402874e-07	Validation loss (MSE)=0.00020126866523020065	epoch_time (seconds)=0
# Epoch 104 ->	Training loss (MSE)=3.187960794271132e-07	Validation loss (MSE)=0.00020246341986615611	epoch_time (seconds)=0
# Epoch 105 ->	Training loss (MSE)=3.084766425084725e-07	Validation loss (MSE)=0.0002072662933169763	epoch_time (seconds)=0
# Epoch 106 ->	Training loss (MSE)=3.9254320424289487e-07	Validation loss (MSE)=0.00020309756648564	epoch_time (seconds)=0
# Epoch 107 ->	Training loss (MSE)=3.1684898658568274e-07	Validation loss (MSE)=0.0002042609541225783	epoch_time (seconds)=0
# Epoch 108 ->	Training loss (MSE)=4.176585353866912e-07	Validation loss (MSE)=0.00020387033657038068	epoch_time (seconds)=0
# Epoch 109 ->	Training loss (MSE)=3.0767934486159833e-07	Validation loss (MSE)=0.00020461158026115518	epoch_time (seconds)=0
# Epoch 110 ->	Training loss (MSE)=2.9961957791994526e-07	Validation loss (MSE)=0.00020316774872858903	epoch_time (seconds)=0
# Epoch 111 ->	Training loss (MSE)=3.024814051855174e-07	Validation loss (MSE)=0.00020174934908808156	epoch_time (seconds)=0
# Epoch 112 ->	Training loss (MSE)=2.8493768717808273e-07	Validation loss (MSE)=0.00019961563428866832	epoch_time (seconds)=0
# Epoch 113 ->	Training loss (MSE)=3.4845025935260866e-07	Validation loss (MSE)=0.00020220829476639255	epoch_time (seconds)=0
# Epoch 114 ->	Training loss (MSE)=3.16103117023797e-07	Validation loss (MSE)=0.0002002804095242438	epoch_time (seconds)=0
# Epoch 115 ->	Training loss (MSE)=3.4817360569111147e-07	Validation loss (MSE)=0.00020402374876138914	epoch_time (seconds)=0
# Epoch 116 ->	Training loss (MSE)=2.929460624769246e-07	Validation loss (MSE)=0.00020397398327039643	epoch_time (seconds)=0
# Epoch 117 ->	Training loss (MSE)=2.6753569008034415e-07	Validation loss (MSE)=0.00020134180971756165	epoch_time (seconds)=0
# Epoch 118 ->	Training loss (MSE)=2.6697145395845414e-07	Validation loss (MSE)=0.00020515091156433587	epoch_time (seconds)=0
# Epoch 119 ->	Training loss (MSE)=2.4858811052470674e-07	Validation loss (MSE)=0.0002025642049865927	epoch_time (seconds)=0
# Epoch 120 ->	Training loss (MSE)=2.7259316111417873e-07	Validation loss (MSE)=0.00020455581292722947	epoch_time (seconds)=0
# Epoch 121 ->	Training loss (MSE)=2.480581933673975e-07	Validation loss (MSE)=0.00020139795057625543	epoch_time (seconds)=0
# Epoch 122 ->	Training loss (MSE)=3.1076900502811685e-07	Validation loss (MSE)=0.00020526233147642918	epoch_time (seconds)=0
# Epoch 123 ->	Training loss (MSE)=2.4826468802530144e-07	Validation loss (MSE)=0.0002048216482212348	epoch_time (seconds)=0
# Epoch 124 ->	Training loss (MSE)=2.6679164717479135e-07	Validation loss (MSE)=0.00020522082775463414	epoch_time (seconds)=0
# Epoch 125 ->	Training loss (MSE)=2.824150902408913e-07	Validation loss (MSE)=0.0002023842319699374	epoch_time (seconds)=0
# Epoch 126 ->	Training loss (MSE)=2.824482369416684e-07	Validation loss (MSE)=0.00020714919642154855	epoch_time (seconds)=0
# Epoch 127 ->	Training loss (MSE)=2.950127549045247e-07	Validation loss (MSE)=0.00020651881621266423	epoch_time (seconds)=0
# Epoch 128 ->	Training loss (MSE)=2.387821953328878e-07	Validation loss (MSE)=0.00020880798465085985	epoch_time (seconds)=0
# Epoch 129 ->	Training loss (MSE)=2.939934864798488e-07	Validation loss (MSE)=0.00020254279596919396	epoch_time (seconds)=0
# Epoch 130 ->	Training loss (MSE)=2.7782583415722824e-07	Validation loss (MSE)=0.00020854791924502473	epoch_time (seconds)=0
# Epoch 131 ->	Training loss (MSE)=2.804196320378806e-07	Validation loss (MSE)=0.00020288933729143162	epoch_time (seconds)=0
# Epoch 132 ->	Training loss (MSE)=2.546112234512759e-07	Validation loss (MSE)=0.0002009966657326115	epoch_time (seconds)=0
# Epoch 133 ->	Training loss (MSE)=3.179672719896899e-07	Validation loss (MSE)=0.0002042640986577721	epoch_time (seconds)=0
# Epoch 134 ->	Training loss (MSE)=3.018558498008976e-07	Validation loss (MSE)=0.00020431133611076104	epoch_time (seconds)=0
# Epoch 135 ->	Training loss (MSE)=2.1992194665084e-07	Validation loss (MSE)=0.00020410234545339823	epoch_time (seconds)=0
# Epoch 136 ->	Training loss (MSE)=2.134372238684569e-07	Validation loss (MSE)=0.00020465149378284532	epoch_time (seconds)=0
# Epoch 137 ->	Training loss (MSE)=1.9522499371760206e-07	Validation loss (MSE)=0.0002047640713021	epoch_time (seconds)=0
# Epoch 138 ->	Training loss (MSE)=2.1057262177059674e-07	Validation loss (MSE)=0.00020405195659646566	epoch_time (seconds)=0
# Epoch 139 ->	Training loss (MSE)=2.74170631198059e-07	Validation loss (MSE)=0.00020748362500307081	epoch_time (seconds)=0
# Epoch 140 ->	Training loss (MSE)=2.159097216574038e-07	Validation loss (MSE)=0.00020662512555974117	epoch_time (seconds)=0
# Epoch 141 ->	Training loss (MSE)=2.217249140990245e-07	Validation loss (MSE)=0.00021103092613964367	epoch_time (seconds)=0
# Epoch 142 ->	Training loss (MSE)=4.066565509497084e-07	Validation loss (MSE)=0.0002078116851778398	epoch_time (seconds)=0
# Epoch 143 ->	Training loss (MSE)=3.643106351330239e-07	Validation loss (MSE)=0.00021029999639153964	epoch_time (seconds)=0
# Epoch 144 ->	Training loss (MSE)=4.0493603183044685e-07	Validation loss (MSE)=0.00020564345341990086	epoch_time (seconds)=0
# Epoch 145 ->	Training loss (MSE)=2.558965168856691e-07	Validation loss (MSE)=0.00020488053281511717	epoch_time (seconds)=0
# Epoch 146 ->	Training loss (MSE)=2.668337958489357e-07	Validation loss (MSE)=0.00020696230829482428	epoch_time (seconds)=0
# Epoch 147 ->	Training loss (MSE)=2.229573898694625e-07	Validation loss (MSE)=0.00020358207251853483	epoch_time (seconds)=0
# Epoch 148 ->	Training loss (MSE)=2.2382094124534378e-07	Validation loss (MSE)=0.00020448870315138297	epoch_time (seconds)=0
# Epoch 149 ->	Training loss (MSE)=2.389362677975929e-07	Validation loss (MSE)=0.0002047800162674096	epoch_time (seconds)=0
# Epoch 150 ->	Training loss (MSE)=2.0474475570054205e-07	Validation loss (MSE)=0.00020776776891138303	epoch_time (seconds)=0
# Epoch 151 ->	Training loss (MSE)=2.261753940393735e-07	Validation loss (MSE)=0.00020612776354744485	epoch_time (seconds)=0
# Epoch 152 ->	Training loss (MSE)=1.9721998689985367e-07	Validation loss (MSE)=0.00020865810969699402	epoch_time (seconds)=0
# Epoch 153 ->	Training loss (MSE)=2.3612734188751212e-07	Validation loss (MSE)=0.00020795306614651752	epoch_time (seconds)=0
# Epoch 154 ->	Training loss (MSE)=2.1501653740520718e-07	Validation loss (MSE)=0.00020502733290473287	epoch_time (seconds)=0
# Epoch 155 ->	Training loss (MSE)=1.9358157375358486e-07	Validation loss (MSE)=0.00020381324301454618	epoch_time (seconds)=0
# Epoch 156 ->	Training loss (MSE)=3.379655461937945e-07	Validation loss (MSE)=0.00020512115093080353	epoch_time (seconds)=0
# Epoch 157 ->	Training loss (MSE)=2.258829884356867e-07	Validation loss (MSE)=0.00020798213643227423	epoch_time (seconds)=0
# Epoch 158 ->	Training loss (MSE)=2.443403261262264e-07	Validation loss (MSE)=0.00020654669732881616	epoch_time (seconds)=0
# Epoch 159 ->	Training loss (MSE)=2.0305725048335329e-07	Validation loss (MSE)=0.00020646170513921269	epoch_time (seconds)=0
# Epoch 160 ->	Training loss (MSE)=1.9330289889261975e-07	Validation loss (MSE)=0.000209146772460656	epoch_time (seconds)=0
# Epoch 161 ->	Training loss (MSE)=2.250370204206974e-07	Validation loss (MSE)=0.00020634130746374004	epoch_time (seconds)=0
# Epoch 162 ->	Training loss (MSE)=1.8723099470862064e-07	Validation loss (MSE)=0.00020867004358898574	epoch_time (seconds)=0
# Epoch 163 ->	Training loss (MSE)=2.503633486301668e-07	Validation loss (MSE)=0.00020328796157783534	epoch_time (seconds)=0
# Epoch 164 ->	Training loss (MSE)=2.9454690492479485e-07	Validation loss (MSE)=0.00020835830453193698	epoch_time (seconds)=0
# Epoch 165 ->	Training loss (MSE)=2.84537594275318e-07	Validation loss (MSE)=0.00020688824253446898	epoch_time (seconds)=0
# Epoch 166 ->	Training loss (MSE)=1.894375470617045e-07	Validation loss (MSE)=0.00020260415432719984	epoch_time (seconds)=0
# Epoch 167 ->	Training loss (MSE)=3.1618346443382305e-07	Validation loss (MSE)=0.00020446626369857623	epoch_time (seconds)=0
# Epoch 168 ->	Training loss (MSE)=2.2952298949939532e-07	Validation loss (MSE)=0.00020518340340949724	epoch_time (seconds)=0
# Epoch 169 ->	Training loss (MSE)=1.7965417533205034e-07	Validation loss (MSE)=0.0002033657063143682	epoch_time (seconds)=0
# Epoch 170 ->	Training loss (MSE)=2.0875902005561173e-07	Validation loss (MSE)=0.00020303022281887304	epoch_time (seconds)=0
# Epoch 171 ->	Training loss (MSE)=2.1418394262249553e-07	Validation loss (MSE)=0.00020812734799671508	epoch_time (seconds)=0
# Epoch 172 ->	Training loss (MSE)=2.909617895475427e-07	Validation loss (MSE)=0.00020654996142942958	epoch_time (seconds)=0
# Epoch 173 ->	Training loss (MSE)=1.8071745992434753e-07	Validation loss (MSE)=0.00020761152338411132	epoch_time (seconds)=0
# Epoch 174 ->	Training loss (MSE)=2.1567272491798888e-07	Validation loss (MSE)=0.0002026356763878607	epoch_time (seconds)=0
# Epoch 175 ->	Training loss (MSE)=2.8071514276877964e-07	Validation loss (MSE)=0.00020760210053496152	epoch_time (seconds)=0
# Epoch 176 ->	Training loss (MSE)=2.3873245482502346e-07	Validation loss (MSE)=0.0002054379141633571	epoch_time (seconds)=0
# Epoch 177 ->	Training loss (MSE)=1.715094211293745e-07	Validation loss (MSE)=0.0002114986917383845	epoch_time (seconds)=0
# Epoch 178 ->	Training loss (MSE)=5.635049570273401e-07	Validation loss (MSE)=0.00020528478936883283	epoch_time (seconds)=0
# Epoch 179 ->	Training loss (MSE)=3.1223970451009804e-07	Validation loss (MSE)=0.00020487698929314526	epoch_time (seconds)=0
# Epoch 180 ->	Training loss (MSE)=1.9717210595511615e-07	Validation loss (MSE)=0.00020224561377533209	epoch_time (seconds)=0
# Epoch 181 ->	Training loss (MSE)=4.325819245201362e-07	Validation loss (MSE)=0.00020714929845398478	epoch_time (seconds)=0
# Epoch 182 ->	Training loss (MSE)=4.2632760760059727e-07	Validation loss (MSE)=0.00020239480452795454	epoch_time (seconds)=0
# Epoch 183 ->	Training loss (MSE)=3.454536564310352e-07	Validation loss (MSE)=0.0002029491046349171	epoch_time (seconds)=0
# Epoch 184 ->	Training loss (MSE)=4.3893824978312763e-07	Validation loss (MSE)=0.00020485640029998747	epoch_time (seconds)=0
# Epoch 185 ->	Training loss (MSE)=2.7606443381955614e-07	Validation loss (MSE)=0.0002054327381224054	epoch_time (seconds)=0
# Epoch 186 ->	Training loss (MSE)=1.889392691592969e-07	Validation loss (MSE)=0.0002024986815231694	epoch_time (seconds)=0
# Epoch 187 ->	Training loss (MSE)=2.1363762848190296e-07	Validation loss (MSE)=0.00021108353873513198	epoch_time (seconds)=0
# Epoch 188 ->	Training loss (MSE)=4.481328751602987e-07	Validation loss (MSE)=0.00020643219285631806	epoch_time (seconds)=0
# Epoch 189 ->	Training loss (MSE)=2.2254814377597208e-07	Validation loss (MSE)=0.00020307225667907922	epoch_time (seconds)=0
# Epoch 190 ->	Training loss (MSE)=1.9364854142206862e-07	Validation loss (MSE)=0.00020502205118952456	epoch_time (seconds)=0
# Epoch 191 ->	Training loss (MSE)=1.9532520494943506e-07	Validation loss (MSE)=0.0002068232497319121	epoch_time (seconds)=0
# Epoch 192 ->	Training loss (MSE)=2.5064409759657215e-07	Validation loss (MSE)=0.00020385169596649774	epoch_time (seconds)=0
# Epoch 193 ->	Training loss (MSE)=2.2367303492595655e-07	Validation loss (MSE)=0.00020164910850430806	epoch_time (seconds)=0
# Epoch 194 ->	Training loss (MSE)=1.798010126346925e-07	Validation loss (MSE)=0.00020217383100610393	epoch_time (seconds)=0
# Epoch 195 ->	Training loss (MSE)=2.1086133682224612e-07	Validation loss (MSE)=0.00020485897706462602	epoch_time (seconds)=0
# Epoch 196 ->	Training loss (MSE)=1.7526797581528694e-07	Validation loss (MSE)=0.0002060045029401559	epoch_time (seconds)=0
# Epoch 197 ->	Training loss (MSE)=2.417928302326423e-07	Validation loss (MSE)=0.00020270543425885318	epoch_time (seconds)=0
# Epoch 198 ->	Training loss (MSE)=3.1759694454011677e-07	Validation loss (MSE)=0.00020524811920320956	epoch_time (seconds)=0
# Epoch 199 ->	Training loss (MSE)=2.571416593316205e-07	Validation loss (MSE)=0.0002003478624609888	epoch_time (seconds)=0
# Epoch 200 ->	Training loss (MSE)=3.852321666416662e-07	Validation loss (MSE)=0.00020518804399528734	epoch_time (seconds)=0
# Epoch 201 ->	Training loss (MSE)=2.5170274653874e-07	Validation loss (MSE)=0.0002083815726294962	epoch_time (seconds)=0
# Epoch 202 ->	Training loss (MSE)=2.644540062308851e-07	Validation loss (MSE)=0.0002049194527037615	epoch_time (seconds)=0
# Epoch 203 ->	Training loss (MSE)=1.9287608615852106e-07	Validation loss (MSE)=0.00020478340972179533	epoch_time (seconds)=0
# Epoch 204 ->	Training loss (MSE)=1.7891704264523625e-07	Validation loss (MSE)=0.00020247902790929752	epoch_time (seconds)=0
# Epoch 205 ->	Training loss (MSE)=1.7369433710261613e-07	Validation loss (MSE)=0.00020315703996341605	epoch_time (seconds)=0
# Epoch 206 ->	Training loss (MSE)=1.7400542226479912e-07	Validation loss (MSE)=0.00020307055249153277	epoch_time (seconds)=0
# Epoch 207 ->	Training loss (MSE)=1.928162552817911e-07	Validation loss (MSE)=0.00020247701221549395	epoch_time (seconds)=0
# Epoch 208 ->	Training loss (MSE)=2.230343055937671e-07	Validation loss (MSE)=0.0002019390313515593	epoch_time (seconds)=0
# Epoch 209 ->	Training loss (MSE)=2.158904417422868e-07	Validation loss (MSE)=0.00020504112126698586	epoch_time (seconds)=0
# Epoch 210 ->	Training loss (MSE)=2.0748059300120343e-07	Validation loss (MSE)=0.00020215659224184342	epoch_time (seconds)=0
# Epoch 211 ->	Training loss (MSE)=1.763511584879491e-07	Validation loss (MSE)=0.00020395830056225387	epoch_time (seconds)=0
# Epoch 212 ->	Training loss (MSE)=1.6309648367634908e-07	Validation loss (MSE)=0.00020101735090363355	epoch_time (seconds)=0
# Epoch 213 ->	Training loss (MSE)=1.8599204131865785e-07	Validation loss (MSE)=0.0002047634666677173	epoch_time (seconds)=0
# Epoch 214 ->	Training loss (MSE)=1.9853234354142353e-07	Validation loss (MSE)=0.0002072560225229626	epoch_time (seconds)=0
# Epoch 215 ->	Training loss (MSE)=4.775172580299868e-07	Validation loss (MSE)=0.00019923285726844328	epoch_time (seconds)=0
# Epoch 216 ->	Training loss (MSE)=4.934030533277331e-07	Validation loss (MSE)=0.00020257454540545107	epoch_time (seconds)=0
# Epoch 217 ->	Training loss (MSE)=2.0034482786730045e-07	Validation loss (MSE)=0.0001906802744526955	epoch_time (seconds)=0
# Epoch 218 ->	Training loss (MSE)=2.677251978727837e-06	Validation loss (MSE)=0.00020172240368927482	epoch_time (seconds)=0
# Epoch 219 ->	Training loss (MSE)=7.64251820261806e-07	Validation loss (MSE)=0.00020859818902826025	epoch_time (seconds)=0
# Epoch 220 ->	Training loss (MSE)=5.501058989821325e-07	Validation loss (MSE)=0.0002022725747094992	epoch_time (seconds)=0
# Epoch 221 ->	Training loss (MSE)=2.393545945024681e-07	Validation loss (MSE)=0.00019701772156835817	epoch_time (seconds)=0
# Epoch 222 ->	Training loss (MSE)=6.480998821388777e-07	Validation loss (MSE)=0.00020218431503868955	epoch_time (seconds)=0
# Epoch 223 ->	Training loss (MSE)=2.1840514687194562e-07	Validation loss (MSE)=0.00020345799658910216	epoch_time (seconds)=0
# Epoch 224 ->	Training loss (MSE)=2.006844413133921e-07	Validation loss (MSE)=0.0002101697519713169	epoch_time (seconds)=0
# Epoch 225 ->	Training loss (MSE)=5.310946950036917e-07	Validation loss (MSE)=0.00020927325843003852	epoch_time (seconds)=0
# Epoch 226 ->	Training loss (MSE)=4.082980519630904e-07	Validation loss (MSE)=0.00019308829551253865	epoch_time (seconds)=0
# Epoch 227 ->	Training loss (MSE)=1.4253442104634858e-06	Validation loss (MSE)=0.0001991220189258702	epoch_time (seconds)=0
# Epoch 228 ->	Training loss (MSE)=3.7169264717748573e-07	Validation loss (MSE)=0.00020468163570114278	epoch_time (seconds)=0
# Epoch 229 ->	Training loss (MSE)=4.467944482274372e-07	Validation loss (MSE)=0.00019907070257257938	epoch_time (seconds)=0
# Epoch 230 ->	Training loss (MSE)=1.796808358521292e-07	Validation loss (MSE)=0.00019553915883988287	epoch_time (seconds)=0
# Epoch 231 ->	Training loss (MSE)=2.9218128031932173e-07	Validation loss (MSE)=0.0002001839837089128	epoch_time (seconds)=0
# Epoch 232 ->	Training loss (MSE)=1.8060230319899968e-07	Validation loss (MSE)=0.00019832475689215704	epoch_time (seconds)=0
# Epoch 233 ->	Training loss (MSE)=1.9367110385745745e-07	Validation loss (MSE)=0.00019868733669919334	epoch_time (seconds)=0
# Epoch 234 ->	Training loss (MSE)=2.0540304148414912e-07	Validation loss (MSE)=0.0002009870826587309	epoch_time (seconds)=0
# Epoch 235 ->	Training loss (MSE)=1.7244242760708825e-07	Validation loss (MSE)=0.00020387387454510718	epoch_time (seconds)=0
# Epoch 236 ->	Training loss (MSE)=2.168465125134567e-07	Validation loss (MSE)=0.0002050985487178214	epoch_time (seconds)=0
# Epoch 237 ->	Training loss (MSE)=3.060565080173968e-07	Validation loss (MSE)=0.00020204450091329396	epoch_time (seconds)=0
# Epoch 238 ->	Training loss (MSE)=1.936066920701173e-07	Validation loss (MSE)=0.0002024905725567648	epoch_time (seconds)=0
# Epoch 239 ->	Training loss (MSE)=2.157089376695938e-07	Validation loss (MSE)=0.00019395984462786903	epoch_time (seconds)=0
# Epoch 240 ->	Training loss (MSE)=4.4653921720066316e-07	Validation loss (MSE)=0.00019898459151433437	epoch_time (seconds)=0
# Epoch 241 ->	Training loss (MSE)=1.613716270229616e-07	Validation loss (MSE)=0.00019808791751086755	epoch_time (seconds)=0
# Epoch 242 ->	Training loss (MSE)=1.4570553280075884e-07	Validation loss (MSE)=0.0001953074130745469	epoch_time (seconds)=0
# Epoch 243 ->	Training loss (MSE)=3.4168620891805184e-07	Validation loss (MSE)=0.0001867832650853136	epoch_time (seconds)=0
# Epoch 244 ->	Training loss (MSE)=1.704206721786072e-06	Validation loss (MSE)=0.00019986534123557276	epoch_time (seconds)=0
# Epoch 245 ->	Training loss (MSE)=5.294769741850337e-07	Validation loss (MSE)=0.0002014759592448854	epoch_time (seconds)=0
# Epoch 246 ->	Training loss (MSE)=3.8686993265422997e-07	Validation loss (MSE)=0.00019966404408512984	epoch_time (seconds)=0
# Epoch 247 ->	Training loss (MSE)=1.8832752322473757e-07	Validation loss (MSE)=0.00019555571192773227	epoch_time (seconds)=0
# Epoch 248 ->	Training loss (MSE)=2.3822688201950614e-07	Validation loss (MSE)=0.00019516619866152826	epoch_time (seconds)=0
# Epoch 249 ->	Training loss (MSE)=3.270114354990721e-07	Validation loss (MSE)=0.00019737502042850265	epoch_time (seconds)=0
# Epoch 250 ->	Training loss (MSE)=1.6023770729411698e-07	Validation loss (MSE)=0.00019396217972622376	epoch_time (seconds)=0
# Epoch 251 ->	Training loss (MSE)=3.631469719188894e-07	Validation loss (MSE)=0.00019764226845685892	epoch_time (seconds)=0
# Epoch 252 ->	Training loss (MSE)=1.7534323409641153e-07	Validation loss (MSE)=0.0001981134411245545	epoch_time (seconds)=0
# Epoch 253 ->	Training loss (MSE)=1.5688709053706145e-07	Validation loss (MSE)=0.00019900278767783278	epoch_time (seconds)=0
# Epoch 254 ->	Training loss (MSE)=1.3750106530751066e-07	Validation loss (MSE)=0.00020417835768223706	epoch_time (seconds)=0
# Epoch 255 ->	Training loss (MSE)=3.1663839667139544e-07	Validation loss (MSE)=0.00020099857049687335	epoch_time (seconds)=0
# Epoch 256 ->	Training loss (MSE)=1.5657123628135728e-07	Validation loss (MSE)=0.0001995216905660121	epoch_time (seconds)=0
# Epoch 257 ->	Training loss (MSE)=1.2689535946897306e-07	Validation loss (MSE)=0.0002020166742400519	epoch_time (seconds)=0
# Epoch 258 ->	Training loss (MSE)=1.7428895174783442e-07	Validation loss (MSE)=0.0001977146657563868	epoch_time (seconds)=0
# Epoch 259 ->	Training loss (MSE)=2.019927257270954e-07	Validation loss (MSE)=0.00020057117344760911	epoch_time (seconds)=0
# Epoch 260 ->	Training loss (MSE)=1.520440700249576e-07	Validation loss (MSE)=0.000199692664029831	epoch_time (seconds)=0
# Epoch 261 ->	Training loss (MSE)=1.9578884315173703e-07	Validation loss (MSE)=0.00020391544822980615	epoch_time (seconds)=0
# Epoch 262 ->	Training loss (MSE)=3.898270415863696e-07	Validation loss (MSE)=0.00020120851260670407	epoch_time (seconds)=0
# Epoch 263 ->	Training loss (MSE)=1.8875537634590818e-07	Validation loss (MSE)=0.0001975210990535229	epoch_time (seconds)=0
# Epoch 264 ->	Training loss (MSE)=2.2375930099753266e-07	Validation loss (MSE)=0.00019946688788423242	epoch_time (seconds)=0
# Epoch 265 ->	Training loss (MSE)=1.4495997897633636e-07	Validation loss (MSE)=0.00020152664147580482	epoch_time (seconds)=0
# Epoch 266 ->	Training loss (MSE)=1.5799902836472871e-07	Validation loss (MSE)=0.00019938673418339286	epoch_time (seconds)=0
# Epoch 267 ->	Training loss (MSE)=1.2707635424889548e-07	Validation loss (MSE)=0.000196922639584751	epoch_time (seconds)=0
# Epoch 268 ->	Training loss (MSE)=1.497280872624243e-07	Validation loss (MSE)=0.00019917096377796873	epoch_time (seconds)=0
# Epoch 269 ->	Training loss (MSE)=1.3344767722162764e-07	Validation loss (MSE)=0.00020509012271328057	epoch_time (seconds)=0
# Epoch 270 ->	Training loss (MSE)=3.233559234226183e-07	Validation loss (MSE)=0.00019539365241092108	epoch_time (seconds)=0
# Epoch 271 ->	Training loss (MSE)=4.140632726619781e-07	Validation loss (MSE)=0.00020206327047142463	epoch_time (seconds)=0
# Epoch 272 ->	Training loss (MSE)=3.226680264117199e-07	Validation loss (MSE)=0.00020294141788918272	epoch_time (seconds)=0
# Epoch 273 ->	Training loss (MSE)=1.6901062198063832e-07	Validation loss (MSE)=0.00019931667454839696	epoch_time (seconds)=0
# Epoch 274 ->	Training loss (MSE)=1.290219149418257e-07	Validation loss (MSE)=0.0002020345741406933	epoch_time (seconds)=0
# Epoch 275 ->	Training loss (MSE)=1.7068219963720166e-07	Validation loss (MSE)=0.00019937535773578209	epoch_time (seconds)=0
# Epoch 276 ->	Training loss (MSE)=1.4013710599362263e-07	Validation loss (MSE)=0.00019822662187985577	epoch_time (seconds)=0
# Epoch 277 ->	Training loss (MSE)=1.560991679366175e-07	Validation loss (MSE)=0.0001980461453546405	epoch_time (seconds)=0
# Epoch 278 ->	Training loss (MSE)=1.1846470194663331e-07	Validation loss (MSE)=0.0001958475199932726	epoch_time (seconds)=0
# Epoch 279 ->	Training loss (MSE)=2.364497315905216e-07	Validation loss (MSE)=0.00019937400340885435	epoch_time (seconds)=0
# Epoch 280 ->	Training loss (MSE)=1.5666541661015045e-07	Validation loss (MSE)=0.00019438825336561775	epoch_time (seconds)=0
# Epoch 281 ->	Training loss (MSE)=2.6139199250581707e-07	Validation loss (MSE)=0.00020133214584751392	epoch_time (seconds)=0
# Epoch 282 ->	Training loss (MSE)=2.4179261656377646e-07	Validation loss (MSE)=0.0001967887251930205	epoch_time (seconds)=0
# Epoch 283 ->	Training loss (MSE)=1.8948480644791922e-07	Validation loss (MSE)=0.0002015334847943765	epoch_time (seconds)=0
# Epoch 284 ->	Training loss (MSE)=2.070119122746713e-07	Validation loss (MSE)=0.0002034682240039641	epoch_time (seconds)=0
# Epoch 285 ->	Training loss (MSE)=2.1008645693732764e-07	Validation loss (MSE)=0.00020035519565818506	epoch_time (seconds)=0
# Epoch 286 ->	Training loss (MSE)=2.21175423270901e-07	Validation loss (MSE)=0.00020244284665422	epoch_time (seconds)=0
# Epoch 287 ->	Training loss (MSE)=2.82248524736521e-07	Validation loss (MSE)=0.00019754062365168174	epoch_time (seconds)=0
# Epoch 288 ->	Training loss (MSE)=1.5242168705376903e-07	Validation loss (MSE)=0.0002024150920490692	epoch_time (seconds)=0
# Epoch 289 ->	Training loss (MSE)=2.6781751032336705e-07	Validation loss (MSE)=0.00020004865658283135	epoch_time (seconds)=0
# Epoch 290 ->	Training loss (MSE)=2.009910912192936e-07	Validation loss (MSE)=0.00019874792789313607	epoch_time (seconds)=0
# Epoch 291 ->	Training loss (MSE)=1.3141458379511566e-07	Validation loss (MSE)=0.00019386959014609928	epoch_time (seconds)=0
# Epoch 292 ->	Training loss (MSE)=5.850153279037087e-07	Validation loss (MSE)=0.00019913386507611327	epoch_time (seconds)=0
# Epoch 293 ->	Training loss (MSE)=2.0816990564892366e-07	Validation loss (MSE)=0.00019633586376727438	epoch_time (seconds)=0
# Epoch 294 ->	Training loss (MSE)=1.5809733146697244e-07	Validation loss (MSE)=0.00019764473930137958	epoch_time (seconds)=0
# Epoch 295 ->	Training loss (MSE)=1.5715246645385844e-07	Validation loss (MSE)=0.000197168239080711	epoch_time (seconds)=0
# Epoch 296 ->	Training loss (MSE)=1.2251800830277139e-07	Validation loss (MSE)=0.00019322136673833408	epoch_time (seconds)=0
# Epoch 297 ->	Training loss (MSE)=3.3416529035781514e-07	Validation loss (MSE)=0.0002060780215054729	epoch_time (seconds)=0
# Epoch 298 ->	Training loss (MSE)=6.853360451802983e-07	Validation loss (MSE)=0.0002026966076694358	epoch_time (seconds)=0
# Epoch 299 ->	Training loss (MSE)=1.6531824345326264e-07	Validation loss (MSE)=0.00019933828664722302	epoch_time (seconds)=0
# Epoch 300 ->	Training loss (MSE)=1.759074955968084e-07	Validation loss (MSE)=0.00019539854128588358	epoch_time (seconds)=0
# Epoch 301 ->	Training loss (MSE)=1.5229857075244182e-07	Validation loss (MSE)=0.00019725927269691553	epoch_time (seconds)=0
# Epoch 302 ->	Training loss (MSE)=1.2986050511777072e-07	Validation loss (MSE)=0.00020393980722928492	epoch_time (seconds)=0
# Epoch 303 ->	Training loss (MSE)=3.7977453129725493e-07	Validation loss (MSE)=0.00020064544185913446	epoch_time (seconds)=0
# Epoch 304 ->	Training loss (MSE)=1.8580617151888963e-07	Validation loss (MSE)=0.00019638394068291267	epoch_time (seconds)=0
# Epoch 305 ->	Training loss (MSE)=3.7664014008086957e-07	Validation loss (MSE)=0.00019815085231611226	epoch_time (seconds)=0
# Epoch 306 ->	Training loss (MSE)=1.451007831541929e-07	Validation loss (MSE)=0.00020064012847391844	epoch_time (seconds)=0
# Epoch 307 ->	Training loss (MSE)=1.7629748623864833e-07	Validation loss (MSE)=0.0001946764306898928	epoch_time (seconds)=0
# Epoch 308 ->	Training loss (MSE)=1.7448423700831726e-07	Validation loss (MSE)=0.00019884104126537713	epoch_time (seconds)=0
# Epoch 309 ->	Training loss (MSE)=1.599550009939044e-07	Validation loss (MSE)=0.00019442736611707942	epoch_time (seconds)=0
# Epoch 310 ->	Training loss (MSE)=2.5312636823189946e-07	Validation loss (MSE)=0.00019688663118552817	epoch_time (seconds)=0
# Epoch 311 ->	Training loss (MSE)=1.8258158850657555e-07	Validation loss (MSE)=0.0001963932618376855	epoch_time (seconds)=0
# Epoch 312 ->	Training loss (MSE)=1.1065810182192142e-07	Validation loss (MSE)=0.00019734529137278002	epoch_time (seconds)=0
# Epoch 313 ->	Training loss (MSE)=1.0773567116715883e-07	Validation loss (MSE)=0.00019675899398601156	epoch_time (seconds)=0
# Epoch 314 ->	Training loss (MSE)=1.0203684090916662e-07	Validation loss (MSE)=0.00019767519363254768	epoch_time (seconds)=0
# Epoch 315 ->	Training loss (MSE)=1.0216217889392727e-07	Validation loss (MSE)=0.00019922053457755072	epoch_time (seconds)=0
# Epoch 316 ->	Training loss (MSE)=1.5175762163929592e-07	Validation loss (MSE)=0.00019738170326111587	epoch_time (seconds)=0
# Epoch 317 ->	Training loss (MSE)=1.0913910734288726e-07	Validation loss (MSE)=0.00019364919035694017	epoch_time (seconds)=0
# Epoch 318 ->	Training loss (MSE)=2.453072395646481e-07	Validation loss (MSE)=0.00019874414616230475	epoch_time (seconds)=0
# Epoch 319 ->	Training loss (MSE)=1.4351941665498133e-07	Validation loss (MSE)=0.00019454535870056072	epoch_time (seconds)=0
# Epoch 320 ->	Training loss (MSE)=1.1799459455773569e-07	Validation loss (MSE)=0.00019631037380585177	epoch_time (seconds)=0
# Epoch 321 ->	Training loss (MSE)=1.398887615955684e-07	Validation loss (MSE)=0.00019600941742602696	epoch_time (seconds)=0
# Epoch 322 ->	Training loss (MSE)=1.194069418752073e-07	Validation loss (MSE)=0.00019820781206193852	epoch_time (seconds)=0
# Epoch 323 ->	Training loss (MSE)=1.3980605966874398e-07	Validation loss (MSE)=0.0001943589052258683	epoch_time (seconds)=0
# Epoch 324 ->	Training loss (MSE)=3.0795285566433094e-07	Validation loss (MSE)=0.0001921850959354876	epoch_time (seconds)=0
# Epoch 325 ->	Training loss (MSE)=6.143560736335331e-07	Validation loss (MSE)=0.0002006952452434988	epoch_time (seconds)=0
# Epoch 326 ->	Training loss (MSE)=3.672426443821811e-07	Validation loss (MSE)=0.00019793777490625258	epoch_time (seconds)=0
# Epoch 327 ->	Training loss (MSE)=1.7595735559369843e-07	Validation loss (MSE)=0.0001959943071290715	epoch_time (seconds)=0
# Epoch 328 ->	Training loss (MSE)=1.193950733159554e-07	Validation loss (MSE)=0.00019746107696700613	epoch_time (seconds)=0
# Epoch 329 ->	Training loss (MSE)=1.1907730717345058e-07	Validation loss (MSE)=0.00019302061275695083	epoch_time (seconds)=0
# Epoch 330 ->	Training loss (MSE)=1.5558269948508872e-07	Validation loss (MSE)=0.0001958540523741414	epoch_time (seconds)=0
# Epoch 331 ->	Training loss (MSE)=1.7520668414241166e-07	Validation loss (MSE)=0.00019525287301872622	epoch_time (seconds)=0
# Epoch 332 ->	Training loss (MSE)=1.3196208832701682e-07	Validation loss (MSE)=0.00019568407139089353	epoch_time (seconds)=0
# Epoch 333 ->	Training loss (MSE)=1.2795375680969123e-07	Validation loss (MSE)=0.0001933299073534688	epoch_time (seconds)=0
# Epoch 334 ->	Training loss (MSE)=1.0920427608353504e-07	Validation loss (MSE)=0.00019517200063459708	epoch_time (seconds)=0
# Epoch 335 ->	Training loss (MSE)=1.1338432027334265e-07	Validation loss (MSE)=0.00019369106233285184	epoch_time (seconds)=0
# Epoch 336 ->	Training loss (MSE)=9.671329693690762e-08	Validation loss (MSE)=0.00019393682165401807	epoch_time (seconds)=0
# Epoch 337 ->	Training loss (MSE)=9.81357242181264e-08	Validation loss (MSE)=0.00019571678712349404	epoch_time (seconds)=0
# Epoch 338 ->	Training loss (MSE)=3.3800013306418116e-07	Validation loss (MSE)=0.00019609679806588558	epoch_time (seconds)=0
# Epoch 339 ->	Training loss (MSE)=2.997534698895434e-07	Validation loss (MSE)=0.0001911190404508011	epoch_time (seconds)=0
# Epoch 340 ->	Training loss (MSE)=1.0693231319730951e-07	Validation loss (MSE)=0.00019405317076232574	epoch_time (seconds)=0
# Epoch 341 ->	Training loss (MSE)=1.1416482942442e-07	Validation loss (MSE)=0.00019540363089122476	epoch_time (seconds)=0
# Epoch 342 ->	Training loss (MSE)=1.9411922962592876e-07	Validation loss (MSE)=0.00019387916733467521	epoch_time (seconds)=0
# Epoch 343 ->	Training loss (MSE)=1.7760600772060283e-07	Validation loss (MSE)=0.00019244298858825244	epoch_time (seconds)=0
# Epoch 344 ->	Training loss (MSE)=1.6526149371686198e-07	Validation loss (MSE)=0.00019161686140929822	epoch_time (seconds)=0
# Epoch 345 ->	Training loss (MSE)=8.95419996369605e-08	Validation loss (MSE)=0.00019244928068580714	epoch_time (seconds)=0
# Epoch 346 ->	Training loss (MSE)=9.428017388752712e-08	Validation loss (MSE)=0.00019548074178198015	epoch_time (seconds)=0
# Epoch 347 ->	Training loss (MSE)=2.3702399681862916e-07	Validation loss (MSE)=0.00019226510182759158	epoch_time (seconds)=0
# Epoch 348 ->	Training loss (MSE)=1.3281475655897272e-07	Validation loss (MSE)=0.00018775693344128336	epoch_time (seconds)=0
# Epoch 349 ->	Training loss (MSE)=4.143807176322342e-07	Validation loss (MSE)=0.00019119581458841795	epoch_time (seconds)=0
# Epoch 350 ->	Training loss (MSE)=1.440097302017099e-07	Validation loss (MSE)=0.00019162428245580743	epoch_time (seconds)=0
# Epoch 351 ->	Training loss (MSE)=9.168107065461965e-08	Validation loss (MSE)=0.00019025250887272068	epoch_time (seconds)=0
# Epoch 352 ->	Training loss (MSE)=1.972289527291251e-07	Validation loss (MSE)=0.0001923697155000693	epoch_time (seconds)=0
# Epoch 353 ->	Training loss (MSE)=9.564461909301982e-08	Validation loss (MSE)=0.00019303132829867568	epoch_time (seconds)=0
# Epoch 354 ->	Training loss (MSE)=8.931315857985393e-08	Validation loss (MSE)=0.0001908211788653574	epoch_time (seconds)=0
# Epoch 355 ->	Training loss (MSE)=1.1786837349833182e-07	Validation loss (MSE)=0.00019206729977981236	epoch_time (seconds)=0
# Epoch 356 ->	Training loss (MSE)=8.161841701787967e-08	Validation loss (MSE)=0.00019236181851219752	epoch_time (seconds)=0
# Epoch 357 ->	Training loss (MSE)=1.3763265239951922e-07	Validation loss (MSE)=0.00019220891239592625	epoch_time (seconds)=0
# Epoch 358 ->	Training loss (MSE)=8.25522299217388e-08	Validation loss (MSE)=0.00019227708881025605	epoch_time (seconds)=0
# Epoch 359 ->	Training loss (MSE)=7.521180559179567e-08	Validation loss (MSE)=0.00019489448934172917	epoch_time (seconds)=0
# Epoch 360 ->	Training loss (MSE)=2.1113935401871925e-07	Validation loss (MSE)=0.00019210662503226208	epoch_time (seconds)=0
# Epoch 361 ->	Training loss (MSE)=8.536211726372929e-08	Validation loss (MSE)=0.0001937832286166629	epoch_time (seconds)=0
# Epoch 362 ->	Training loss (MSE)=1.4094780331189635e-07	Validation loss (MSE)=0.00019047806846061988	epoch_time (seconds)=0
# Epoch 363 ->	Training loss (MSE)=8.995819602033385e-08	Validation loss (MSE)=0.00019453835710878223	epoch_time (seconds)=0
# Epoch 364 ->	Training loss (MSE)=1.2897470739403615e-07	Validation loss (MSE)=0.0001936190011718093	epoch_time (seconds)=0
# Epoch 365 ->	Training loss (MSE)=1.0498559606314923e-07	Validation loss (MSE)=0.00019449549520311044	epoch_time (seconds)=0
# Epoch 366 ->	Training loss (MSE)=1.4338838402026585e-07	Validation loss (MSE)=0.00019030256237485078	epoch_time (seconds)=0
# Epoch 367 ->	Training loss (MSE)=1.6449030822611083e-07	Validation loss (MSE)=0.00019102479657760616	epoch_time (seconds)=0
# Epoch 368 ->	Training loss (MSE)=1.1010623309147842e-07	Validation loss (MSE)=0.00019105660474397942	epoch_time (seconds)=0
# Epoch 369 ->	Training loss (MSE)=8.51290804708314e-08	Validation loss (MSE)=0.00019297232967125275	epoch_time (seconds)=0
# Epoch 370 ->	Training loss (MSE)=1.0117254827084097e-07	Validation loss (MSE)=0.00019459183147883214	epoch_time (seconds)=0
# Epoch 371 ->	Training loss (MSE)=1.7103649607112702e-07	Validation loss (MSE)=0.00019357176905093713	epoch_time (seconds)=0
# Epoch 372 ->	Training loss (MSE)=1.769779003056345e-07	Validation loss (MSE)=0.00019100466583916423	epoch_time (seconds)=0
# Epoch 373 ->	Training loss (MSE)=1.0887424939094827e-07	Validation loss (MSE)=0.000193424102131237	epoch_time (seconds)=0
# Epoch 374 ->	Training loss (MSE)=1.6509150610523293e-07	Validation loss (MSE)=0.00019095121811433188	epoch_time (seconds)=0
# Epoch 375 ->	Training loss (MSE)=1.6498807481156757e-07	Validation loss (MSE)=0.0001913607041530976	epoch_time (seconds)=0
# Epoch 376 ->	Training loss (MSE)=8.995946812059096e-08	Validation loss (MSE)=0.000191807786931865	epoch_time (seconds)=0
# Epoch 377 ->	Training loss (MSE)=9.644347250960758e-08	Validation loss (MSE)=0.0001906351493938296	epoch_time (seconds)=0
# Epoch 378 ->	Training loss (MSE)=1.3268050423329352e-07	Validation loss (MSE)=0.00019238324226590744	epoch_time (seconds)=0
# Epoch 379 ->	Training loss (MSE)=9.138909521003902e-08	Validation loss (MSE)=0.00019070924479583693	epoch_time (seconds)=0
# Epoch 380 ->	Training loss (MSE)=7.901448681861172e-08	Validation loss (MSE)=0.00019232316894804392	epoch_time (seconds)=0
# Epoch 381 ->	Training loss (MSE)=1.2785704862286676e-07	Validation loss (MSE)=0.00019224991005835042	epoch_time (seconds)=0
# Epoch 382 ->	Training loss (MSE)=1.1153715557312108e-07	Validation loss (MSE)=0.00019079438651520503	epoch_time (seconds)=0
# Epoch 383 ->	Training loss (MSE)=1.2758896536494343e-07	Validation loss (MSE)=0.00019198875350473447	epoch_time (seconds)=0
# Epoch 384 ->	Training loss (MSE)=8.830815195060827e-08	Validation loss (MSE)=0.00019262182036288862	epoch_time (seconds)=0
# Epoch 385 ->	Training loss (MSE)=1.2700309422537364e-07	Validation loss (MSE)=0.00019125319477242007	epoch_time (seconds)=0
# Epoch 386 ->	Training loss (MSE)=9.563639786747666e-08	Validation loss (MSE)=0.0001894735715879617	epoch_time (seconds)=0
# Epoch 387 ->	Training loss (MSE)=1.4669028032807458e-07	Validation loss (MSE)=0.0001822887374676514	epoch_time (seconds)=0
# Epoch 388 ->	Training loss (MSE)=1.2581516541392442e-06	Validation loss (MSE)=0.00019590005712471058	epoch_time (seconds)=0
# Epoch 389 ->	Training loss (MSE)=8.315061035368561e-07	Validation loss (MSE)=0.0001890998614865671	epoch_time (seconds)=0
# Epoch 390 ->	Training loss (MSE)=2.8176000900502246e-07	Validation loss (MSE)=0.00019466457441323775	epoch_time (seconds)=0
# Epoch 391 ->	Training loss (MSE)=3.395095730483507e-07	Validation loss (MSE)=0.00019198936311780833	epoch_time (seconds)=0
# Epoch 392 ->	Training loss (MSE)=9.459852578759904e-08	Validation loss (MSE)=0.00018872700647538018	epoch_time (seconds)=0
# Epoch 393 ->	Training loss (MSE)=7.063144609934702e-08	Validation loss (MSE)=0.00018873555557959672	epoch_time (seconds)=0
# Epoch 394 ->	Training loss (MSE)=8.596915032429512e-08	Validation loss (MSE)=0.00018854622396042054	epoch_time (seconds)=0
# Epoch 395 ->	Training loss (MSE)=2.0102039997720743e-07	Validation loss (MSE)=0.0001920878953497597	epoch_time (seconds)=0
# Epoch 396 ->	Training loss (MSE)=1.2598498655370904e-07	Validation loss (MSE)=0.00019065303216101218	epoch_time (seconds)=0
# Epoch 397 ->	Training loss (MSE)=8.13372930166202e-08	Validation loss (MSE)=0.0001928515458245218	epoch_time (seconds)=0
# Epoch 398 ->	Training loss (MSE)=1.3087305536781214e-07	Validation loss (MSE)=0.00018991142915932555	epoch_time (seconds)=0
# Epoch 399 ->	Training loss (MSE)=7.577034238454694e-08	Validation loss (MSE)=0.0001895262250886225	epoch_time (seconds)=0
# Epoch 400 ->	Training loss (MSE)=8.186034331562795e-08	Validation loss (MSE)=0.00019185716795726211	epoch_time (seconds)=0
# Epoch 401 ->	Training loss (MSE)=7.27214909888084e-08	Validation loss (MSE)=0.00019105927851626408	epoch_time (seconds)=0
# Epoch 402 ->	Training loss (MSE)=7.715813894969315e-08	Validation loss (MSE)=0.00019179896186371438	epoch_time (seconds)=0
# Epoch 403 ->	Training loss (MSE)=8.859644661398062e-08	Validation loss (MSE)=0.00019166347240771482	epoch_time (seconds)=0
# Epoch 404 ->	Training loss (MSE)=1.0151693344639403e-07	Validation loss (MSE)=0.00019130232056306328	epoch_time (seconds)=0
# Epoch 405 ->	Training loss (MSE)=8.118591759537084e-08	Validation loss (MSE)=0.00019137950624175046	epoch_time (seconds)=0
# Epoch 406 ->	Training loss (MSE)=1.0324705329952205e-07	Validation loss (MSE)=0.00019010103061126984	epoch_time (seconds)=0
# Epoch 407 ->	Training loss (MSE)=7.939179471280822e-08	Validation loss (MSE)=0.00018921453514236686	epoch_time (seconds)=0
# Epoch 408 ->	Training loss (MSE)=1.2689953937352562e-07	Validation loss (MSE)=0.0001915741299330419	epoch_time (seconds)=0
# Epoch 409 ->	Training loss (MSE)=3.3633050510915626e-07	Validation loss (MSE)=0.00018728569386858364	epoch_time (seconds)=0
# Epoch 410 ->	Training loss (MSE)=2.1747785797218767e-07	Validation loss (MSE)=0.00018767434575975064	epoch_time (seconds)=0
# Epoch 411 ->	Training loss (MSE)=2.3660534799180423e-07	Validation loss (MSE)=0.00019646125219648246	epoch_time (seconds)=0
# Epoch 412 ->	Training loss (MSE)=3.6335118194273955e-07	Validation loss (MSE)=0.00018810183041246653	epoch_time (seconds)=0
# Epoch 413 ->	Training loss (MSE)=1.4140097610701248e-07	Validation loss (MSE)=0.0001901640495625418	epoch_time (seconds)=0
# Epoch 414 ->	Training loss (MSE)=9.239781330034187e-08	Validation loss (MSE)=0.00018828599239845094	epoch_time (seconds)=0
# Epoch 415 ->	Training loss (MSE)=8.465055146080974e-08	Validation loss (MSE)=0.00018961787862870882	epoch_time (seconds)=0
# Epoch 416 ->	Training loss (MSE)=6.322056020111654e-08	Validation loss (MSE)=0.00019159787927334785	epoch_time (seconds)=0
# Epoch 417 ->	Training loss (MSE)=1.0654230860456952e-07	Validation loss (MSE)=0.00018831241326755722	epoch_time (seconds)=0
# Epoch 418 ->	Training loss (MSE)=8.771685558502479e-08	Validation loss (MSE)=0.00018592945271092462	epoch_time (seconds)=0
# Epoch 419 ->	Training loss (MSE)=3.3329737651988914e-07	Validation loss (MSE)=0.00018681159772572856	epoch_time (seconds)=0
# Epoch 420 ->	Training loss (MSE)=1.9406525342030985e-07	Validation loss (MSE)=0.0001931038057643511	epoch_time (seconds)=0
# Epoch 421 ->	Training loss (MSE)=2.3379130657608916e-07	Validation loss (MSE)=0.00018731758622708312	epoch_time (seconds)=0
# Epoch 422 ->	Training loss (MSE)=1.2086696456873786e-07	Validation loss (MSE)=0.00018677867173562426	epoch_time (seconds)=0
# Epoch 423 ->	Training loss (MSE)=3.3013356355889676e-07	Validation loss (MSE)=0.00018596900453992136	epoch_time (seconds)=0
# Epoch 424 ->	Training loss (MSE)=1.96831532146395e-07	Validation loss (MSE)=0.00019108025148329488	epoch_time (seconds)=0
# Epoch 425 ->	Training loss (MSE)=1.0606231020603457e-07	Validation loss (MSE)=0.00018933538457259748	epoch_time (seconds)=0
# Epoch 426 ->	Training loss (MSE)=6.70548687630466e-08	Validation loss (MSE)=0.0001882667810890436	epoch_time (seconds)=0
# Epoch 427 ->	Training loss (MSE)=1.0647628054046924e-07	Validation loss (MSE)=0.00018944336677527245	epoch_time (seconds)=0
# Epoch 428 ->	Training loss (MSE)=1.462157612105252e-07	Validation loss (MSE)=0.0001912436603790753	epoch_time (seconds)=0
# Epoch 429 ->	Training loss (MSE)=1.2195601610950158e-07	Validation loss (MSE)=0.00018584165158679113	epoch_time (seconds)=0
# Epoch 430 ->	Training loss (MSE)=1.315699658178113e-07	Validation loss (MSE)=0.0001887359110335598	epoch_time (seconds)=0
# Epoch 431 ->	Training loss (MSE)=1.0361686654838062e-07	Validation loss (MSE)=0.00018917877343421804	epoch_time (seconds)=0
# Epoch 432 ->	Training loss (MSE)=7.175536298086072e-08	Validation loss (MSE)=0.00019068508721822175	epoch_time (seconds)=0
# Epoch 433 ->	Training loss (MSE)=8.012903368295134e-08	Validation loss (MSE)=0.00019023355902143122	epoch_time (seconds)=0
# Epoch 434 ->	Training loss (MSE)=8.250760324020165e-08	Validation loss (MSE)=0.00018854486056735765	epoch_time (seconds)=0
# Epoch 435 ->	Training loss (MSE)=1.05298778179054e-07	Validation loss (MSE)=0.00018919765860862133	epoch_time (seconds)=0
# Epoch 436 ->	Training loss (MSE)=1.1096686139159452e-07	Validation loss (MSE)=0.00018670583230066148	epoch_time (seconds)=0
# Epoch 437 ->	Training loss (MSE)=1.228589974843777e-07	Validation loss (MSE)=0.00019045200203129885	epoch_time (seconds)=0
# Epoch 438 ->	Training loss (MSE)=1.1159651099277897e-07	Validation loss (MSE)=0.00018862991171757226	epoch_time (seconds)=0
# Epoch 439 ->	Training loss (MSE)=6.439294923705059e-08	Validation loss (MSE)=0.00018711404934173417	epoch_time (seconds)=0
# Epoch 440 ->	Training loss (MSE)=8.442751926560416e-08	Validation loss (MSE)=0.00018912727740242165	epoch_time (seconds)=0
# Epoch 441 ->	Training loss (MSE)=7.77053274252533e-08	Validation loss (MSE)=0.00019249322244500666	epoch_time (seconds)=0
# Epoch 442 ->	Training loss (MSE)=2.7004177871820103e-07	Validation loss (MSE)=0.0001883472252135345	epoch_time (seconds)=0
# Epoch 443 ->	Training loss (MSE)=1.0294053814718387e-07	Validation loss (MSE)=0.00019137933778066638	epoch_time (seconds)=0
# Epoch 444 ->	Training loss (MSE)=9.221336083749897e-08	Validation loss (MSE)=0.0001893602837908004	epoch_time (seconds)=0
# Epoch 445 ->	Training loss (MSE)=1.0289445673164409e-07	Validation loss (MSE)=0.00019058631648545063	epoch_time (seconds)=0
# Epoch 446 ->	Training loss (MSE)=7.566578233308974e-08	Validation loss (MSE)=0.00018776622742838338	epoch_time (seconds)=0
# Epoch 447 ->	Training loss (MSE)=8.635161850911461e-08	Validation loss (MSE)=0.00018848325766956408	epoch_time (seconds)=0
# Epoch 448 ->	Training loss (MSE)=1.5363283111122568e-07	Validation loss (MSE)=0.00018964705010175354	epoch_time (seconds)=0
# Epoch 449 ->	Training loss (MSE)=1.2020387398077153e-07	Validation loss (MSE)=0.00018848254381130235	epoch_time (seconds)=0
# Epoch 450 ->	Training loss (MSE)=7.990056769535951e-08	Validation loss (MSE)=0.00018918665811365888	epoch_time (seconds)=0
# Epoch 451 ->	Training loss (MSE)=6.230538828194822e-08	Validation loss (MSE)=0.0001878386330410962	epoch_time (seconds)=0
# Epoch 452 ->	Training loss (MSE)=5.1454038095621064e-08	Validation loss (MSE)=0.00018894555629661293	epoch_time (seconds)=0
# Epoch 453 ->	Training loss (MSE)=8.485195663973993e-08	Validation loss (MSE)=0.00018863426764208506	epoch_time (seconds)=0
# Epoch 454 ->	Training loss (MSE)=8.292409588696822e-08	Validation loss (MSE)=0.00018975901012500667	epoch_time (seconds)=0
# Epoch 455 ->	Training loss (MSE)=1.1247267881400126e-07	Validation loss (MSE)=0.00018858340292062154	epoch_time (seconds)=0
# Epoch 456 ->	Training loss (MSE)=7.292759358309501e-08	Validation loss (MSE)=0.00018903785619066996	epoch_time (seconds)=0
# Epoch 457 ->	Training loss (MSE)=6.592739428417256e-08	Validation loss (MSE)=0.00018891226882894387	epoch_time (seconds)=0
# Epoch 458 ->	Training loss (MSE)=8.468659132870193e-08	Validation loss (MSE)=0.00018525831123524853	epoch_time (seconds)=0
# Epoch 459 ->	Training loss (MSE)=2.0382611024815116e-07	Validation loss (MSE)=0.0001895910011337177	epoch_time (seconds)=0
# Epoch 460 ->	Training loss (MSE)=1.1566033075759728e-07	Validation loss (MSE)=0.00019086216037776793	epoch_time (seconds)=0
# Epoch 461 ->	Training loss (MSE)=9.956027089928528e-08	Validation loss (MSE)=0.00019194927953693566	epoch_time (seconds)=0
# Epoch 462 ->	Training loss (MSE)=4.770090075459027e-07	Validation loss (MSE)=0.00018353935181991313	epoch_time (seconds)=0
# Epoch 463 ->	Training loss (MSE)=8.002791703458526e-07	Validation loss (MSE)=0.00018971200190693997	epoch_time (seconds)=0
# Epoch 464 ->	Training loss (MSE)=2.0667411263968637e-07	Validation loss (MSE)=0.0001866981326011103	epoch_time (seconds)=0
# Epoch 465 ->	Training loss (MSE)=1.6736466372227679e-07	Validation loss (MSE)=0.00018417192738574026	epoch_time (seconds)=0
# Epoch 466 ->	Training loss (MSE)=3.7486710130967433e-07	Validation loss (MSE)=0.0001851643527762811	epoch_time (seconds)=0
# Epoch 467 ->	Training loss (MSE)=1.9236370426009362e-07	Validation loss (MSE)=0.00018592250331857173	epoch_time (seconds)=0
# Epoch 468 ->	Training loss (MSE)=8.589697982967398e-08	Validation loss (MSE)=0.00018720039959228376	epoch_time (seconds)=0
# Epoch 469 ->	Training loss (MSE)=5.847457349157749e-08	Validation loss (MSE)=0.00018903003984530197	epoch_time (seconds)=0
# Epoch 470 ->	Training loss (MSE)=1.0901508808385143e-07	Validation loss (MSE)=0.00018775294415742245	epoch_time (seconds)=0
# Epoch 471 ->	Training loss (MSE)=1.9910731790504565e-07	Validation loss (MSE)=0.00018746036791364115	epoch_time (seconds)=0
# Epoch 472 ->	Training loss (MSE)=8.477899282242129e-08	Validation loss (MSE)=0.00018203272267270325	epoch_time (seconds)=0
# Epoch 473 ->	Training loss (MSE)=2.3106433772914985e-07	Validation loss (MSE)=0.00018436738407045578	epoch_time (seconds)=0
# Epoch 474 ->	Training loss (MSE)=1.1372445135848244e-07	Validation loss (MSE)=0.00018553891292772694	epoch_time (seconds)=0
# Epoch 475 ->	Training loss (MSE)=1.1127608486075554e-07	Validation loss (MSE)=0.00018731812165151206	epoch_time (seconds)=0
# Epoch 476 ->	Training loss (MSE)=7.686703083170248e-08	Validation loss (MSE)=0.00018561349350626165	epoch_time (seconds)=0
# Epoch 477 ->	Training loss (MSE)=1.1550918899052792e-07	Validation loss (MSE)=0.00018758244130284935	epoch_time (seconds)=0
# Epoch 478 ->	Training loss (MSE)=9.796035510312433e-08	Validation loss (MSE)=0.00018410958304712125	epoch_time (seconds)=0
# Epoch 479 ->	Training loss (MSE)=1.4645464754996127e-07	Validation loss (MSE)=0.0001841439743244277	epoch_time (seconds)=0
# Epoch 480 ->	Training loss (MSE)=2.3432968115374512e-07	Validation loss (MSE)=0.00018422133676201762	epoch_time (seconds)=0
# Epoch 481 ->	Training loss (MSE)=1.4247306107957162e-07	Validation loss (MSE)=0.00018770901215584297	epoch_time (seconds)=0
# Epoch 482 ->	Training loss (MSE)=1.4010640054438248e-07	Validation loss (MSE)=0.00018726773463853918	epoch_time (seconds)=0
# Epoch 483 ->	Training loss (MSE)=8.339309525552369e-08	Validation loss (MSE)=0.00018419495742810337	epoch_time (seconds)=0
# Epoch 484 ->	Training loss (MSE)=7.802604726271611e-08	Validation loss (MSE)=0.00018535731820998872	epoch_time (seconds)=0
# Epoch 485 ->	Training loss (MSE)=1.808843022145749e-07	Validation loss (MSE)=0.00018890336328731907	epoch_time (seconds)=0
# Epoch 486 ->	Training loss (MSE)=3.421354369670664e-07	Validation loss (MSE)=0.00018501127506419428	epoch_time (seconds)=0
# Epoch 487 ->	Training loss (MSE)=2.2012718741224513e-07	Validation loss (MSE)=0.00018689616016515973	epoch_time (seconds)=0
# Epoch 488 ->	Training loss (MSE)=1.1745349413018164e-07	Validation loss (MSE)=0.00018361131041069782	epoch_time (seconds)=0
# Epoch 489 ->	Training loss (MSE)=7.496746507779502e-08	Validation loss (MSE)=0.00018626692079876992	epoch_time (seconds)=0
# Epoch 490 ->	Training loss (MSE)=2.3639930824069003e-07	Validation loss (MSE)=0.00018214790730509975	epoch_time (seconds)=0
# Epoch 491 ->	Training loss (MSE)=8.903571151074075e-08	Validation loss (MSE)=0.00018380150076190212	epoch_time (seconds)=0
# Epoch 492 ->	Training loss (MSE)=6.273090512300636e-08	Validation loss (MSE)=0.0001825904162647842	epoch_time (seconds)=0
# Epoch 493 ->	Training loss (MSE)=6.575606008834433e-08	Validation loss (MSE)=0.00018321927456153752	epoch_time (seconds)=0
# Epoch 494 ->	Training loss (MSE)=6.67830467193653e-08	Validation loss (MSE)=0.0001817835087391549	epoch_time (seconds)=0
# Epoch 495 ->	Training loss (MSE)=5.656454041375183e-08	Validation loss (MSE)=0.0001802782521740737	epoch_time (seconds)=0
# Epoch 496 ->	Training loss (MSE)=1.1535887399018953e-07	Validation loss (MSE)=0.0001816363537180313	epoch_time (seconds)=0
# Epoch 497 ->	Training loss (MSE)=1.8449722677182652e-07	Validation loss (MSE)=0.00018993030794133524	epoch_time (seconds)=0
# Epoch 498 ->	Training loss (MSE)=5.896468844889015e-07	Validation loss (MSE)=0.000183613644925132	epoch_time (seconds)=0
# Epoch 499 ->	Training loss (MSE)=1.8955813985490838e-07	Validation loss (MSE)=0.00018518918796298374	epoch_time (seconds)=0
# Metrics exported in the following csv file: metrics/logged_metrics/multivariate_NN_layers50-500_training_ranges=ti0.15-0.4-ct0.3-0.7_06-07-2023_16-43-34.csv

# %% [markdown]
# # Testing

# %%
# loading best model
model = MultivariateNN(input_space, output_space).to(DEVICE)
model.load_state_dict(torch.load(BEST_MODEL_PATH))
model.eval()

save_results = False

# evaluation on trainset
evaluate_model(
    model,
    data=train_dataloader,
    data_type="train",
    model_description=MODEL_DESCRIPTION,
    save_results=save_results,
    experiment=EXPERIMENT,
)

print()

# evalution on testset
evaluate_model(
    model,
    data=test_dataloader,
    data_type="test",
    model_description=MODEL_DESCRIPTION,
    save_results=save_results,
    experiment=EXPERIMENT,
)
# Out:
# Train results for multivariate_NN_layers50-500_training_factors=ti4-ct4_discr_factors_x2_30_y-2_2_step0.125_TIstep0.01_CTstep0.01: act. func. ReLU (not last layer), batch size 64, 500 epochs, lr=0.001)
# metrics/final_results/trainset_results_interpolation.csv
# r2_score=0.942704959878812
# explained_variance_score=0.9568645846863676
# mean_squared_error=1.6404421330662444e-05
# mean_absolute_error=0.0019142470555379987
# median_absolute_error=0.0012943163746967912
# mean_absolute_percentage_error=425550577664.0
# peak_signal_noise_ratio=47.85039084834938
# Prediction time=0.0001134291562167081s
#
# Test results for multivariate_NN_layers50-500_training_factors=ti4-ct4_discr_factors_x2_30_y-2_2_step0.125_TIstep0.01_CTstep0.01: act. func. ReLU (not last layer), batch size 64, 500 epochs, lr=0.001)
# metrics/final_results/testset_results_interpolation.csv
# r2_score=0.9512092151212225
# explained_variance_score=0.9644757632299193
# mean_squared_error=1.3979134564578999e-05
# mean_absolute_error=0.0017960515106096864
# median_absolute_error=0.0012430304195731878
# mean_absolute_percentage_error=194936569856.0
# peak_signal_noise_ratio=48.5451971453182
# Prediction time=5.4653179571495294e-05s

# %%
test_dataset = test_dataloader.dataset
indices = list(range(len(test_dataset)))
# random.shuffle(indices)

with torch.no_grad():
    for i in range(0, len(indices), 50):
        for idx in indices[i : i + 3]:
            ti, ct, ws, wake_field, predicted_wake_field = (
                test_dataset.get_parameters_for_plotting_multivariate(model, idx)
            )

            plotting.plot_maps(
                test_dataset.X_grid,
                test_dataset.Y_grid,
                wake_field,
                predicted_wake_field,
                ti,
                ct,
                ws,
                error_to_plot="absolute",
            )
# Out:
# 4025
