# %% [markdown]
# # Univariate regression to predict the wind speed field

# %%
import torch
import torch.nn as nn
import numpy as np
import random

import sys
sys.path.append("../..")

from src.logging_metrics import MetricsLogger
from src.data_loaders import get_wake_dataloaders
import src.plotting as plotting
from src.evaluation import evaluate_model

# define random seeds for Neural Networks
torch.manual_seed(0)
np.random.seed(0)

# %%
# hyperparameters
# in univariate, the batch size is a multiplier for number of cells
# (i.e. the batch_size should be dividible by the number of cells)
BATCH_MULTIPLIER = 8
EPOCHS = 500
LR = 0.0001  # before it was 0.01

ACTIVATION_FUNCTION = nn.ReLU()  # TODO
N_MAPPING = 256  # Number of Fourier features
HIDDEN_LAYERS_UNITS = [256, 256, 256]  # before it was [128, 256, 32]

FACTORS_FOLDER = "discr_factors_x2_30_y-2_2_step0.125_TIstep0.01_CTstep0.01"
DATA_FOLDER = f"../data/{FACTORS_FOLDER}/"
INPUT_VAR_TO_TRAIN_REDUCTION_FACTOR = {"ti": 32, "ct": 32}  # , 'x/D': 12, 'y/D': 12}
train_reduc_factor_string = "training_factors=" + "-".join(
    [f"{k}{v}" for k, v in INPUT_VAR_TO_TRAIN_REDUCTION_FACTOR.items()]
).replace("/", "")
# INPUT_VAR_TO_TRAIN_RANGES = {'ti': [(0.15, 0.4)], 'ct': [(0.3, 0.7)]}
# train_range_string = "training_ranges=" + '-'.join([f"{var}{r[0]}-{r[1]}" for var, ranges in INPUT_VAR_TO_TRAIN_RANGES.items() for r in ranges])
EXPERIMENT = "interpolation"

MODEL_NAME = (
    f"univariate_NeRF_{N_MAPPING}fourier-features_"
    f"layers{'-'.join(str(lu) for lu in HIDDEN_LAYERS_UNITS)}_{train_reduc_factor_string}"
)
BEST_MODEL_PATH = f"../saved_models/{FACTORS_FOLDER}/{MODEL_NAME}.pt"
CONSIDER_WS = False
COORDS_AS_INPUT = True  # univariate setting
N_COORDINATES = 2  # Number of input coordinates (x and y)
if CONSIDER_WS:
    MODEL_NAME += "_consider_ws"
    FACTORS_FOLDER = FACTORS_FOLDER.replace("TIstep0.01_CTstep0.01", "reducedTI-CT")
    BEST_MODEL_PATH = f"../saved_models/{FACTORS_FOLDER}/{MODEL_NAME}.pt"
print(f"Model name: {MODEL_NAME}")
print(f"Best model path: {BEST_MODEL_PATH}")

MODEL_DESCRIPTION = (
    f"{MODEL_NAME}_{FACTORS_FOLDER}: act. func. {ACTIVATION_FUNCTION.__class__.__name__} "
    + f"(not last layer), batch multiplier {BATCH_MULTIPLIER}, {EPOCHS} epochs, lr={LR})"
)
print(f"Model description: {MODEL_DESCRIPTION}")

DEVICE = torch.device("cuda" if torch.cuda.is_available() else "cpu")
print(f"\nDevice: {DEVICE}")
# Out:
# Model name: univariate_NeRF_256fourier-features_layers256-256-256_training_factors=ti32-ct32
# Best model path: saved_models/discr_factors_x2_30_y-2_2_step0.125_TIstep0.01_CTstep0.01/univariate_NeRF_256fourier-features_layers256-256-256_training_factors=ti32-ct32.pt
# Model description: univariate_NeRF_256fourier-features_layers256-256-256_training_factors=ti32-ct32_discr_factors_x2_30_y-2_2_step0.125_TIstep0.01_CTstep0.01: act. func. ReLU (not last layer), batch multiplier 8, 500 epochs, lr=0.0001)
#
# Device: cpu

# %%
class FourierLayer(nn.Module):
    def __init__(self, n_features: int, n_mapping: int):
        super(FourierLayer, self).__init__()
        self.coefficients = nn.Parameter(
            torch.randn(n_mapping, n_features)
        )  # sampled from normal distribution with mean 0 and variance 1

    def forward(self, x):
        x_proj = 2 * torch.pi * x @ self.coefficients.t()
        out = torch.cat([torch.sin(x_proj), torch.cos(x_proj)], dim=-1)
        return out


class NeRF2D(nn.Module):
    def __init__(self, n_coordinates: int, n_features: int, output_space: int):
        super(NeRF2D, self).__init__()
        self.fourier_layer = FourierLayer(n_coordinates, N_MAPPING)
        layer_units = [N_MAPPING * 2 + n_features] + HIDDEN_LAYERS_UNITS
        mlp_layers = list()
        for first, second in zip(layer_units, layer_units[1:]):
            mlp_layers += [nn.Linear(first, second), ACTIVATION_FUNCTION]
        mlp_layers.append(
            nn.Linear(layer_units[-1], output_space)
        )  # last layer not activated
        self.mlp = nn.Sequential(*mlp_layers)

    def forward(self, inputs):
        # Pass coordinates through the Fourier Layer
        coords = inputs[:, -2:]
        input_features = inputs[:, :-2]
        fourier_out = self.fourier_layer(coords)

        # Concatenate Fourier layer output with other input features
        input_features = torch.cat((fourier_out, input_features), dim=-1)

        # Feed-forward through the rest of the neural network
        x = self.mlp(input_features)

        return x

# %%
valid_dataloader = None
train_dataloader, valid_dataloader, test_dataloader = get_wake_dataloaders(
    DATA_FOLDER,
    consider_ws=CONSIDER_WS,
    coords_as_input=COORDS_AS_INPUT,
    # train_perc=0.6,
    # test_perc=0.2,
    # validation_perc=0.2,
    input_var_to_train_reduction_factor=INPUT_VAR_TO_TRAIN_REDUCTION_FACTOR,
    # input_var_to_train_ranges=INPUT_VAR_TO_TRAIN_RANGES,
    batch_multiplier=BATCH_MULTIPLIER,
)
len(train_dataloader)
print(valid_dataloader)
# Out:
# /Users/niccolomorabito/Library/CloudStorage/GoogleDrive-morabito.1808746@studenti.uniroma1.it/My Drive/BDMA/Semester4 Thesis/Ainslie-surrogate/utils/data_loaders.py:328: UserWarning:
# Ignoring percentages of train-valid-test split (train_perc=0.8, valid_perc=0, test_perc=0.2)
# and using the reduction factors for the training set instead:
# {'ti': 32, 'ct': 32}
#   warnings.warn(
# <torch.utils.data.dataloader.DataLoader object at 0x17ed33160>

# %%
for b in train_dataloader:
    print(b[0].shape, b[1].shape)
    break

input_space = train_dataloader.dataset.inputs.shape[1]
n_features = input_space - N_COORDINATES
output_space = train_dataloader.dataset.outputs.shape[1]
print(
    f"{input_space=} ({N_COORDINATES} coordinates and {n_features} other input features)\t{output_space=}"
)
# Out:
# torch.Size([57344, 4]) torch.Size([57344, 1])
# input_space=4 (2 coordinates and 2 other input features)	output_space=1

# %%
model = NeRF2D(N_COORDINATES, n_features, output_space).to(DEVICE)

optimizer = torch.optim.Adam((p for p in model.parameters() if p.requires_grad), lr=LR)
loss_function = torch.nn.MSELoss()

metrics_logger = MetricsLogger(name=MODEL_NAME, automatic_save_after=2)
best_vloss = 1_000_000.0
for epoch in range(EPOCHS):
    """TRAINING"""
    model.train(True)
    epoch_tloss = 0
    for batch in iter(train_dataloader):
        x, y = batch[0].to(DEVICE), batch[1].to(DEVICE)
        optimizer.zero_grad()
        prediction = model(x)
        tloss = loss_function(prediction, y)
        tloss.backward()
        # torch.nn.utils.clip_grad_norm_(model.parameters(), 0.5) TODO
        optimizer.step()

        epoch_tloss += tloss.item() * x.size(0)
        # TODO accuracy or other metric computation????

    avg_tloss = epoch_tloss / len(train_dataloader.sampler)
    metrics_logger.log_metric(epoch, "Training loss", avg_tloss)

    """VALIDATION"""
    if valid_dataloader:
        model.train(False)
        epoch_vloss = 0
        for batch in iter(valid_dataloader):
            x, y = batch[0].to(DEVICE), batch[1].to(DEVICE)
            prediction = model(x)
            vloss = loss_function(prediction, y)

            epoch_vloss += vloss.item() * x.size(0)

        avg_vloss = epoch_vloss / len(valid_dataloader.sampler)
        metrics_logger.log_metric(epoch, "Validation loss", avg_vloss)
        # Track best performance, and save the model's state
        if avg_vloss < best_vloss:
            best_vloss = avg_vloss
            torch.save(model.state_dict(), BEST_MODEL_PATH)
# Out:
# Logging univariate_NeRF_256fourier-features_layers256-256-256_training_factors=ti32-ct32
# Epoch 0 ->	Training loss=0.008905830172200998	Validation loss=0.0038162972143680747	epoch_time (seconds)=270
# Epoch 1 ->	Training loss=0.004037052470569809	Validation loss=0.001357641410512887	epoch_time (seconds)=257
# Epoch 2 ->	Training loss=0.0019468720226238172	Validation loss=0.0010121435314242506	epoch_time (seconds)=233
# Epoch 3 ->	Training loss=0.0017787198691318433	Validation loss=0.0015394458368083988	epoch_time (seconds)=237
# Epoch 4 ->	Training loss=0.002264255735402306	Validation loss=0.001778882255510509	epoch_time (seconds)=229
# Epoch 5 ->	Training loss=0.0023996044571201005	Validation loss=0.0015308559850737986	epoch_time (seconds)=228
# Epoch 6 ->	Training loss=0.0021035780664533377	Validation loss=0.0011213690397760372	epoch_time (seconds)=230
# Epoch 7 ->	Training loss=0.0017055707285180688	Validation loss=0.0008305199582696449	epoch_time (seconds)=208
# Epoch 8 ->	Training loss=0.0014501118178789814	Validation loss=0.0007414598956573573	epoch_time (seconds)=217
# Epoch 9 ->	Training loss=0.0013916784664615989	Validation loss=0.0007913852438604364	epoch_time (seconds)=212
# Epoch 10 ->	Training loss=0.0014524675983314712	Validation loss=0.0008700515617435698	epoch_time (seconds)=212
# Epoch 11 ->	Training loss=0.0015252764569595456	Validation loss=0.0009004006073062977	epoch_time (seconds)=243
# Epoch 12 ->	Training loss=0.0015425212914124131	Validation loss=0.0008667599725378999	epoch_time (seconds)=243
# Epoch 13 ->	Training loss=0.0014983703925584753	Validation loss=0.000798834794985608	epoch_time (seconds)=221
# Epoch 14 ->	Training loss=0.0014255882318442066	Validation loss=0.0007369893512584036	epoch_time (seconds)=232
# Epoch 15 ->	Training loss=0.0013655894823993246	Validation loss=0.000706464512364817	epoch_time (seconds)=236
# Epoch 16 ->	Training loss=0.0013376022689044476	Validation loss=0.0007075247486348819	epoch_time (seconds)=234
# Epoch 17 ->	Training loss=0.0013401618925854564	Validation loss=0.000722046607482179	epoch_time (seconds)=235
# Epoch 18 ->	Training loss=0.0013545081407452624	Validation loss=0.0007299648997292329	epoch_time (seconds)=214
# Epoch 19 ->	Training loss=0.0013615973681832354	Validation loss=0.0007222676141762089	epoch_time (seconds)=204
# Epoch 20 ->	Training loss=0.0013541706139221787	Validation loss=0.0007033817264150882	epoch_time (seconds)=217
# Epoch 21 ->	Training loss=0.0013370042433962226	Validation loss=0.0006845519534417597	epoch_time (seconds)=228
# Epoch 22 ->	Training loss=0.00132186869935443	Validation loss=0.0006741880421111604	epoch_time (seconds)=235
# Epoch 23 ->	Training loss=0.0013141432233775656	Validation loss=0.0006735370361499279	epoch_time (seconds)=219
# Epoch 24 ->	Training loss=0.001314549435240527	Validation loss=0.0006772736002854624	epoch_time (seconds)=232
# Epoch 25 ->	Training loss=0.0013165820855647326	Validation loss=0.0006792291997751663	epoch_time (seconds)=222
# Epoch 26 ->	Training loss=0.0013158589135855436	Validation loss=0.0006775883769727748	epoch_time (seconds)=239
# Epoch 27 ->	Training loss=0.0013109114952385426	Validation loss=0.0006739356454245357	epoch_time (seconds)=228
# Epoch 28 ->	Training loss=0.0013043061286831896	Validation loss=0.0006711572453762007	epoch_time (seconds)=234
# Epoch 29 ->	Training loss=0.0012993114069104195	Validation loss=0.0006708451091193342	epoch_time (seconds)=232
# Epoch 30 ->	Training loss=0.0012970974979301293	Validation loss=0.0006718052656531401	epoch_time (seconds)=219
# Epoch 31 ->	Training loss=0.0012964706402271986	Validation loss=0.0006717638271530239	epoch_time (seconds)=226
# Epoch 32 ->	Training loss=0.0012953229403744142	Validation loss=0.0006697547101111181	epoch_time (seconds)=240
# Epoch 33 ->	Training loss=0.0012925451543803017	Validation loss=0.0006664477870162489	epoch_time (seconds)=223
# Epoch 34 ->	Training loss=0.0012889389957611759	Validation loss=0.0006629571927448172	epoch_time (seconds)=227
# Epoch 35 ->	Training loss=0.0012855168121556442	Validation loss=0.0006605898505008446	epoch_time (seconds)=229
# Epoch 36 ->	Training loss=0.001283068520327409	Validation loss=0.0006591052208805017	epoch_time (seconds)=227
# Epoch 37 ->	Training loss=0.0012812862017502387	Validation loss=0.0006574675527530426	epoch_time (seconds)=225
# Epoch 38 ->	Training loss=0.0012791611952707171	Validation loss=0.000655241388527496	epoch_time (seconds)=207
# Epoch 39 ->	Training loss=0.0012763328074167173	Validation loss=0.0006528024479393723	epoch_time (seconds)=208
# Epoch 40 ->	Training loss=0.0012732084918146331	Validation loss=0.0006507361643593263	epoch_time (seconds)=211
# Epoch 41 ->	Training loss=0.0012702754077812035	Validation loss=0.0006493274442117156	epoch_time (seconds)=239
# Epoch 42 ->	Training loss=0.0012676734865332644	Validation loss=0.0006480182021088303	epoch_time (seconds)=324
# Epoch 43 ->	Training loss=0.0012650435091927648	Validation loss=0.0006466896578155629	epoch_time (seconds)=337
# Epoch 44 ->	Training loss=0.0012622159362460177	Validation loss=0.000645242935832723	epoch_time (seconds)=365
# Epoch 45 ->	Training loss=0.0012592177372425795	Validation loss=0.0006436963533615767	epoch_time (seconds)=311
# Epoch 46 ->	Training loss=0.0012561907448495428	Validation loss=0.0006422237517904494	epoch_time (seconds)=240
# Epoch 47 ->	Training loss=0.001253181175949673	Validation loss=0.0006404005251836785	epoch_time (seconds)=231
# Epoch 48 ->	Training loss=0.0012500981489817302	Validation loss=0.0006379533548198807	epoch_time (seconds)=224
# Epoch 49 ->	Training loss=0.001246750820428133	Validation loss=0.0006350345585712015	epoch_time (seconds)=225
# Epoch 50 ->	Training loss=0.001243465153189997	Validation loss=0.0006321371175597313	epoch_time (seconds)=218
# Epoch 51 ->	Training loss=0.0012400387786328793	Validation loss=0.000629421454715175	epoch_time (seconds)=230
# Epoch 52 ->	Training loss=0.0012364058444897335	Validation loss=0.0006270845077146634	epoch_time (seconds)=219
# Epoch 53 ->	Training loss=0.0012325687954823177	Validation loss=0.0006251494153911893	epoch_time (seconds)=214
# Epoch 54 ->	Training loss=0.0012285836273804307	Validation loss=0.0006237377165404092	epoch_time (seconds)=218
# Epoch 55 ->	Training loss=0.001224480220116675	Validation loss=0.0006220413715934097	epoch_time (seconds)=225
# Epoch 56 ->	Training loss=0.0012202172850569089	Validation loss=0.0006201279527311655	epoch_time (seconds)=224
# Epoch 57 ->	Training loss=0.001215846821044882	Validation loss=0.0006175080255542274	epoch_time (seconds)=222
# Epoch 58 ->	Training loss=0.0012113137636333704	Validation loss=0.0006144686380517181	epoch_time (seconds)=218
# Epoch 59 ->	Training loss=0.0012066453928127885	Validation loss=0.0006107954052474821	epoch_time (seconds)=215
# Epoch 60 ->	Training loss=0.0012018493143841624	Validation loss=0.0006071183457029862	epoch_time (seconds)=233
# Epoch 61 ->	Training loss=0.001196758821606636	Validation loss=0.0006040092752326816	epoch_time (seconds)=225
# Epoch 62 ->	Training loss=0.0011914084510256846	Validation loss=0.0006014164658039387	epoch_time (seconds)=221
# Epoch 63 ->	Training loss=0.0011857596303646762	Validation loss=0.0005987669229175063	epoch_time (seconds)=215
# Epoch 64 ->	Training loss=0.0011798333143815398	Validation loss=0.0005966397581365966	epoch_time (seconds)=216
# Epoch 65 ->	Training loss=0.001173770093979935	Validation loss=0.000593950881809636	epoch_time (seconds)=220
# Epoch 66 ->	Training loss=0.0011675032631804545	Validation loss=0.0005904137042684426	epoch_time (seconds)=217
# Epoch 67 ->	Training loss=0.0011604108149185777	Validation loss=0.0005859565960723645	epoch_time (seconds)=224
# Epoch 68 ->	Training loss=0.0011532392430429657	Validation loss=0.0005823657449881312	epoch_time (seconds)=217
# Epoch 69 ->	Training loss=0.001145724478798608	Validation loss=0.0005796219909013954	epoch_time (seconds)=216
# Epoch 70 ->	Training loss=0.0011376830904434125	Validation loss=0.0005750524207193128	epoch_time (seconds)=215
# Epoch 71 ->	Training loss=0.0011292511286834876	Validation loss=0.0005677914909703304	epoch_time (seconds)=213
# Epoch 72 ->	Training loss=0.0011202598301072915	Validation loss=0.0005604173557388865	epoch_time (seconds)=231
# Epoch 73 ->	Training loss=0.001110908924601972	Validation loss=0.0005545090447426359	epoch_time (seconds)=221
# Epoch 74 ->	Training loss=0.001100906093294422	Validation loss=0.0005503527481668153	epoch_time (seconds)=229
# Epoch 75 ->	Training loss=0.001090421574190259	Validation loss=0.0005469435061978565	epoch_time (seconds)=223
# Epoch 76 ->	Training loss=0.0010799051572879155	Validation loss=0.0005422114297018539	epoch_time (seconds)=223
# Epoch 77 ->	Training loss=0.0010686850485702355	Validation loss=0.0005356737331083933	epoch_time (seconds)=227
# Epoch 78 ->	Training loss=0.0010571151118104656	Validation loss=0.0005303405160860831	epoch_time (seconds)=229
# Epoch 79 ->	Training loss=0.0010450005065649748	Validation loss=0.0005242169344937407	epoch_time (seconds)=229
# Epoch 80 ->	Training loss=0.0010320848474899928	Validation loss=0.0005130266730826409	epoch_time (seconds)=221
# Epoch 81 ->	Training loss=0.0010183869938676555	Validation loss=0.0005087381714487467	epoch_time (seconds)=209
# Epoch 82 ->	Training loss=0.001004806758525471	Validation loss=0.0005003678276286858	epoch_time (seconds)=236
# Epoch 83 ->	Training loss=0.0009907986968755722	Validation loss=0.0004915579046299712	epoch_time (seconds)=230
# Epoch 84 ->	Training loss=0.0009755750264351567	Validation loss=0.0004908310597189118	epoch_time (seconds)=226
# Epoch 85 ->	Training loss=0.0009605999997196099	Validation loss=0.0004784566018155971	epoch_time (seconds)=222
# Epoch 86 ->	Training loss=0.0009459642460569739	Validation loss=0.00047500577188947364	epoch_time (seconds)=239
# Epoch 87 ->	Training loss=0.000929001544136554	Validation loss=0.00046811512863005606	epoch_time (seconds)=243
# Epoch 88 ->	Training loss=0.0009132488436686496	Validation loss=0.00045151553959977213	epoch_time (seconds)=236
# Epoch 89 ->	Training loss=0.0008967442554421723	Validation loss=0.00045688898193166935	epoch_time (seconds)=228
# Epoch 90 ->	Training loss=0.0008787893263312677	Validation loss=0.000436730293140512	epoch_time (seconds)=238
# Epoch 91 ->	Training loss=0.0008612675398277739	Validation loss=0.0004378252215357042	epoch_time (seconds)=226
# Epoch 92 ->	Training loss=0.0008435192091080049	Validation loss=0.0004264067993037364	epoch_time (seconds)=214
# Epoch 93 ->	Training loss=0.0008254301501438022	Validation loss=0.0004144049862830331	epoch_time (seconds)=227
# Epoch 94 ->	Training loss=0.0008074111732033392	Validation loss=0.00042310426132380444	epoch_time (seconds)=230
# Epoch 95 ->	Training loss=0.0007897889202771088	Validation loss=0.0004026888204110278	epoch_time (seconds)=219
# Epoch 96 ->	Training loss=0.000772531512969484	Validation loss=0.00040109098883267427	epoch_time (seconds)=221
# Epoch 97 ->	Training loss=0.0007546384974072377	Validation loss=0.0003929662540136187	epoch_time (seconds)=234
# Epoch 98 ->	Training loss=0.0007366148638539016	Validation loss=0.00040597416262250154	epoch_time (seconds)=228
# Epoch 99 ->	Training loss=0.0007215501391328871	Validation loss=0.00037800265892887463	epoch_time (seconds)=222
# Epoch 100 ->	Training loss=0.0007052787307960292	Validation loss=0.0003789899399310546	epoch_time (seconds)=226
# Epoch 101 ->	Training loss=0.0006884160296370586	Validation loss=0.0004009610653075081	epoch_time (seconds)=220
# Epoch 102 ->	Training loss=0.0006752180051989853	Validation loss=0.00036356132288421555	epoch_time (seconds)=226
# Epoch 103 ->	Training loss=0.0006694034673273563	Validation loss=0.0003610924499350243	epoch_time (seconds)=245
# Epoch 104 ->	Training loss=0.0006482046446762979	Validation loss=0.00042345595550160545	epoch_time (seconds)=222
# Epoch 105 ->	Training loss=0.0006402109089928368	Validation loss=0.0003550615392122528	epoch_time (seconds)=219
# Epoch 106 ->	Training loss=0.0006254538699674109	Validation loss=0.0003708842976178905	epoch_time (seconds)=235
# Epoch 107 ->	Training loss=0.0006135521301378807	Validation loss=0.00040777343057512867	epoch_time (seconds)=275
# Epoch 108 ->	Training loss=0.0006043332784126202	Validation loss=0.00034834395021268066	epoch_time (seconds)=301
# Epoch 109 ->	Training loss=0.0006023963020804027	Validation loss=0.0003938080625929885	epoch_time (seconds)=245
# Epoch 110 ->	Training loss=0.0005928297759965062	Validation loss=0.00040082285641184515	epoch_time (seconds)=217
# Epoch 111 ->	Training loss=0.0005788628671628734	Validation loss=0.0003411102980931828	epoch_time (seconds)=229
# Epoch 112 ->	Training loss=0.0005805076604398588	Validation loss=0.0004365208900569295	epoch_time (seconds)=227
# Epoch 113 ->	Training loss=0.0005687102093361318	Validation loss=0.0003383205201043088	epoch_time (seconds)=233
# Epoch 114 ->	Training loss=0.0005558582294421891	Validation loss=0.0003665963365296969	epoch_time (seconds)=313
# Epoch 115 ->	Training loss=0.0005448156928954025	Validation loss=0.0003930164163801366	epoch_time (seconds)=263
# Epoch 116 ->	Training loss=0.0005386851456326743	Validation loss=0.00032967942198039533	epoch_time (seconds)=299
# Epoch 117 ->	Training loss=0.0005341521076237162	Validation loss=0.00043809796550049144	epoch_time (seconds)=295
# Epoch 118 ->	Training loss=0.0005350961776760718	Validation loss=0.000332719988384594	epoch_time (seconds)=294
# Epoch 119 ->	Training loss=0.0005218181371067961	Validation loss=0.000371348886302979	epoch_time (seconds)=272
# Epoch 120 ->	Training loss=0.000510082890590032	Validation loss=0.00034202171486437914	epoch_time (seconds)=204
# Epoch 121 ->	Training loss=0.0004969430156052113	Validation loss=0.00033480418574845336	epoch_time (seconds)=234
# Epoch 122 ->	Training loss=0.0004924360158232352	Validation loss=0.0003658056729134013	epoch_time (seconds)=237
# Epoch 123 ->	Training loss=0.0004859243636019528	Validation loss=0.0003296737716147235	epoch_time (seconds)=239
# Epoch 124 ->	Training loss=0.0004788274139476319	Validation loss=0.00036107582886555067	epoch_time (seconds)=273
# Epoch 125 ->	Training loss=0.0004706345401549091	Validation loss=0.00032574571226579805	epoch_time (seconds)=244
# Epoch 126 ->	Training loss=0.000466034000661845	Validation loss=0.0003336979359564357	epoch_time (seconds)=220
# Epoch 127 ->	Training loss=0.0004549723428984483	Validation loss=0.0003399600894188202	epoch_time (seconds)=236
# Epoch 128 ->	Training loss=0.0004497144157843043	Validation loss=0.0003357742878453167	epoch_time (seconds)=226
# Epoch 129 ->	Training loss=0.00044328893030372757	Validation loss=0.00031969415034875827	epoch_time (seconds)=238
# Epoch 130 ->	Training loss=0.00043650020961649716	Validation loss=0.0003279336309843967	epoch_time (seconds)=275
# Epoch 131 ->	Training loss=0.00043042979086749256	Validation loss=0.00032395824493364157	epoch_time (seconds)=264
# Epoch 132 ->	Training loss=0.00042692718367713195	Validation loss=0.000338113674267355	epoch_time (seconds)=263
# Epoch 133 ->	Training loss=0.00042010082203584415	Validation loss=0.000312482425369616	epoch_time (seconds)=237
# Epoch 134 ->	Training loss=0.0004179185489192605	Validation loss=0.00032939543583420376	epoch_time (seconds)=263
# Epoch 135 ->	Training loss=0.00041071916348300874	Validation loss=0.00033871478931933884	epoch_time (seconds)=255
# Epoch 136 ->	Training loss=0.00040766683135492104	Validation loss=0.0003138844685027522	epoch_time (seconds)=247
# Epoch 137 ->	Training loss=0.00041044670312354964	Validation loss=0.0003259654647365577	epoch_time (seconds)=222
# Epoch 138 ->	Training loss=0.00039850316049220663	Validation loss=0.0003465394567601508	epoch_time (seconds)=216
# Epoch 139 ->	Training loss=0.0003915486643866946	Validation loss=0.00029899514582738823	epoch_time (seconds)=220
# Epoch 140 ->	Training loss=0.0003884403946964691	Validation loss=0.00032875984574631887	epoch_time (seconds)=217
# Epoch 141 ->	Training loss=0.00038426607109916705	Validation loss=0.00031028652029289503	epoch_time (seconds)=218
# Epoch 142 ->	Training loss=0.000378087783853213	Validation loss=0.00032533911350850664	epoch_time (seconds)=215
# Epoch 143 ->	Training loss=0.00037247862201184034	Validation loss=0.00031901628728941343	epoch_time (seconds)=218
# Epoch 144 ->	Training loss=0.00036782923658999306	Validation loss=0.00031713066643504007	epoch_time (seconds)=217
# Epoch 145 ->	Training loss=0.0003643063634323577	Validation loss=0.0003150018047496701	epoch_time (seconds)=212
# Epoch 146 ->	Training loss=0.0003604112231793503	Validation loss=0.0003368632090513024	epoch_time (seconds)=216
# Epoch 147 ->	Training loss=0.00035572990115421516	Validation loss=0.00029877121184480984	epoch_time (seconds)=218
# Epoch 148 ->	Training loss=0.0003517932491376996	Validation loss=0.00035410723526965135	epoch_time (seconds)=220
# Epoch 149 ->	Training loss=0.00035390992222043377	Validation loss=0.0003076058263241892	epoch_time (seconds)=217
# Epoch 150 ->	Training loss=0.00034470292545544606	Validation loss=0.000291430691664627	epoch_time (seconds)=220
# Epoch 151 ->	Training loss=0.0003399009777543445	Validation loss=0.00036317298627220153	epoch_time (seconds)=219
# Epoch 152 ->	Training loss=0.0003394072506731997	Validation loss=0.00028288544932771585	epoch_time (seconds)=217
# Epoch 153 ->	Training loss=0.00033014319099796313	Validation loss=0.00032904983250048287	epoch_time (seconds)=214
# Epoch 154 ->	Training loss=0.00032887450652197003	Validation loss=0.00032820405651120974	epoch_time (seconds)=214
# Epoch 155 ->	Training loss=0.0003224337609329571	Validation loss=0.00029004506295800703	epoch_time (seconds)=213
# Epoch 156 ->	Training loss=0.00031946511201870936	Validation loss=0.0003353325407159611	epoch_time (seconds)=217
# Epoch 157 ->	Training loss=0.0003165778083105882	Validation loss=0.00029520115992586263	epoch_time (seconds)=217
# Epoch 158 ->	Training loss=0.0003128764316594849	Validation loss=0.0002750014641476756	epoch_time (seconds)=216
# Epoch 159 ->	Training loss=0.00030746420573753613	Validation loss=0.0003348063710807978	epoch_time (seconds)=212
# Epoch 160 ->	Training loss=0.00030390164465643466	Validation loss=0.000280018672461749	epoch_time (seconds)=225
# Epoch 161 ->	Training loss=0.00029957798930505913	Validation loss=0.00029403900239398335	epoch_time (seconds)=213
# Epoch 162 ->	Training loss=0.0002974911767523736	Validation loss=0.000291666413227208	epoch_time (seconds)=218
# Epoch 163 ->	Training loss=0.00029072610777802765	Validation loss=0.00030865610121014035	epoch_time (seconds)=215
# Epoch 164 ->	Training loss=0.0002876949923423429	Validation loss=0.00030294417314754424	epoch_time (seconds)=215
# Epoch 165 ->	Training loss=0.0002864762694419672	Validation loss=0.00025638041810220564	epoch_time (seconds)=231
# Epoch 166 ->	Training loss=0.0002837085921783	Validation loss=0.0003207415247218205	epoch_time (seconds)=233
# Epoch 167 ->	Training loss=0.0002779694914352149	Validation loss=0.000272615311980823	epoch_time (seconds)=227
# Epoch 168 ->	Training loss=0.0002743877121247351	Validation loss=0.0002933153329419495	epoch_time (seconds)=222
# Epoch 169 ->	Training loss=0.0002704802415488909	Validation loss=0.0003252942668661382	epoch_time (seconds)=218
# Epoch 170 ->	Training loss=0.0002710088059150924	Validation loss=0.0002853656556195875	epoch_time (seconds)=218
# Epoch 171 ->	Training loss=0.0002662644158893575	Validation loss=0.0002600214187200586	epoch_time (seconds)=217
# Epoch 172 ->	Training loss=0.00026922611868940294	Validation loss=0.0003605298497359759	epoch_time (seconds)=232
# Epoch 173 ->	Training loss=0.00027859321562573314	Validation loss=0.00029051210033325	epoch_time (seconds)=231
# Epoch 174 ->	Training loss=0.0002626098964052896	Validation loss=0.0002466184045304097	epoch_time (seconds)=209
# Epoch 175 ->	Training loss=0.0002722903397322322	Validation loss=0.0003494613069353023	epoch_time (seconds)=204
# Epoch 176 ->	Training loss=0.0002601581412212302	Validation loss=0.00027371363952752894	epoch_time (seconds)=229
# Epoch 177 ->	Training loss=0.0002497904933989048	Validation loss=0.00024815641486022075	epoch_time (seconds)=220
# Epoch 178 ->	Training loss=0.00024854753670903545	Validation loss=0.00039644673984830925	epoch_time (seconds)=217
# Epoch 179 ->	Training loss=0.00026310841106654453	Validation loss=0.00023728665096401058	epoch_time (seconds)=217
# Epoch 180 ->	Training loss=0.00024913774298814434	Validation loss=0.0003047113170102201	epoch_time (seconds)=215
# Epoch 181 ->	Training loss=0.00024203948366145292	Validation loss=0.0002844986783082448	epoch_time (seconds)=221
# Epoch 182 ->	Training loss=0.00023492001734363535	Validation loss=0.00024001436932901278	epoch_time (seconds)=215
# Epoch 183 ->	Training loss=0.00023399184768398604	Validation loss=0.0003449750028765454	epoch_time (seconds)=208
# Epoch 184 ->	Training loss=0.0002320957719348371	Validation loss=0.00024416655505486484	epoch_time (seconds)=213
# Epoch 185 ->	Training loss=0.0002308528977058207	Validation loss=0.00029933954790118474	epoch_time (seconds)=216
# Epoch 186 ->	Training loss=0.00022371460120969763	Validation loss=0.0002689502780235105	epoch_time (seconds)=218
# Epoch 187 ->	Training loss=0.00021941139129921794	Validation loss=0.00026130198413051034	epoch_time (seconds)=217
# Epoch 188 ->	Training loss=0.00021639341624298444	Validation loss=0.00028000241302634664	epoch_time (seconds)=214
# Epoch 189 ->	Training loss=0.00021328870692135146	Validation loss=0.0002696662716808453	epoch_time (seconds)=239
# Epoch 190 ->	Training loss=0.00021126976935192943	Validation loss=0.00028425266062344416	epoch_time (seconds)=239
# Epoch 191 ->	Training loss=0.00021340535022318363	Validation loss=0.0002898798216626228	epoch_time (seconds)=227
# Epoch 192 ->	Training loss=0.00020671942426512638	Validation loss=0.00026015651485633735	epoch_time (seconds)=236
# Epoch 193 ->	Training loss=0.00020646587169418731	Validation loss=0.0003023869211348707	epoch_time (seconds)=217
# Epoch 194 ->	Training loss=0.0002029229848024746	Validation loss=0.00023231424058710637	epoch_time (seconds)=225
# Epoch 195 ->	Training loss=0.00020248320167108128	Validation loss=0.00030590597535263533	epoch_time (seconds)=232
# Epoch 196 ->	Training loss=0.00020044253809222332	Validation loss=0.0002507382046003787	epoch_time (seconds)=231
# Epoch 197 ->	Training loss=0.0001964409117742131	Validation loss=0.0002692772042087167	epoch_time (seconds)=233
# Epoch 198 ->	Training loss=0.00019365866804340234	Validation loss=0.00025189510131837467	epoch_time (seconds)=215
# Epoch 199 ->	Training loss=0.0001919846205661694	Validation loss=0.00029412482335019726	epoch_time (seconds)=222
# Epoch 200 ->	Training loss=0.00018863743753172457	Validation loss=0.0002243955480734252	epoch_time (seconds)=211
# Epoch 201 ->	Training loss=0.00018750105906898776	Validation loss=0.0002839669218474969	epoch_time (seconds)=214
# Epoch 202 ->	Training loss=0.00018527367016455779	Validation loss=0.0002623985577596805	epoch_time (seconds)=221
# Epoch 203 ->	Training loss=0.00018298069577819356	Validation loss=0.0002459831811014802	epoch_time (seconds)=210
# Epoch 204 ->	Training loss=0.00018421010463498533	Validation loss=0.00026408293739268903	epoch_time (seconds)=210
# Epoch 205 ->	Training loss=0.00018184528744313866	Validation loss=0.00026323753956766983	epoch_time (seconds)=216
# Epoch 206 ->	Training loss=0.00017861276865005493	Validation loss=0.00021415428370376565	epoch_time (seconds)=213
# Epoch 207 ->	Training loss=0.00017776947061065584	Validation loss=0.00031784697426920746	epoch_time (seconds)=211
# Epoch 208 ->	Training loss=0.00017565159942023456	Validation loss=0.00019502965253626116	epoch_time (seconds)=215
# Epoch 209 ->	Training loss=0.00018254153352851668	Validation loss=0.00027686601144386345	epoch_time (seconds)=216
# Epoch 210 ->	Training loss=0.00017049337232795855	Validation loss=0.00022727440702369163	epoch_time (seconds)=216
# Epoch 211 ->	Training loss=0.0001693170537085583	Validation loss=0.00022673246274514927	epoch_time (seconds)=215
# Epoch 212 ->	Training loss=0.0001690564192055414	Validation loss=0.0003077765996365588	epoch_time (seconds)=209
# Epoch 213 ->	Training loss=0.00017481079945961633	Validation loss=0.00022820513863601523	epoch_time (seconds)=211
# Epoch 214 ->	Training loss=0.0001668672339292243	Validation loss=0.00021880537327821373	epoch_time (seconds)=212
# Epoch 215 ->	Training loss=0.00016078042972367257	Validation loss=0.0002894700330994189	epoch_time (seconds)=211
# Epoch 216 ->	Training loss=0.0001636065038231512	Validation loss=0.00022790232073483473	epoch_time (seconds)=214
# Epoch 217 ->	Training loss=0.00016058967351758233	Validation loss=0.00021732844321846706	epoch_time (seconds)=213
# Epoch 218 ->	Training loss=0.00015249392405773202	Validation loss=0.00027287949837991244	epoch_time (seconds)=212
# Epoch 219 ->	Training loss=0.00015135642024688423	Validation loss=0.0001962503671919087	epoch_time (seconds)=213
# Epoch 220 ->	Training loss=0.00015869665852126977	Validation loss=0.0002786947722932765	epoch_time (seconds)=209
# Epoch 221 ->	Training loss=0.00015474139945581555	Validation loss=0.00022432754165977565	epoch_time (seconds)=210
# Epoch 222 ->	Training loss=0.00015019829637215784	Validation loss=0.00020433879361462671	epoch_time (seconds)=212
# Epoch 223 ->	Training loss=0.00015236937421529242	Validation loss=0.0003152290968128961	epoch_time (seconds)=207
# Epoch 224 ->	Training loss=0.00015689364712064466	Validation loss=0.00019369661300803082	epoch_time (seconds)=211
# Epoch 225 ->	Training loss=0.00014778390565576652	Validation loss=0.00025588432141811435	epoch_time (seconds)=211
# Epoch 226 ->	Training loss=0.0001434598865065103	Validation loss=0.00022769038626231617	epoch_time (seconds)=208
# Epoch 227 ->	Training loss=0.0001375339440225313	Validation loss=0.000206687875061255	epoch_time (seconds)=210
# Epoch 228 ->	Training loss=0.00013531719256813327	Validation loss=0.0002585905405818342	epoch_time (seconds)=210
# Epoch 229 ->	Training loss=0.0001337960954212273	Validation loss=0.00018470307395313128	epoch_time (seconds)=207
# Epoch 230 ->	Training loss=0.0001375705663425227	Validation loss=0.0003037105487268915	epoch_time (seconds)=211
# Epoch 231 ->	Training loss=0.00014690228272229433	Validation loss=0.00019093944158185642	epoch_time (seconds)=213
# Epoch 232 ->	Training loss=0.00013816085023184618	Validation loss=0.000204197994545831	epoch_time (seconds)=213
# Epoch 233 ->	Training loss=0.00012773622681076327	Validation loss=0.00024587166709870537	epoch_time (seconds)=212
# Epoch 234 ->	Training loss=0.00012558154897609106	Validation loss=0.000175616182978949	epoch_time (seconds)=211
# Epoch 235 ->	Training loss=0.00012536368255193034	Validation loss=0.0002696191912284128	epoch_time (seconds)=212
# Epoch 236 ->	Training loss=0.0001254837504044796	Validation loss=0.00018784719139933743	epoch_time (seconds)=213
# Epoch 237 ->	Training loss=0.00012158448468350495	Validation loss=0.0002274717329207751	epoch_time (seconds)=211
# Epoch 238 ->	Training loss=0.00012065867000880341	Validation loss=0.00022115139591751383	epoch_time (seconds)=211
# Epoch 239 ->	Training loss=0.00011748960726739217	Validation loss=0.00020987831032380497	epoch_time (seconds)=210
# Epoch 240 ->	Training loss=0.00011610857230455925	Validation loss=0.00021588907080554823	epoch_time (seconds)=210
# Epoch 241 ->	Training loss=0.00011268485589729	Validation loss=0.00020676217532438694	epoch_time (seconds)=214
# Epoch 242 ->	Training loss=0.00011307929526083171	Validation loss=0.00019415884996052234	epoch_time (seconds)=214
# Epoch 243 ->	Training loss=0.00010990888161662345	Validation loss=0.0002153376277338405	epoch_time (seconds)=214
# Epoch 244 ->	Training loss=0.00010755123366834596	Validation loss=0.00018500085392720683	epoch_time (seconds)=214
# Epoch 245 ->	Training loss=0.00010664815393586953	Validation loss=0.0002215580311876074	epoch_time (seconds)=213
# Epoch 246 ->	Training loss=0.00010576744292241831	Validation loss=0.00018169929579289559	epoch_time (seconds)=209
# Epoch 247 ->	Training loss=0.00010376522307827447	Validation loss=0.00022492562387522826	epoch_time (seconds)=211
# Epoch 248 ->	Training loss=0.00010343077641058092	Validation loss=0.0001789522270707227	epoch_time (seconds)=212
# Epoch 249 ->	Training loss=0.00010249472688883543	Validation loss=0.00020203126278885925	epoch_time (seconds)=211
# Epoch 250 ->	Training loss=0.00010022629915814225	Validation loss=0.0002151294775755814	epoch_time (seconds)=211
# Epoch 251 ->	Training loss=9.966550229970987e-05	Validation loss=0.00017232811419174145	epoch_time (seconds)=212
# Epoch 252 ->	Training loss=9.896897245198488e-05	Validation loss=0.000224772027980874	epoch_time (seconds)=210
# Epoch 253 ->	Training loss=9.761954424902797e-05	Validation loss=0.00018023654123406398	epoch_time (seconds)=212
# Epoch 254 ->	Training loss=9.421562087178852e-05	Validation loss=0.00018402699030852112	epoch_time (seconds)=210
# Epoch 255 ->	Training loss=9.354023738220955e-05	Validation loss=0.0002458849102413148	epoch_time (seconds)=210
# Epoch 256 ->	Training loss=9.734353564757232e-05	Validation loss=0.00016118103164991502	epoch_time (seconds)=213
# Epoch 257 ->	Training loss=0.00010051584104076028	Validation loss=0.00019897883342292428	epoch_time (seconds)=213
# Epoch 258 ->	Training loss=9.251318260794505e-05	Validation loss=0.00020914236215700458	epoch_time (seconds)=208
# Epoch 259 ->	Training loss=8.998645838194837e-05	Validation loss=0.0001751475336927329	epoch_time (seconds)=211
# Epoch 260 ->	Training loss=8.944098226493225e-05	Validation loss=0.0002051352783799588	epoch_time (seconds)=206
# Epoch 261 ->	Training loss=9.034369819952796e-05	Validation loss=0.00018344008760321355	epoch_time (seconds)=207
# Epoch 262 ->	Training loss=8.544729401667912e-05	Validation loss=0.0001679995195430969	epoch_time (seconds)=208
# Epoch 263 ->	Training loss=8.471807571671282e-05	Validation loss=0.0002038794990931139	epoch_time (seconds)=207
# Epoch 264 ->	Training loss=8.31957659102045e-05	Validation loss=0.00016355611300839575	epoch_time (seconds)=210
# Epoch 265 ->	Training loss=8.396564226131886e-05	Validation loss=0.00016392649560659987	epoch_time (seconds)=212
# Epoch 266 ->	Training loss=8.197908027796075e-05	Validation loss=0.0002202469758000997	epoch_time (seconds)=215
# Epoch 267 ->	Training loss=8.338360930792987e-05	Validation loss=0.0001694493024924147	epoch_time (seconds)=214
# Epoch 268 ->	Training loss=8.033648191485554e-05	Validation loss=0.00017558676142518105	epoch_time (seconds)=211
# Epoch 269 ->	Training loss=7.78152170823887e-05	Validation loss=0.00020950274452376767	epoch_time (seconds)=211
# Epoch 270 ->	Training loss=7.934200887878735e-05	Validation loss=0.0001630305927172897	epoch_time (seconds)=212
# Epoch 271 ->	Training loss=7.857722812332213e-05	Validation loss=0.00015606186658551858	epoch_time (seconds)=211
# Epoch 272 ->	Training loss=7.463186436022322e-05	Validation loss=0.00022193148642788007	epoch_time (seconds)=211
# Epoch 273 ->	Training loss=7.721357542322949e-05	Validation loss=0.0001527882535599973	epoch_time (seconds)=212
# Epoch 274 ->	Training loss=7.364222013469164e-05	Validation loss=0.00017499008802337567	epoch_time (seconds)=209
# Epoch 275 ->	Training loss=7.252452633110806e-05	Validation loss=0.00020319891143164294	epoch_time (seconds)=209
# Epoch 276 ->	Training loss=7.325608506410693e-05	Validation loss=0.00015710904142764322	epoch_time (seconds)=210
# Epoch 277 ->	Training loss=7.096056409257774e-05	Validation loss=0.00017083858959889958	epoch_time (seconds)=209
# Epoch 278 ->	Training loss=7.0167096661559e-05	Validation loss=0.00020702049019724454	epoch_time (seconds)=210
# Epoch 279 ->	Training loss=7.25919477796803e-05	Validation loss=0.00015241559001135207	epoch_time (seconds)=211
# Epoch 280 ->	Training loss=7.036462435886885e-05	Validation loss=0.00016401376450421936	epoch_time (seconds)=207
# Epoch 281 ->	Training loss=6.729913972473393e-05	Validation loss=0.00019013965404476147	epoch_time (seconds)=207
# Epoch 282 ->	Training loss=7.2850756017336e-05	Validation loss=0.00017679428317774064	epoch_time (seconds)=210
# Epoch 283 ->	Training loss=6.563329952768981e-05	Validation loss=0.0001461996305621984	epoch_time (seconds)=211
# Epoch 284 ->	Training loss=6.609035093182077e-05	Validation loss=0.00019557963544620787	epoch_time (seconds)=212
# Epoch 285 ->	Training loss=6.951572383210684e-05	Validation loss=0.0001758454932109183	epoch_time (seconds)=211
# Epoch 286 ->	Training loss=6.287490396061912e-05	Validation loss=0.00014370424541375524	epoch_time (seconds)=210
# Epoch 287 ->	Training loss=6.372228745021857e-05	Validation loss=0.00017734131607363249	epoch_time (seconds)=214
# Epoch 288 ->	Training loss=6.27032471432661e-05	Validation loss=0.0001771065571215994	epoch_time (seconds)=211
# Epoch 289 ->	Training loss=6.0755060985684395e-05	Validation loss=0.00013349742560789992	epoch_time (seconds)=211
# Epoch 290 ->	Training loss=6.216448067182985e-05	Validation loss=0.0001793396784902248	epoch_time (seconds)=219
# Epoch 291 ->	Training loss=6.0817112777537354e-05	Validation loss=0.0001707074355369332	epoch_time (seconds)=210
# Epoch 292 ->	Training loss=5.9036204523484535e-05	Validation loss=0.00012821761100304855	epoch_time (seconds)=204
# Epoch 293 ->	Training loss=6.54216297940972e-05	Validation loss=0.0001482131738826784	epoch_time (seconds)=204
# Epoch 294 ->	Training loss=5.7528569110824414e-05	Validation loss=0.00019473223474483423	epoch_time (seconds)=207
# Epoch 295 ->	Training loss=6.09001375172132e-05	Validation loss=0.00015592157553623269	epoch_time (seconds)=206
# Epoch 296 ->	Training loss=5.677083997094693e-05	Validation loss=0.00012733205415438176	epoch_time (seconds)=206
# Epoch 297 ->	Training loss=5.7364823684717216e-05	Validation loss=0.0001837476793056806	epoch_time (seconds)=205
# Epoch 298 ->	Training loss=5.83392902626656e-05	Validation loss=0.00016429249985367765	epoch_time (seconds)=207
# Epoch 299 ->	Training loss=5.4003680512929954e-05	Validation loss=0.00014508522739036726	epoch_time (seconds)=207
# Epoch 300 ->	Training loss=5.314342342899181e-05	Validation loss=0.00015489078783027625	epoch_time (seconds)=208
# Epoch 301 ->	Training loss=5.232860591301384e-05	Validation loss=0.00016045064480387528	epoch_time (seconds)=210
# Epoch 302 ->	Training loss=5.27933043485973e-05	Validation loss=0.0001455755863502745	epoch_time (seconds)=211
# Epoch 303 ->	Training loss=5.2476980878661074e-05	Validation loss=0.0001694184019649177	epoch_time (seconds)=207
# Epoch 304 ->	Training loss=5.217841317062266e-05	Validation loss=0.00014493430368845396	epoch_time (seconds)=208
# Epoch 305 ->	Training loss=5.172166371873269e-05	Validation loss=0.0001269618613410767	epoch_time (seconds)=209
# Epoch 306 ->	Training loss=5.127288507840907e-05	Validation loss=0.000183988745886655	epoch_time (seconds)=210
# Epoch 307 ->	Training loss=5.331122883944772e-05	Validation loss=0.00015437493498450893	epoch_time (seconds)=213
# Epoch 308 ->	Training loss=5.0268000146994986e-05	Validation loss=0.00015015324469119142	epoch_time (seconds)=213
# Epoch 309 ->	Training loss=4.868771914819566e-05	Validation loss=0.00014149142235185316	epoch_time (seconds)=210
# Epoch 310 ->	Training loss=5.118411960817563e-05	Validation loss=0.00014112337404381515	epoch_time (seconds)=211
# Epoch 311 ->	Training loss=4.866790307763343e-05	Validation loss=0.0001663306691032141	epoch_time (seconds)=214
# Epoch 312 ->	Training loss=5.041382852747726e-05	Validation loss=0.0001563546468469403	epoch_time (seconds)=214
# Epoch 313 ->	Training loss=4.689944883769689e-05	Validation loss=0.00013721374946920866	epoch_time (seconds)=211
# Epoch 314 ->	Training loss=4.6708169975318015e-05	Validation loss=0.00015119895115030753	epoch_time (seconds)=207
# Epoch 315 ->	Training loss=4.648281659077232e-05	Validation loss=0.00016226177145119622	epoch_time (seconds)=206
# Epoch 316 ->	Training loss=4.5909921027487144e-05	Validation loss=0.00012671871598605492	epoch_time (seconds)=207
# Epoch 317 ->	Training loss=4.611227753533361e-05	Validation loss=0.00013928290324763027	epoch_time (seconds)=208
# Epoch 318 ->	Training loss=4.4512108919055514e-05	Validation loss=0.0001596982690771078	epoch_time (seconds)=211
# Epoch 319 ->	Training loss=4.616644946509041e-05	Validation loss=0.00015592890353181258	epoch_time (seconds)=210
# Epoch 320 ->	Training loss=4.510015423875302e-05	Validation loss=0.00014479191404940424	epoch_time (seconds)=213
# Epoch 321 ->	Training loss=4.343471421937769e-05	Validation loss=0.0001391342387642333	epoch_time (seconds)=213
# Epoch 322 ->	Training loss=4.308059336229538e-05	Validation loss=0.00013803934123933308	epoch_time (seconds)=209
# Epoch 323 ->	Training loss=4.2605865019140765e-05	Validation loss=0.0001404993417527531	epoch_time (seconds)=208
# Epoch 324 ->	Training loss=4.2450935628342755e-05	Validation loss=0.00013383607284846402	epoch_time (seconds)=213
# Epoch 325 ->	Training loss=4.242394061293453e-05	Validation loss=0.00014270042071925907	epoch_time (seconds)=212
# Epoch 326 ->	Training loss=4.179008101345971e-05	Validation loss=0.00014876494496278192	epoch_time (seconds)=212
# Epoch 327 ->	Training loss=4.1493753087706864e-05	Validation loss=0.0001314907985663553	epoch_time (seconds)=214
# Epoch 328 ->	Training loss=4.1930918087018654e-05	Validation loss=0.00012289384107715733	epoch_time (seconds)=211
# Epoch 329 ->	Training loss=4.487343782481427e-05	Validation loss=0.00014352710932008408	epoch_time (seconds)=205
# Epoch 330 ->	Training loss=4.2498086259001866e-05	Validation loss=0.0001718164656474764	epoch_time (seconds)=204
# Epoch 331 ->	Training loss=4.646339948521927e-05	Validation loss=0.00015365600485450832	epoch_time (seconds)=207
# Epoch 332 ->	Training loss=4.113358590984717e-05	Validation loss=0.00011466544131893334	epoch_time (seconds)=222
# Epoch 333 ->	Training loss=4.550323137664236e-05	Validation loss=0.00011576658131025418	epoch_time (seconds)=237
# Epoch 334 ->	Training loss=4.134354700606006e-05	Validation loss=0.00015945227341016992	epoch_time (seconds)=234
# Epoch 335 ->	Training loss=4.3079589280144624e-05	Validation loss=0.00016207725236483866	epoch_time (seconds)=229
# Epoch 336 ->	Training loss=4.245721356710419e-05	Validation loss=0.00012522591481167817	epoch_time (seconds)=210
# Epoch 337 ->	Training loss=4.305276888771914e-05	Validation loss=0.00011037755383372715	epoch_time (seconds)=209
# Epoch 338 ->	Training loss=4.537385029834695e-05	Validation loss=0.00015989567614098054	epoch_time (seconds)=212
# Epoch 339 ->	Training loss=4.817768907135663e-05	Validation loss=0.00015971632187127704	epoch_time (seconds)=217
# Epoch 340 ->	Training loss=4.450724251607122e-05	Validation loss=9.755889415301306e-05	epoch_time (seconds)=211
# Epoch 341 ->	Training loss=5.4565527534577996e-05	Validation loss=0.00015069557190745814	epoch_time (seconds)=212
# Epoch 342 ->	Training loss=4.833433801347079e-05	Validation loss=0.00018266063884154362	epoch_time (seconds)=208
# Epoch 343 ->	Training loss=4.459875344764441e-05	Validation loss=0.0001012970472270487	epoch_time (seconds)=210
# Epoch 344 ->	Training loss=4.551269375951961e-05	Validation loss=0.00012504986332263337	epoch_time (seconds)=204
# Epoch 345 ->	Training loss=3.8723057514289394e-05	Validation loss=0.00017327690921691322	epoch_time (seconds)=211
# Epoch 346 ->	Training loss=4.530879838663774e-05	Validation loss=0.00013187692006441542	epoch_time (seconds)=213
# Epoch 347 ->	Training loss=3.9250177602904536e-05	Validation loss=0.0001116604686026431	epoch_time (seconds)=213
# Epoch 348 ->	Training loss=4.49027975264471e-05	Validation loss=0.00014646255594773106	epoch_time (seconds)=235
# Epoch 349 ->	Training loss=4.0581087281073756e-05	Validation loss=0.00016390985513443142	epoch_time (seconds)=218
# Epoch 350 ->	Training loss=4.118829019716941e-05	Validation loss=0.00011888063965241338	epoch_time (seconds)=221
# Epoch 351 ->	Training loss=4.025286398245953e-05	Validation loss=0.00011779488113164884	epoch_time (seconds)=245
# Epoch 352 ->	Training loss=3.879145636650113e-05	Validation loss=0.00014630487288754833	epoch_time (seconds)=214
# Epoch 353 ->	Training loss=3.8334765122272074e-05	Validation loss=0.000133955892683672	epoch_time (seconds)=214
# Epoch 354 ->	Training loss=3.725593827160386e-05	Validation loss=0.00010316322499497591	epoch_time (seconds)=212
# Epoch 355 ->	Training loss=4.0226882750478886e-05	Validation loss=0.00015093411632555138	epoch_time (seconds)=210
# Epoch 356 ->	Training loss=3.8836751627968624e-05	Validation loss=0.0001478156243098254	epoch_time (seconds)=211
# Epoch 357 ->	Training loss=3.977292847897237e-05	Validation loss=0.0001267910594687943	epoch_time (seconds)=210
# Epoch 358 ->	Training loss=3.5293093484748774e-05	Validation loss=0.0001305655003143524	epoch_time (seconds)=216
# Epoch 359 ->	Training loss=3.588669157276551e-05	Validation loss=0.0001120886420926973	epoch_time (seconds)=208
# Epoch 360 ->	Training loss=3.533642666297965e-05	Validation loss=0.00014573919188639586	epoch_time (seconds)=214
# Epoch 361 ->	Training loss=3.5320357710588723e-05	Validation loss=0.00013289967381119468	epoch_time (seconds)=209
# Epoch 362 ->	Training loss=3.4301241006081305e-05	Validation loss=0.00012110701483688696	epoch_time (seconds)=213
# Epoch 363 ->	Training loss=3.464444671408273e-05	Validation loss=0.00012278339245338382	epoch_time (seconds)=212
# Epoch 364 ->	Training loss=3.349057321126262e-05	Validation loss=0.00013059815083864542	epoch_time (seconds)=214
# Epoch 365 ->	Training loss=3.3427465192896e-05	Validation loss=0.00012497076519451852	epoch_time (seconds)=220
# Epoch 366 ->	Training loss=3.336609006510116e-05	Validation loss=0.00013344289748974377	epoch_time (seconds)=214
# Epoch 367 ->	Training loss=3.3591746614547446e-05	Validation loss=0.0001147382761395586	epoch_time (seconds)=220
# Epoch 368 ->	Training loss=3.4093940485036e-05	Validation loss=0.00012658359662822023	epoch_time (seconds)=213
# Epoch 369 ->	Training loss=3.306490179966204e-05	Validation loss=0.0001443295388191937	epoch_time (seconds)=205
# Epoch 370 ->	Training loss=3.32435023058982e-05	Validation loss=0.00011659744514496983	epoch_time (seconds)=221
# Epoch 371 ->	Training loss=3.293506354869654e-05	Validation loss=0.0001213430825632334	epoch_time (seconds)=202
# Epoch 372 ->	Training loss=3.292731040952882e-05	Validation loss=0.00013649722996910609	epoch_time (seconds)=211
# Epoch 373 ->	Training loss=3.457430769534161e-05	Validation loss=0.00014074077923812106	epoch_time (seconds)=221
# Epoch 374 ->	Training loss=3.273877640215991e-05
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# Cell In[6], line 35
#      33 for batch in iter(valid_dataloader):
#      34     x, y = batch[0].to(DEVICE), batch[1].to(DEVICE)
# ---> 35     prediction = model(x)
#      36     vloss = loss_function(prediction, y)
#      38     epoch_vloss += vloss.item() * x.size(0)
#
# File /opt/homebrew/lib/python3.10/site-packages/torch/nn/modules/module.py:1501, in Module._call_impl(self, *args, **kwargs)
#    1496 # If we don't have any hooks, we want to skip the rest of the logic in
#    1497 # this function, and just call forward.
#    1498 if not (self._backward_hooks or self._backward_pre_hooks or self._forward_hooks or self._forward_pre_hooks
#    1499         or _global_backward_pre_hooks or _global_backward_hooks
#    1500         or _global_forward_hooks or _global_forward_pre_hooks):
# -> 1501     return forward_call(*args, **kwargs)
#    1502 # Do not call functions when jit is used
#    1503 full_backward_hooks, non_full_backward_hooks = [], []
#
# Cell In[3], line 32, in NeRF2D.forward(self, inputs)
#      29 input_features = torch.cat((fourier_out, input_features), dim=-1)
#      31 # Feed-forward through the rest of the neural network
# ---> 32 x = self.mlp(input_features)
#      34 return x
#
# File /opt/homebrew/lib/python3.10/site-packages/torch/nn/modules/module.py:1501, in Module._call_impl(self, *args, **kwargs)
#    1496 # If we don't have any hooks, we want to skip the rest of the logic in
#    1497 # this function, and just call forward.
#    1498 if not (self._backward_hooks or self._backward_pre_hooks or self._forward_hooks or self._forward_pre_hooks
#    1499         or _global_backward_pre_hooks or _global_backward_hooks
#    1500         or _global_forward_hooks or _global_forward_pre_hooks):
# -> 1501     return forward_call(*args, **kwargs)
#    1502 # Do not call functions when jit is used
#    1503 full_backward_hooks, non_full_backward_hooks = [], []
#
# File /opt/homebrew/lib/python3.10/site-packages/torch/nn/modules/container.py:217, in Sequential.forward(self, input)
#     215 def forward(self, input):
#     216     for module in self:
# --> 217         input = module(input)
#     218     return input
#
# File /opt/homebrew/lib/python3.10/site-packages/torch/nn/modules/module.py:1501, in Module._call_impl(self, *args, **kwargs)
#    1496 # If we don't have any hooks, we want to skip the rest of the logic in
#    1497 # this function, and just call forward.
#    1498 if not (self._backward_hooks or self._backward_pre_hooks or self._forward_hooks or self._forward_pre_hooks
#    1499         or _global_backward_pre_hooks or _global_backward_hooks
#    1500         or _global_forward_hooks or _global_forward_pre_hooks):
# -> 1501     return forward_call(*args, **kwargs)
#    1502 # Do not call functions when jit is used
#    1503 full_backward_hooks, non_full_backward_hooks = [], []
#
# File /opt/homebrew/lib/python3.10/site-packages/torch/nn/modules/linear.py:114, in Linear.forward(self, input)
#     113 def forward(self, input: Tensor) -> Tensor:
# --> 114     return F.linear(input, self.weight, self.bias)
#
# KeyboardInterrupt:

# %%
metrics_logger.plot_metrics_by_epoch(start_from_epoch=2)
metrics_logger.save_metrics()
# Out:
# epoch_time (seconds)=17
# Metrics exported in the following csv file: metrics/logged_metrics/univariate_NeRF_256fourier-features_layers256-256-256_training_factors=ti32-ct32_31-07-2023_10-46-22.csv

# %% [markdown]
# # Evaluation and testing

# %%
# loading best model
model = NeRF2D(N_COORDINATES, n_features, output_space).to(DEVICE)
model.load_state_dict(torch.load(BEST_MODEL_PATH))
model.eval()

save_results = True

# evaluation on trainset
evaluate_model(
    model,
    data=train_dataloader,
    data_type="train",
    model_description=MODEL_DESCRIPTION,
    save_results=save_results,
    experiment=EXPERIMENT,
)

print("\n")

# evalution on testset
evaluate_model(
    model,
    data=test_dataloader,
    data_type="test",
    model_description=MODEL_DESCRIPTION,
    save_results=save_results,
    experiment=EXPERIMENT,
)
# Out:
# Train results for univariate_NeRF_256fourier-features_layers256-256-256_training_factors=ti32-ct32_discr_factors_x2_30_y-2_2_step0.125_TIstep0.01_CTstep0.01: act. func. ReLU (not last layer), batch multiplier 8, 500 epochs, lr=0.0001)
# metrics/final_results/trainset_results_interpolation.csv
# r2_score=0.9680684494968329
# explained_variance_score=0.9694012403488159
# mean_squared_error=5.9005215007346123e-05
# mean_absolute_error=0.0035334527492523193
# median_absolute_error=0.001875568414106965
# mean_absolute_percentage_error=1283317170176.0
# peak_signal_noise_ratio=42.291096027845605
# Prediction time=1.0479527104291178e-05s
#
#
# Test results for univariate_NeRF_256fourier-features_layers256-256-256_training_factors=ti32-ct32_discr_factors_x2_30_y-2_2_step0.125_TIstep0.01_CTstep0.01: act. func. ReLU (not last layer), batch multiplier 8, 500 epochs, lr=0.0001)
# metrics/final_results/testset_results_interpolation.csv
# r2_score=0.9146869365567185
# explained_variance_score=0.9147767424583435
# mean_squared_error=9.400626731803641e-05
# mean_absolute_error=0.0043495758436620235
# median_absolute_error=0.0019352426752448082
# mean_absolute_percentage_error=146706120704.0
# peak_signal_noise_ratio=40.26843191390669
# Prediction time=7.102739810621368e-06s

# %%
test_dataset = test_dataloader.dataset
num_cells = test_dataset.num_cells
num_fields = len(test_dataset) // num_cells
field_indices = list(range(num_fields))
random.shuffle(field_indices)

with torch.no_grad():
    for field_idx in field_indices[:10]:
        ti, ct, ws, wake_field, predicted_wake_field = (
            test_dataset.get_parameters_for_plotting_univariate(model, field_idx)
        )
        plotting.plot_maps(
            test_dataset.X_grid,
            test_dataset.Y_grid,
            wake_field,
            predicted_wake_field,
            ti,
            ct,
            ws,
            error_to_plot="absolute",
        )
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# Cell In[9], line 2
#       1 test_dataset = test_dataloader.dataset
# ----> 2 num_cells = test_dataset.num_cells
#       3 num_fields = len(test_dataset)//num_cells
#       4 field_indices = list(range(num_fields))
#
# AttributeError: 'DeficitDataset' object has no attribute 'num_cells'
